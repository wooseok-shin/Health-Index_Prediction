# %% [markdown]
# # 데이터 불러오기 및 전처리

# %%
import pandas as pd
import numpy as np

# 데이터 전처리에 필요한 패키지 장착

# %%
GJ_2011=pd.read_csv("./NHIS_OPEN_GJ_2011.csv",encoding='CP949') # 데이터 불러오기
GJ_2011.head() # 데이터 일부 확인
# Out:
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0  2011   762544     2            1    47        145          40    66    1.2
# 1  2011    56745     2            1    26        145          45    68    0.9
# 2  2011   171067     2            1    26        145          45    65    1.0
# 3  2011   196496     2            1    27        145          45    68    0.9
# 4  2011   812525     2            1    46        150          35    56    0.7
#
#    시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 0    1.2  ...     13   1.0   1.0          1      NaN    0.0      0.0
# 1    1.0  ...     12   1.0   0.0          0      NaN    NaN      NaN
# 2    1.5  ...     16   1.0   0.0          0      NaN    NaN      NaN
# 3    0.9  ...     23   1.0   0.0          1      NaN    0.0      0.0
# 4    0.9  ...      8   1.0   0.0          0      NaN    NaN      NaN
#
#    제3대구치(사랑니)이상   치석   데이터공개일자
# 0           0.0  0.0  20151220
# 1           NaN  NaN  20151220
# 2           NaN  NaN  20151220
# 3           0.0  0.0  20151220
# 4           NaN  NaN  20151220
#
# [5 rows x 34 columns]

# %%
GJ_2011.shape # 데이터 차원 : 1000000 x 34
# Out:
# (1000000, 34)

# %%
GJ_2011.info() # 34개 변수 타입 : 정수형 또는 실수형
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
# 기준년도            1000000 non-null int64
# 가입자일련번호         1000000 non-null int64
# 성별코드            1000000 non-null int64
# 연령대코드(5세단위)     1000000 non-null int64
# 시도코드            1000000 non-null int64
# 신장(5Cm단위)       1000000 non-null int64
# 체중(5Kg 단위)      1000000 non-null int64
# 허리둘레            1000000 non-null int64
# 시력(좌)           999907 non-null float64
# 시력(우)           999897 non-null float64
# 청력(좌)           999882 non-null float64
# 청력(우)           999879 non-null float64
# 수축기혈압           1000000 non-null int64
# 이완기혈압           1000000 non-null int64
# 식전혈당(공복혈당)      1000000 non-null int64
# 총콜레스테롤          1000000 non-null int64
# 트리글리세라이드        1000000 non-null int64
# HDL콜레스테롤        1000000 non-null float64
# LDL콜레스테롤        989987 non-null float64
# 혈색소             1000000 non-null float64
# 요단백             995622 non-null float64
# 혈청크레아티닌         1000000 non-null float64
# (혈청지오티)AST      1000000 non-null int64
# (혈청지오티)ALT      1000000 non-null int64
# 감마지티피           1000000 non-null int64
# 흡연상태            999841 non-null float64
# 음주여부            999785 non-null float64
# 구강검진 수검여부       1000000 non-null int64
# 치아우식증유무         155208 non-null float64
# 결손치유무           366828 non-null float64
# 치아마모증유무         366827 non-null float64
# 제3대구치(사랑니)이상    286823 non-null float64
# 치석              366830 non-null float64
# 데이터공개일자         1000000 non-null int64
# dtypes: float64(16), int64(18)
# memory usage: 259.4 MB

# %%
GJ_2011.isna().sum()

# 결측치가 있는 변수 : 시력좌/시력우/청력좌/청력우/LDL/요단백/흡연상태/음주여부/치아우식증유무/결손치유무/치아마모증유무/사랑니이상/치석
# Out:
# 기준년도                 0
# 가입자일련번호              0
# 성별코드                 0
# 연령대코드(5세단위)          0
# 시도코드                 0
# 신장(5Cm단위)            0
# 체중(5Kg 단위)           0
# 허리둘레                 0
# 시력(좌)               93
# 시력(우)              103
# 청력(좌)              118
# 청력(우)              121
# 수축기혈압                0
# 이완기혈압                0
# 식전혈당(공복혈당)           0
# 총콜레스테롤               0
# 트리글리세라이드             0
# HDL콜레스테롤             0
# LDL콜레스테롤         10013
# 혈색소                  0
# 요단백               4378
# 혈청크레아티닌              0
# (혈청지오티)AST           0
# (혈청지오티)ALT           0
# 감마지티피                0
# 흡연상태               159
# 음주여부               215
# 구강검진 수검여부            0
# 치아우식증유무         844792
# 결손치유무           633172
# 치아마모증유무         633173
# 제3대구치(사랑니)이상    713177
# 치석              633170
# 데이터공개일자              0
# dtype: int64

# %%
GJ_2011=GJ_2011.drop(['치아우식증유무','결손치유무','치아마모증유무','제3대구치(사랑니)이상','치석'],axis=1)

# 결측비율이 60%를 넘어가는 5개 변수 제거

# %%
GJ_2011.shape # 5개의 변수가 제거됨
# Out:
# (1000000, 29)

# %%
GJ_2011.describe()

# 영-분산에 해당하는 변수 : 기준년도/데이터공개일자
# Out:
#             기준년도         가입자일련번호            성별코드     연령대코드(5세단위)  \
# count  1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean      2011.0   500000.500000        1.453735        6.129215
# std          0.0   288675.278933        0.497855        2.787610
# min       2011.0        1.000000        1.000000        1.000000
# 25%       2011.0   250000.750000        1.000000        4.000000
# 50%       2011.0   500000.500000        1.000000        6.000000
# 75%       2011.0   750000.250000        2.000000        8.000000
# max       2011.0  1000000.000000        2.000000       14.000000
#
#                  시도코드       신장(5Cm단위)      체중(5Kg 단위)            허리둘레  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        33.428904      162.127850       62.198390       80.245373
# std         12.861787        9.270571       11.683187        9.048950
# min         11.000000      125.000000       25.000000       51.000000
# 25%         26.000000      155.000000       55.000000       74.000000
# 50%         41.000000      160.000000       60.000000       80.000000
# 75%         44.000000      170.000000       70.000000       86.000000
# max         49.000000      190.000000      125.000000      128.000000
#
#                시력(좌)          시력(우)  ...             혈색소            요단백  \
# count  999907.000000  999897.000000  ...  1000000.000000  995622.000000
# mean        0.982922       0.981011  ...       14.024697       1.072831
# std         0.623759       0.620927  ...        1.613644       0.390740
# min         0.100000       0.100000  ...        0.400000       1.000000
# 25%         0.700000       0.700000  ...       12.900000       1.000000
# 50%         1.000000       1.000000  ...       14.000000       1.000000
# 75%         1.200000       1.200000  ...       15.200000       1.000000
# max         9.900000       9.900000  ...       24.900000       6.000000
#
#               혈청크레아티닌      (혈청지오티)AST      (혈청지오티)ALT           감마지티피  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.996575       25.171788       24.832292       36.455872
# std          1.072771       15.346525       21.225311       48.574831
# min          0.100000        1.000000        1.000000        1.000000
# 25%          0.800000       19.000000       14.000000       15.000000
# 50%          0.900000       22.000000       20.000000       23.000000
# 75%          1.000000       28.000000       28.000000       39.000000
# max         98.000000      999.000000      999.000000      999.000000
#
#                 흡연상태           음주여부       구강검진 수검여부     데이터공개일자
# count  999841.000000  999785.000000  1000000.000000   1000000.0
# mean        1.657889       0.488976        0.366836  20151220.0
# std         0.854650       0.499879        0.481941         0.0
# min         1.000000       0.000000        0.000000  20151220.0
# 25%         1.000000       0.000000        0.000000  20151220.0
# 50%         1.000000       0.000000        0.000000  20151220.0
# 75%         3.000000       1.000000        1.000000  20151220.0
# max         3.000000       1.000000        1.000000  20151220.0
#
# [8 rows x 29 columns]

# %%
GJ_2011=GJ_2011.drop(['기준년도','데이터공개일자'],axis=1)

# 영-분산을 가지는 2개의 변수를 제거

# %%
GJ_2011.shape # 2개의 변수가 제거됨
# Out:
# (1000000, 27)

# %%
GJ_2011
# Out:
#         가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0        762544     2            1    47        145          40    66    1.2
# 1         56745     2            1    26        145          45    68    0.9
# 2        171067     2            1    26        145          45    65    1.0
# 3        196496     2            1    27        145          45    68    0.9
# 4        812525     2            1    46        150          35    56    0.7
# 5        270309     2            1    26        150          35    58    1.0
# 6         78048     2            1    47        150          35    62    1.2
# 7        707680     2            1    26        150          40    58    0.7
# 8        658822     2            1    31        150          40    66    0.9
# 9         10872     2            1    45        150          40    62    0.6
# 10       998292     2            1    41        150          40    58    1.2
# 11        10175     2            1    44        150          40    70    1.0
# 12       125464     2            1    44        150          40    62    1.5
# 13       822803     2            1    44        150          40    62    0.2
# 14       618200     2            1    29        150          40    79    1.2
# 15       997524     2            1    44        150          40    65    1.5
# 16        82740     2            1    44        150          40    61    1.5
# 17         3452     2            1    26        150          40    63    0.5
# 18       955136     2            1    41        150          40    60    0.6
# 19       885481     2            1    41        150          40    62    1.0
# 20       108258     2            1    41        150          40    59    0.8
# 21       864550     2            1    43        150          40    73    1.2
# 22       884881     2            1    41        150          40    58    0.7
# 23        49579     2            1    11        150          40    60    1.0
# 24        85033     2            1    44        150          40    56    0.3
# 25       107750     2            1    44        150          40    63    0.9
# 26       186044     2            1    44        150          40    62    0.4
# 27       421722     2            1    41        150          40    58    1.0
# 28        72654     2            1    27        150          40    61    0.9
# 29       232570     2            1    47        150          40    56    0.9
# ...         ...   ...          ...   ...        ...         ...   ...    ...
# 999970   759694     2           14    47        135          30    81    1.0
# 999971   830395     2           14    44        135          35    72    0.2
# 999972   817405     2           14    45        135          40    80    0.3
# 999973   137803     2           14    42        135          40    84    0.4
# 999974   220900     2           14    45        135          40    68    0.2
# 999975   139962     1           14    43        140          30    84    9.9
# 999976   502017     2           14    29        140          30    77    0.5
# 999977   135690     2           14    42        140          30    71    0.1
# 999978   241390     2           14    11        140          30    64    0.2
# 999979   439901     2           14    43        140          35    78    0.2
# 999980   431792     2           14    43        140          35    71    0.2
# 999981   394477     2           14    44        140          35    70    0.1
# 999982   561236     2           14    11        140          35    60    0.2
# 999983   326950     2           14    48        140          35    81    0.3
# 999984   164194     2           14    46        140          40    60    0.1
# 999985    50890     2           14    11        145          35    64    0.2
# 999986   266398     2           14    26        145          40    79    0.2
# 999987   421168     2           14    11        150          35    64    0.1
# 999988   149551     2           14    44        150          35    56    0.1
# 999989   348568     2           14    46        150          45    73    0.5
# 999990   470875     2           14    27        150          50    84    0.2
# 999991   977368     2           14    41        150          50    80    0.3
# 999992   279066     2           14    47        150          50    89    0.4
# 999993   379803     1           14    45        155          50    82    0.4
# 999994   383245     2           14    45        130          30    79    0.6
# 999995   247844     2           14    46        130          30    60    0.1
# 999996   192212     2           14    49        130          30    63    0.1
# 999997   521995     2           14    44        140          30    74    0.1
# 999998   326659     2           14    41        140          40    68    0.1
# 999999   978435     1           14    45        150          40    74    0.2
#
#         시력(우)  청력(좌)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0         1.2    1.0  ...     135.0  12.4  1.0      0.7          13
# 1         1.0    1.0  ...      81.0  13.6  1.0      0.8          17
# 2         1.5    1.0  ...      74.0  14.3  1.0      0.9          35
# 3         0.9    1.0  ...     117.0  13.4  1.0      0.7          16
# 4         0.9    1.0  ...      78.0  13.1  1.0      0.5          23
# 5         1.2    1.0  ...      89.0  12.2  1.0      0.8          19
# 6         1.0    1.0  ...      93.0  13.0  1.0      0.7          18
# 7         0.8    1.0  ...     126.0  14.2  1.0      0.8          20
# 8         1.2    1.0  ...      97.0  13.1  1.0      0.8          16
# 9         0.9    1.0  ...      78.0  13.2  1.0      0.6          17
# 10        2.0    1.0  ...     118.0  12.7  1.0      0.7          18
# 11        1.0    1.0  ...     159.0  13.4  1.0      0.7          19
# 12        1.5    1.0  ...      99.0  14.2  1.0      0.7          19
# 13        0.3    1.0  ...      85.0  13.7  1.0      0.7          15
# 14        1.2    1.0  ...      71.0  14.2  1.0      0.7          17
# 15        1.2    1.0  ...      61.0  14.1  1.0      0.7          15
# 16        1.5    1.0  ...      83.0  13.1  1.0      0.8          16
# 17        0.4    1.0  ...     102.0  13.2  1.0      0.7          12
# 18        0.6    1.0  ...      73.0  13.3  1.0      0.8          15
# 19        0.9    1.0  ...      57.0  13.3  1.0      0.6          31
# 20        0.7    1.0  ...      98.0  13.8  1.0      0.8          19
# 21        1.2    1.0  ...     130.0  13.8  1.0      0.7          16
# 22        0.7    1.0  ...      78.0  13.6  2.0      0.7          17
# 23        0.6    1.0  ...     129.0  10.9  1.0      0.9          15
# 24        0.5    1.0  ...     119.0  13.5  1.0      0.9          20
# 25        0.9    1.0  ...      83.0  13.6  1.0      0.5          23
# 26        0.2    1.0  ...      87.0  12.6  1.0      0.8          23
# 27        1.2    1.0  ...      98.0  11.9  1.0      0.6          19
# 28        0.7    1.0  ...      99.0  13.8  1.0      0.7          11
# 29        1.0    1.0  ...     109.0  13.4  1.0      0.7          19
# ...       ...    ...  ...       ...   ...  ...      ...         ...
# 999970    1.0    1.0  ...      70.0  12.4  NaN      0.5          18
# 999971    0.1    1.0  ...      88.0   9.1  1.0      0.8          18
# 999972    9.9    2.0  ...      77.0  12.3  1.0      0.7          34
# 999973    0.1    1.0  ...      96.0   7.5  1.0      1.1          16
# 999974    0.3    1.0  ...     186.0  10.6  NaN      0.7          17
# 999975    9.9    1.0  ...     126.0  14.0  1.0      1.0          27
# 999976    0.4    1.0  ...     132.0   7.0  1.0      0.7          19
# 999977    0.1    2.0  ...      79.0  10.2  1.0      0.6          23
# 999978    0.3    1.0  ...      78.0  10.3  1.0      1.0          19
# 999979    0.3    1.0  ...      86.0  13.1  1.0      0.4          20
# 999980    0.2    2.0  ...      93.0  12.1  1.0      0.9          30
# 999981    0.2    1.0  ...     115.0  10.1  1.0      0.8          16
# 999982    0.2    1.0  ...      92.0  10.6  1.0      8.1          19
# 999983    0.3    1.0  ...      42.0  11.8  1.0      0.6          16
# 999984    0.1    1.0  ...     168.0  10.4  1.0      1.6          21
# 999985    0.3    2.0  ...     107.0   8.6  1.0      1.0          28
# 999986    0.1    1.0  ...     120.0   8.0  1.0      0.9          13
# 999987    0.1    1.0  ...     102.0  11.1  3.0      0.6          16
# 999988    0.1    2.0  ...      80.0  11.7  1.0      0.8          22
# 999989    0.5    1.0  ...     101.0  11.9  NaN      0.8          23
# 999990    0.2    1.0  ...      44.0   9.6  1.0      1.7          18
# 999991    0.4    1.0  ...      93.0  14.5  1.0      1.0          26
# 999992    0.4    1.0  ...     193.0  13.0  1.0      0.7          18
# 999993    0.4    1.0  ...      63.0   9.2  3.0      1.6          23
# 999994    1.0    1.0  ...      91.0  12.0  1.0      0.5          32
# 999995    0.1    1.0  ...      92.0  10.9  1.0      0.9          25
# 999996    0.2    2.0  ...     106.0  12.4  NaN      0.6          21
# 999997    0.1    2.0  ...     132.0  11.4  1.0      0.9          40
# 999998    0.1    1.0  ...      97.0  10.9  1.0      0.7          23
# 999999    0.2    1.0  ...      63.0  14.3  1.0      1.3          29
#
#         (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부
# 0               11     13   1.0   1.0          1
# 1               14     12   1.0   0.0          0
# 2               26     16   1.0   0.0          0
# 3               12     23   1.0   0.0          1
# 4               16      8   1.0   0.0          0
# 5               10     15   1.0   0.0          0
# 6               11     13   1.0   0.0          1
# 7               10     19   1.0   0.0          0
# 8               13      8   1.0   0.0          0
# 9               14     13   1.0   0.0          0
# 10               9      8   1.0   0.0          0
# 11              19     17   1.0   0.0          1
# 12               9      9   1.0   0.0          1
# 13               9      8   1.0   0.0          1
# 14               7     15   1.0   0.0          1
# 15               9      9   1.0   0.0          0
# 16               7     12   1.0   0.0          1
# 17               8     11   1.0   0.0          1
# 18              12     10   1.0   0.0          0
# 19              20     20   1.0   0.0          1
# 20              13     18   1.0   0.0          0
# 21              11     17   1.0   0.0          1
# 22               6     11   1.0   0.0          1
# 23              10     10   1.0   0.0          0
# 24              14     10   1.0   0.0          1
# 25              14     22   1.0   1.0          1
# 26              14     17   1.0   1.0          1
# 27              13     10   1.0   1.0          0
# 28              12     19   1.0   1.0          0
# 29              12     16   1.0   1.0          1
# ...            ...    ...   ...   ...        ...
# 999970          12     35   1.0   0.0          0
# 999971           8      5   1.0   0.0          0
# 999972          36     71   1.0   0.0          0
# 999973           6     13   1.0   0.0          1
# 999974          10     16   1.0   0.0          0
# 999975          15     69   1.0   0.0          0
# 999976          13     15   1.0   0.0          0
# 999977          12      9   1.0   0.0          0
# 999978           7     13   1.0   0.0          0
# 999979           6     14   1.0   0.0          0
# 999980          16      5   1.0   0.0          0
# 999981           9     23   1.0   0.0          0
# 999982          15     23   1.0   0.0          0
# 999983           5      9   1.0   0.0          0
# 999984          13     26   1.0   0.0          0
# 999985          16     25   1.0   0.0          1
# 999986           9     12   1.0   0.0          0
# 999987           6     20   1.0   0.0          0
# 999988          11      7   1.0   0.0          0
# 999989           7      9   1.0   0.0          0
# 999990          13     35   1.0   0.0          0
# 999991          10     19   1.0   0.0          0
# 999992          21     34   1.0   0.0          0
# 999993          14     38   1.0   0.0          0
# 999994          11     10   1.0   0.0          0
# 999995          15     14   1.0   0.0          0
# 999996          19     22   1.0   0.0          0
# 999997          16     15   1.0   0.0          0
# 999998          12     29   1.0   0.0          0
# 999999          13     12   1.0   0.0          0
#
# [1000000 rows x 27 columns]

# %%
GJ_2011=GJ_2011.drop(['가입자일련번호'],axis=1)

# 편의상 가입자일련번호 변수 제거

# %%
GJ_2011.shape # 1개의 변수가 제거됨
# Out:
# (1000000, 26)

# %%
GJ_2011.isna().sum()

# 결측치가 있는 변수 : 시력좌/시력우/청력좌/청력우/LDL/요단백/흡연상태/음주여부
# Out:
# 성별코드               0
# 연령대코드(5세단위)        0
# 시도코드               0
# 신장(5Cm단위)          0
# 체중(5Kg 단위)         0
# 허리둘레               0
# 시력(좌)             93
# 시력(우)            103
# 청력(좌)            118
# 청력(우)            121
# 수축기혈압              0
# 이완기혈압              0
# 식전혈당(공복혈당)         0
# 총콜레스테롤             0
# 트리글리세라이드           0
# HDL콜레스테롤           0
# LDL콜레스테롤       10013
# 혈색소                0
# 요단백             4378
# 혈청크레아티닌            0
# (혈청지오티)AST         0
# (혈청지오티)ALT         0
# 감마지티피              0
# 흡연상태             159
# 음주여부             215
# 구강검진 수검여부          0
# dtype: int64

# %%
fill_mean_func = lambda g: g.fillna(g.mean())
GJ_2011=GJ_2011.groupby(['성별코드','연령대코드(5세단위)','시도코드']).apply(fill_mean_func)

# sex, age, sido 그룹별로 결측값 평균치 대체
# mean, median, mode 중 UE(비편향) 성질을 만족하는 평균값으로 대체
# 각 변수별로 이상치가 많으나, 데이터의 갯수가 충분히 확보(100만개)된 상태이므로, mean 사용
# 전반적으로 히스토그램이 우측 긴 꼬리의 형태를 나타내고 있으므로, 평균 > 중앙값 > 최빈값 순서를 따름
# https://rfriend.tistory.com/402 : 결측값을 그룹 평균값으로 채우기 (Fill missing values by Group means)
# 출처: https://rfriend.tistory.com/402 [R, Python 분석과 프로그래밍 (by R Friend)]

# %%
GJ_2011=GJ_2011.drop(['성별코드','연령대코드(5세단위)','시도코드'], axis=1)

# %%
GJ_2011.reset_index(inplace=True)

# 인덱스 초기화
# inplace=True : 객체 반환 x(결과물 안보이게 하기)
# https://nittaku.tistory.com/122

# %%
del GJ_2011['level_3']

# del health['변수명'] : 특정 변수 제거

# %%
GJ_2011.head()
# Out:
#    성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0     1            1    11        160          60    81    0.9    0.9    1.0
# 1     1            1    11        160          60    74    1.2    1.2    1.0
# 2     1            1    11        165          45    63    0.8    0.4    1.0
# 3     1            1    11        165          50    63    0.6    0.6    1.0
# 4     1            1    11        165          50    70    0.7    0.8    2.0
#
#    청력(우)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  \
# 0    1.0  ...     107.0  15.8  1.0      1.0          23          31     47
# 1    1.0  ...     114.0  15.1  1.0      1.0          14          14     17
# 2    1.0  ...      96.0  14.2  1.0      1.0          23          14     24
# 3    1.0  ...      61.0  15.7  1.0      0.8          20          13     17
# 4    2.0  ...      69.0  16.6  1.0      0.9          21          18     34
#
#    흡연상태  음주여부  구강검진 수검여부
# 0   1.0   1.0          0
# 1   3.0   0.0          0
# 2   3.0   0.0          1
# 3   3.0   1.0          0
# 4   3.0   1.0          0
#
# [5 rows x 26 columns]

# %%
GJ_2011.shape
# Out:
# (1000000, 26)

# %%
GJ_2011.describe()
# Out:
#                  성별코드     연령대코드(5세단위)            시도코드       신장(5Cm단위)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.453735        6.129215       33.428904      162.127850
# std          0.497855        2.787610       12.861787        9.270571
# min          1.000000        1.000000       11.000000      125.000000
# 25%          1.000000        4.000000       26.000000      155.000000
# 50%          1.000000        6.000000       41.000000      160.000000
# 75%          2.000000        8.000000       44.000000      170.000000
# max          2.000000       14.000000       49.000000      190.000000
#
#            체중(5Kg 단위)            허리둘레           시력(좌)           시력(우)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        62.198390       80.245373        0.982913        0.981002
# std         11.683187        9.048950        0.623734        0.620898
# min         25.000000       51.000000        0.100000        0.100000
# 25%         55.000000       74.000000        0.700000        0.700000
# 50%         60.000000       80.000000        1.000000        1.000000
# 75%         70.000000       86.000000        1.200000        1.200000
# max        125.000000      128.000000        9.900000        9.900000
#
#                 청력(좌)           청력(우)  ...        LDL콜레스테롤             혈색소  \
# count  1000000.000000  1000000.000000  ...  1000000.000000  1000000.000000
# mean         1.024999        1.023556  ...      113.662989       14.024697
# std          0.156102        0.151641  ...       41.133481        1.613644
# min          1.000000        1.000000  ...        0.000000        0.400000
# 25%          1.000000        1.000000  ...       91.000000       12.900000
# 50%          1.000000        1.000000  ...      111.000000       14.000000
# 75%          1.000000        1.000000  ...      133.000000       15.200000
# max          2.000000        2.000000  ...     2107.000000       24.900000
#
#                   요단백         혈청크레아티닌      (혈청지오티)AST      (혈청지오티)ALT  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.072898        0.996575       25.171788       24.832292
# std          0.389894        1.072771       15.346525       21.225311
# min          1.000000        0.100000        1.000000        1.000000
# 25%          1.000000        0.800000       19.000000       14.000000
# 50%          1.000000        0.900000       22.000000       20.000000
# 75%          1.000000        1.000000       28.000000       28.000000
# max          6.000000       98.000000      999.000000      999.000000
#
#                 감마지티피            흡연상태            음주여부       구강검진 수검여부
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        36.455872        1.657852        0.488954        0.366836
# std         48.574831        0.854611        0.499840        0.481941
# min          1.000000        1.000000        0.000000        0.000000
# 25%         15.000000        1.000000        0.000000        0.000000
# 50%         23.000000        1.000000        0.000000        0.000000
# 75%         39.000000        3.000000        1.000000        1.000000
# max        999.000000        3.000000        1.000000        1.000000
#
# [8 rows x 26 columns]

# %%
GJ_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
# 성별코드           1000000 non-null int64
# 연령대코드(5세단위)    1000000 non-null int64
# 시도코드           1000000 non-null int64
# 신장(5Cm단위)      1000000 non-null int64
# 체중(5Kg 단위)     1000000 non-null int64
# 허리둘레           1000000 non-null int64
# 시력(좌)          1000000 non-null float64
# 시력(우)          1000000 non-null float64
# 청력(좌)          1000000 non-null float64
# 청력(우)          1000000 non-null float64
# 수축기혈압          1000000 non-null int64
# 이완기혈압          1000000 non-null int64
# 식전혈당(공복혈당)     1000000 non-null int64
# 총콜레스테롤         1000000 non-null int64
# 트리글리세라이드       1000000 non-null int64
# HDL콜레스테롤       1000000 non-null float64
# LDL콜레스테롤       1000000 non-null float64
# 혈색소            1000000 non-null float64
# 요단백            1000000 non-null float64
# 혈청크레아티닌        1000000 non-null float64
# (혈청지오티)AST     1000000 non-null int64
# (혈청지오티)ALT     1000000 non-null int64
# 감마지티피          1000000 non-null int64
# 흡연상태           1000000 non-null float64
# 음주여부           1000000 non-null float64
# 구강검진 수검여부      1000000 non-null int64
# dtypes: float64(11), int64(15)
# memory usage: 198.4 MB

# %%
GJ_2011 = GJ_2011.rename(columns = {'성별코드' : 'sex',
                    '연령대코드(5세단위)' : 'year',
                    '시도코드' : 'sido',
                    '신장(5Cm단위)' : 'height',
                    '체중(5Kg 단위)' : 'weight',
                    '허리둘레' : 'waist',
                    '시력(좌)' : 'sight_left',
                    '시력(우)' : 'sight_right',
                    '청력(좌)' : 'hearing_left',
                    '청력(우)' : 'hearing_right',
                    '수축기혈압' : 'SBP',
                    '이완기혈압' : 'RPBP',
                    '식전혈당(공복혈당)' : 'pred_blood_sugar',
                    '총콜레스테롤' : 'cholesterol',
                    '트리글리세라이드' : 'triglycerides',
                    'HDL콜레스테롤' : 'HDL',
                    'LDL콜레스테롤' : 'LDL',
                    '혈색소' : 'blood_pigment',
                    '요단백' : 'urine_protein',
                    '혈청크레아티닌' : 'serum_creatinine',
                    '(혈청지오티)AST' : 'AST',
                    '(혈청지오티)ALT' : 'ALT',
                    '감마지티피' : 'gamma_gtp',
                    '흡연상태' : 'smoking',
                    '음주여부' : 'alcohol',
                    '구강검진 수검여부' : 'oral_inspection'})

# 시각화에서 변수명 출력을 위해 영어로 변경

# %%
GJ_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
# sex                 1000000 non-null int64
# year                1000000 non-null int64
# sido                1000000 non-null int64
# height              1000000 non-null int64
# weight              1000000 non-null int64
# waist               1000000 non-null int64
# sight_left          1000000 non-null float64
# sight_right         1000000 non-null float64
# hearing_left        1000000 non-null float64
# hearing_right       1000000 non-null float64
# SBP                 1000000 non-null int64
# RPBP                1000000 non-null int64
# pred_blood_sugar    1000000 non-null int64
# cholesterol         1000000 non-null int64
# triglycerides       1000000 non-null int64
# HDL                 1000000 non-null float64
# LDL                 1000000 non-null float64
# blood_pigment       1000000 non-null float64
# urine_protein       1000000 non-null float64
# serum_creatinine    1000000 non-null float64
# AST                 1000000 non-null int64
# ALT                 1000000 non-null int64
# gamma_gtp           1000000 non-null int64
# smoking             1000000 non-null float64
# alcohol             1000000 non-null float64
# oral_inspection     1000000 non-null int64
# dtypes: float64(11), int64(15)
# memory usage: 198.4 MB

# %%
import matplotlib
import matplotlib.pyplot as plt

# 데이터 탐색을 위한 시각화 패키지 장착

# %%
plt.hist(GJ_2011['height'], histtype='bar', rwidth=0.9)
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
plt.boxplot(GJ_2011['height'])
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# %%
GJ_2011['pred_blood_sugar'] = np.where(GJ_2011['pred_blood_sugar'] >= 126, 1, 0)

# target 변수인 pred_blood_sugar가 126 이상일 때, 당뇨진단으로 판정
# 이분형 자료로 변환
# https://rfriend.tistory.com/tag/Python

# %%
GJ_2011['pred_blood_sugar'].value_counts()

# 당뇨진단자 비율 : 약 7%
# Out:
# 0    938114
# 1     61886
# Name: pred_blood_sugar, dtype: int64

# %% [markdown]
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
GJ_2011.hist(bins=50, figsize=(20,15))
plt.show()



# ALT / AST / HDL / LDL / RPBP / SBP / cholesterol / gamma_gtp / height / serum_creatinine / sight_left / sight_right -> skwed distribution
# triglycerides / urine_protein / waist / weight -> skwed distribution
# blood_pigment -> normal distribution
# alcohol / oral_inspection -> 이산형, 비교적 고른 분포
# hearing_left / hearing_right / smoking / pred_blood_sugar -> class unbalance
# sex / year / sido -> groupby 기준변수

# %%
GJ_2011.boxplot(figsize=(30,15))
plt.show()

# %% [markdown]
# # 이상치 처리
# 일반적으로 1) 표준점수로 변환 후 -3 이하 및 +3 제거 2) IQR 방식 3) 도메인 지식 이용하거나 Binning 처리하는 방식이 이용된다.
#
# 표준점수 이용할 경우 평균이 0, 표준편차가 1인 분포로 변환한후 +3 이상이거나 -3 이하인 경우 극단치로 처리한다.
#
# IQR 방식은 75% percentile * 1.5 이상이거나 25 percentile* 1.5 이하인 경우 극단치로 처리하는 방식이다.
# 이해하기 쉽고 적용하기 쉬운 편이지만, 경우에 따라 너무 많은 사례들이 극단치로 고려되는 경우가 있다.
#
# https://wikidocs.net/16582
#
# ![image.png](attachment:image.png)
#
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 3)
    upper_bound = quartile_3 + (iqr * 3)
    return np.where((ys > upper_bound) | (ys < lower_bound))

# %%
print(np.array(outliers_iqr(GJ_2011['height'])).shape[1],
      np.array(outliers_iqr(GJ_2011['weight'])).shape[1],
      np.array(outliers_iqr(GJ_2011['waist'])).shape[1],
      np.array(outliers_iqr(GJ_2011['sight_left'])).shape[1],
      np.array(outliers_iqr(GJ_2011['sight_right'])).shape[1],
      np.array(outliers_iqr(GJ_2011['SBP'])).shape[1],
      np.array(outliers_iqr(GJ_2011['RPBP'])).shape[1],
      np.array(outliers_iqr(GJ_2011['pred_blood_sugar'])).shape[1],
      np.array(outliers_iqr(GJ_2011['cholesterol'])).shape[1],
      np.array(outliers_iqr(GJ_2011['triglycerides'])).shape[1],
      np.array(outliers_iqr(GJ_2011['HDL'])).shape[1],
      np.array(outliers_iqr(GJ_2011['LDL'])).shape[1],
      np.array(outliers_iqr(GJ_2011['blood_pigment'])).shape[1],
      np.array(outliers_iqr(GJ_2011['serum_creatinine'])).shape[1],
      np.array(outliers_iqr(GJ_2011['AST'])).shape[1],
      np.array(outliers_iqr(GJ_2011['ALT'])).shape[1],
      np.array(outliers_iqr(GJ_2011['gamma_gtp'])).shape[1])

# Outer fence(바깥 울타리) 기준 심각한 이상치는 최소 15개를 가진 변수부터 최대 43296개를 가진 변수까지 있음
# gamma_gtp 변수의 OF 기준 이상치 제거할 경우, 데이터 손실율 약 4.3%
# 특정 연령, 성별, 시/도에 해당하는 범주의 경우, 이상치 비율이 많을 경우 문제 발생
# 이상치 제거 방법으로 IQR 정보를 이용하는 것이 바람직하지 않을 수 있음
# Out:
# 0 40 15 3277 3245 566 2124 61886 560 16955 1383 1131 195 17685 22727 27141 43296

# %% [markdown]
# 데이터 단위 변환
# 데이터의 스케일(측정단위)이 다를 경우 특히 거리를 기반으로 분류하는 모델(KNN 등)에 부정적인 영향을 미치므로, 스케일링을 통해 단위를 일정하게 맞추는 작업을 진행해야 한다. 아래 방식이 주로 스케일링을 위해 쓰이는 방법이다. 대부분의 통계 분석 방법이 정규성 가정을 기반으로 하므로 완벽하지 않더라도 최대한 정규분포로 변환하는 노력이 필요하다.
#
# Scaling: 평균이 0, 분산이 1인 분포로 변환
# MinMax Scaling: 특정 범위 (예, 0~1)로 모든 데이터를 변환
# Box-Cox: 여러 k 값중 가장 작은 SSE 선택
# Robust_scale: median, interquartile range 사용(outlier 영향 최소화)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# http://ko.logpresso.com/documents/anomaly-detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clf = IsolationForest(max_samples=1000, random_state=1, contamination=0.01, max_features=2)
# Isolation Forest 방법을 사용하기 위해, 변수로 선언을 해 준다.
# n_estimators=100 : 학습모형 100개
# max_samples=100 : 모형 당 최대 아웃라이어 갯수 1000개
# contamination='legacy' : 아웃라이어 비율 : 0.01(10000개)
# max_features=2 : 각 학습모형이 2개의 변수로 학습됨
# bootstrap=False : 각 학습모형이 샘플을 비복원 추출함
clf.fit(GJ_2011)
# fit 함수를 이용하여, 데이터셋을 학습
y_pred_outliers = clf.predict(GJ_2011)
# predict 함수를 이용하여, outlier를 판별. 0과 1로 이루어진 Series형태의 데이터가 나옴

out = pd.DataFrame(y_pred_outliers)
out = out.rename(columns={0: "out"})
GJ_2011 = pd.concat([GJ_2011, out], 1)
# 원래의 dataframe에 붙이기. 데이터가 0인 것이 outlier이기 때문에, 0인 것을 제거하면 outlier가 제거된 dataframe을 얻을 수 있음

# https://mkjjo.github.io/python/2019/01/10/outlier.html
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html
# Out:
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
GJ_2011['out'].value_counts()

# 10000개의 이상치를 detecting(label : -1)
# Out:
#  1    990000
# -1     10000
# Name: out, dtype: int64

# %%
GJ_2011=GJ_2011[GJ_2011['out']==1]

# %%
GJ_2011.boxplot(figsize=(30,15))
plt.show()

# %%
del GJ_2011['out']

# %%
GJ_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 990000 entries, 0 to 999997
# Data columns (total 26 columns):
# sex                 990000 non-null int64
# year                990000 non-null int64
# sido                990000 non-null int64
# height              990000 non-null int64
# weight              990000 non-null int64
# waist               990000 non-null int64
# sight_left          990000 non-null float64
# sight_right         990000 non-null float64
# hearing_left        990000 non-null float64
# hearing_right       990000 non-null float64
# SBP                 990000 non-null int64
# RPBP                990000 non-null int64
# pred_blood_sugar    990000 non-null int32
# cholesterol         990000 non-null int64
# triglycerides       990000 non-null int64
# HDL                 990000 non-null float64
# LDL                 990000 non-null float64
# blood_pigment       990000 non-null float64
# urine_protein       990000 non-null float64
# serum_creatinine    990000 non-null float64
# AST                 990000 non-null int64
# ALT                 990000 non-null int64
# gamma_gtp           990000 non-null int64
# smoking             990000 non-null float64
# alcohol             990000 non-null float64
# oral_inspection     990000 non-null int64
# dtypes: float64(11), int32(1), int64(14)
# memory usage: 200.2 MB

# %%
GJ_2011 = GJ_2011.rename(columns = {'height' : 'height_2011',
                    'weight' : 'weight_2011',
                    'waist' : 'waist_2011',
                    'sight_left' : 'sight_left_2011',
                    'sight_right' : 'sight_right_2011',
                    'hearing_left' : 'hearing_left_2011',
                    'hearing_right' : 'hearing_right_2011',
                    'SBP' : 'SBP_2011',
                    'RPBP' : 'RPBP_2011',
                    'cholesterol' : 'cholesterol_2011',
                    'triglycerides' : 'triglycerides_2011',
                    'HDL' : 'HDL_2011',
                    'LDL' : 'LDL_2011',
                    'blood_pigment' : 'blood_pigment_2011',
                    'urine_protein' : 'urine_protein_2011',
                    'serum_creatinine' : 'serum_creatinine_2011',
                    'AST' : 'AST_2011',
                    'ALT' : 'ALT_2011',
                    'gamma_gtp' : 'gamma_gtp_2011',
                    'smoking' : 'smoking_2011',
                    'alcohol' : 'alcohol_2011',
                    'oral_inspection' : 'oral_inspection_2011'})

# 2017년도 건강검진정보 예측변수(22개) rename

# %%
GJ_2011['target'] = GJ_2011['pred_blood_sugar']

# %%
del GJ_2011['pred_blood_sugar']

# %%
plt.hist(GJ_2011['target'], histtype='bar', rwidth=0.9)
plt.xlabel('pre_blood_sugar')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
GJ_2011_group = GJ_2011.groupby(['sex','year','sido']).mean()

# 시/도 그룹별 평균치를 저장

# %%
GJ_2011_group.reset_index(inplace=True)

# %%
GJ_2011_group

# 448개 범주를 가지는 자료형태로 변환
# dimension : 448x26
# Out:
#      sex  year  sido  height_2011  weight_2011  waist_2011  sight_left_2011  \
# 0      1     1    11   172.153061    67.765306   78.246939         1.049592
# 1      1     1    26   171.636661    67.553191   78.328969         1.036661
# 2      1     1    27   171.421663    66.856867   78.257253         1.083946
# 3      1     1    28   171.328790    68.100511   78.429302         1.097104
# 4      1     1    29   171.226415    66.471698   77.690566         1.129057
# 5      1     1    30   171.990950    68.280543   78.031674         1.052941
# 6      1     1    31   171.921488    68.863636   79.280992         1.090909
# 7      1     1    41   171.198646    66.462754   77.645598         1.135079
# 8      1     1    42   172.125280    69.407159   78.675615         1.164206
# 9      1     1    43   171.065760    65.963719   77.142857         1.186848
# 10     1     1    44   171.068702    66.479008   77.835878         1.181870
# 11     1     1    45   171.313776    66.607143   77.775510         1.137245
# 12     1     1    46   171.498316    66.548822   77.740741         1.156566
# 13     1     1    47   171.228758    66.745098   77.707190         1.121307
# 14     1     1    48   170.646095    65.675024   77.192864         1.142719
# 15     1     1    49   171.086957    67.898551   79.347826         1.249275
# 16     1     2    11   172.899272    70.992595   81.385548         1.087817
# 17     1     2    26   172.118201    70.627615   81.236053         1.093061
# 18     1     2    27   172.286902    70.901767   81.372141         1.082692
# 19     1     2    28   172.455288    70.995334   81.494946         1.099456
# 20     1     2    29   171.975806    69.905914   80.785842         1.147849
# 21     1     2    30   172.443420    70.435876   81.133277         1.132775
# 22     1     2    31   172.087866    70.146444   80.749791         1.052301
# 23     1     2    41   172.056705    70.278445   81.040266         1.122359
# 24     1     2    42   172.486445    71.452363   81.102246         1.147792
# 25     1     2    43   171.953757    69.193642   80.255491         1.134451
# 26     1     2    44   171.482085    69.387215   80.883143         1.193445
# 27     1     2    45   171.924867    69.295213   80.079787         1.179654
# 28     1     2    46   171.692745    69.637269   80.753201         1.147226
# 29     1     2    47   171.551355    69.575606   80.714693         1.127996
# ..   ...   ...   ...          ...          ...         ...              ...
# 418    2    13    27   146.929825    49.181287   80.555556         0.514035
# 419    2    13    28   146.358382    50.664740   82.612717         0.618497
# 420    2    13    29   146.614173    49.921260   82.070866         0.573228
# 421    2    13    30   146.124031    49.147287   81.534884         0.652713
# 422    2    13    31   146.320755    48.584906   80.132075         0.516981
# 423    2    13    41   146.631382    50.367372   82.247821         0.654421
# 424    2    13    42   145.466102    50.190678   82.139831         0.514407
# 425    2    13    43   144.708520    47.869955   81.156951         0.665022
# 426    2    13    44   145.453297    47.774725   80.445055         0.582692
# 427    2    13    45   144.667674    47.432024   79.093656         0.571299
# 428    2    13    46   146.235566    48.452656   80.651270         0.496305
# 429    2    13    47   145.708583    47.514970   79.634731         0.527545
# 430    2    13    48   146.401985    47.444169   79.171216         0.597767
# 431    2    13    49   146.250000    51.736111   82.041667         0.470833
# 432    2    14    11   145.967742    48.225806   81.306452         0.704839
# 433    2    14    26   146.607143    49.285714   80.982143         0.437500
# 434    2    14    27   145.000000    44.666667   75.566667         0.453333
# 435    2    14    28   146.125000    49.500000   81.825000         0.407500
# 436    2    14    29   146.200000    48.400000   82.640000         0.464222
# 437    2    14    30   146.578947    45.789474   81.894737         0.382852
# 438    2    14    31   143.888889    47.222222   81.444444         0.477778
# 439    2    14    41   146.111111    46.274510   79.607843         0.492157
# 440    2    14    42   144.553571    46.517857   80.821429         0.351786
# 441    2    14    43   144.117647    45.735294   80.029412         0.673529
# 442    2    14    44   145.129870    44.870130   78.129870         0.472171
# 443    2    14    45   143.897059    45.073529   76.617647         0.388235
# 444    2    14    46   145.000000    46.358025   77.580247         0.372840
# 445    2    14    47   145.478723    45.212766   78.489362         0.491813
# 446    2    14    48   145.466667    45.533333   79.640000         0.400000
# 447    2    14    49   145.000000    45.833333   81.500000         0.322222
#
#      sight_right_2011  hearing_left_2011  hearing_right_2011  ...  \
# 0            1.074694           1.003061            1.002041  ...
# 1            1.043208           1.009820            1.008183  ...
# 2            1.100580           1.005803            1.001934  ...
# 3            1.083816           1.001704            1.011925  ...
# 4            1.078491           1.007576            1.011364  ...
# 5            1.048869           1.000000            1.000000  ...
# 6            1.116529           1.000000            1.004132  ...
# 7            1.120361           1.004063            1.004063  ...
# 8            1.169128           1.000000            1.000000  ...
# 9            1.140590           1.006803            1.006803  ...
# 10           1.170611           1.003817            1.001908  ...
# 11           1.139031           1.002551            1.005102  ...
# 12           1.139731           1.006734            1.003367  ...
# 13           1.139216           1.013072            1.006536  ...
# 14           1.134619           1.005786            1.006750  ...
# 15           1.273913           1.000000            1.000000  ...
# 16           1.080066           1.003064            1.002553  ...
# 17           1.083054           1.005927            1.005579  ...
# 18           1.083784           1.003119            1.003119  ...
# 19           1.095334           1.003499            1.003110  ...
# 20           1.137814           1.004484            1.006272  ...
# 21           1.113747           1.003353            1.003353  ...
# 22           1.052803           1.002510            1.001674  ...
# 23           1.117455           1.003786            1.003417  ...
# 24           1.147173           1.004648            1.002324  ...
# 25           1.145896           1.005202            1.005780  ...
# 26           1.183998           1.004886            1.005700  ...
# 27           1.187965           1.006649            1.003324  ...
# 28           1.137411           1.001422            1.000711  ...
# 29           1.128067           1.007489            1.007846  ...
# ..                ...                ...                 ...  ...
# 418          0.616959           1.122807            1.122807  ...
# 419          0.650289           1.115607            1.086705  ...
# 420          0.505512           1.094488            1.086614  ...
# 421          0.535659           1.116279            1.124031  ...
# 422          0.832075           1.132075            1.094340  ...
# 423          0.640598           1.109589            1.089664  ...
# 424          0.590678           1.088983            1.080508  ...
# 425          0.767713           1.107623            1.080717  ...
# 426          0.592582           1.085165            1.087912  ...
# 427          0.585801           1.096677            1.054381  ...
# 428          0.569284           1.076212            1.073903  ...
# 429          0.522754           1.127745            1.129741  ...
# 430          0.542680           1.089663            1.082197  ...
# 431          0.575000           1.083333            1.055556  ...
# 432          0.477419           1.104839            1.104839  ...
# 433          0.766071           1.196429            1.214286  ...
# 434          0.733333           1.033333            1.033333  ...
# 435          0.412500           1.050000            1.050000  ...
# 436          1.246000           1.214444            1.091111  ...
# 437          0.457385           1.157895            1.157895  ...
# 438          0.455556           1.222222            1.111111  ...
# 439          0.493464           1.150327            1.111111  ...
# 440          0.539286           1.000000            1.035714  ...
# 441          0.697059           1.088235            1.117647  ...
# 442          0.612727           1.077922            1.067120  ...
# 443          0.522059           1.029412            1.044118  ...
# 444          0.404938           1.024691            1.049383  ...
# 445          0.688077           1.074468            1.074468  ...
# 446          0.517333           1.120000            1.093333  ...
# 447          0.372222           1.125514            1.067901  ...
#
#      blood_pigment_2011  urine_protein_2011  serum_creatinine_2011   AST_2011  \
# 0             15.397449            1.038862               1.170204  22.062245
# 1             15.197054            1.052373               1.001964  23.873977
# 2             15.370019            1.038685               1.122824  22.547389
# 3             15.328279            1.049404               1.178705  23.328790
# 4             15.220377            1.011321               1.238868  23.754717
# 5             15.524434            1.018181               1.190045  23.339367
# 6             15.163636            1.033058               1.872727  22.975207
# 7             15.365688            1.042889               1.164470  23.255079
# 8             15.461745            1.017937               1.467114  23.957494
# 9             15.383900            1.034014               1.179365  22.970522
# 10            15.380344            1.036260               1.034542  22.559160
# 11            15.172449            1.040816               1.064796  23.826531
# 12            15.337374            1.016835               1.089899  23.727273
# 13            15.356340            1.018301               1.189281  23.711111
# 14            15.247445            1.032787               1.029701  23.018322
# 15            15.239130            1.028986               1.515942  25.434783
# 16            15.460832            1.043861               1.201353  24.150900
# 17            15.328068            1.037308               1.075767  25.372385
# 18            15.341684            1.036902               1.041892  24.877339
# 19            15.429510            1.049397               1.106104  24.720062
# 20            15.248835            1.024263               1.151075  25.436380
# 21            15.457754            1.030226               1.046521  23.757754
# 22            15.166862            1.017573               2.481757  24.815900
# 23            15.441938            1.039404               1.384281  24.575360
# 24            15.448954            1.021742               1.182494  25.522851
# 25            15.441850            1.023175               1.097919  24.775723
# 26            15.554275            1.038324               1.043811  23.883958
# 27            15.187301            1.029275               1.138763  24.402261
# 28            15.252703            1.014936               1.123044  24.812233
# 29            15.413445            1.032810               1.160128  24.302425
# ..                  ...                 ...                    ...        ...
# 418           12.222222            1.100308               0.817544  23.777778
# 419           12.636416            1.111279               1.041040  23.641618
# 420           12.095276            1.150882               0.887402  24.795276
# 421           12.603876            1.039182               0.797674  22.426357
# 422           12.224528            1.037736               0.771698  23.773585
# 423           12.534620            1.117227               0.918306  24.413450
# 424           12.506780            1.069373               0.899153  24.305085
# 425           12.657399            1.115792               0.858296  24.475336
# 426           12.408791            1.134462               0.853297  23.821429
# 427           12.221450            1.092232               0.925680  23.996979
# 428           12.231178            1.077864               0.905543  26.013857
# 429           12.333932            1.087173               0.829741  23.497006
# 430           12.207940            1.095618               0.833499  23.719603
# 431           12.523611            1.053862               0.862500  23.013889
# 432           12.307258            1.148137               0.900806  22.750000
# 433           12.207143            1.250000               0.894643  26.053571
# 434           11.666667            1.166667               0.960000  22.066667
# 435           12.110000            1.100000               1.095000  23.575000
# 436           12.260000            1.105000               0.912000  22.640000
# 437           11.963158            1.015595               0.831579  21.263158
# 438           11.255556            1.222222               0.833333  26.666667
# 439           12.486275            1.147339               0.958170  23.359477
# 440           12.514286            1.082495               0.914286  24.196429
# 441           11.988235            1.109844               0.876471  22.941176
# 442           12.280519            1.062550               0.927273  24.103896
# 443           11.988235            1.071940               0.864706  23.441176
# 444           11.943210            1.080741               1.075309  25.185185
# 445           12.087234            1.152059               0.800000  21.872340
# 446           11.646667            1.084638               0.837333  22.053333
# 447           11.861111            1.222222               1.627778  21.222222
#
#       ALT_2011  gamma_gtp_2011  smoking_2011  alcohol_2011  \
# 0    20.854082       24.113265      2.024490      0.728571
# 1    22.346972       24.443535      2.127660      0.718494
# 2    21.363636       23.555126      2.081238      0.694391
# 3    23.318569       25.500852      2.069847      0.717206
# 4    23.173585       23.181132      2.086792      0.690566
# 5    23.176471       24.113122      2.090498      0.737557
# 6    22.417355       22.545455      2.214876      0.719008
# 7    22.097517       24.845598      2.089391      0.684876
# 8    22.861298       26.337808      2.221477      0.769575
# 9    21.494331       25.927438      2.063492      0.693878
# 10   21.639313       23.725191      2.166031      0.702290
# 11   22.025510       24.446429      2.181122      0.645408
# 12   22.518519       25.659933      2.077441      0.683502
# 13   22.226144       24.613072      2.053595      0.694118
# 14   21.403086       23.671167      2.057859      0.666345
# 15   22.608696       25.898551      2.289855      0.782609
# 16   26.992595       33.948423      2.062572      0.795301
# 17   28.102510       34.031032      2.175384      0.787657
# 18   27.029106       32.253638      2.171518      0.767672
# 19   27.881026       35.650855      2.189736      0.760498
# 20   28.514337       34.363799      2.122760      0.762545
# 21   26.687343       34.992456      2.184409      0.779547
# 22   27.205021       31.955649      2.230126      0.753138
# 23   27.458810       34.729405      2.159601      0.759767
# 24   28.735864       36.224632      2.220759      0.770720
# 25   26.809827       36.042775      2.231214      0.758382
# 26   26.388436       34.891287      2.162459      0.745114
# 27   26.560505       32.656250      2.138390      0.706587
# 28   27.100284       34.292319      2.083215      0.761735
# 29   27.138374       33.416548      2.180456      0.756419
# ..         ...             ...           ...           ...
# 418  17.415205       19.994152      1.076023      0.017544
# 419  17.075145       23.184971      1.023121      0.017341
# 420  17.937008       22.031496      1.015748      0.031496
# 421  16.232558       21.651163      1.031008      0.031008
# 422  16.283019       18.433962      1.018868      0.000000
# 423  17.770859       21.009963      1.047323      0.028643
# 424  17.453390       19.487288      1.033898      0.038136
# 425  17.443946       22.950673      1.035874      0.044843
# 426  17.233516       19.530220      1.060440      0.027473
# 427  16.175227       20.465257      1.039275      0.018127
# 428  17.639723       21.893764      1.016166      0.030023
# 429  16.826347       18.554890      1.085828      0.025948
# 430  16.610422       19.585608      1.101737      0.027295
# 431  16.680556       18.444444      1.000000      0.027778
# 432  15.153226       17.701613      1.000000      0.000000
# 433  19.142857       22.178571      1.053571      0.000000
# 434  12.633333       17.600000      1.000000      0.033333
# 435  15.175000       18.200000      1.025000      0.000000
# 436  16.680000       18.280000      1.000000      0.000000
# 437  13.947368       20.368421      1.000000      0.000000
# 438  20.666667       22.111111      1.000000      0.000000
# 439  15.771242       18.594771      1.019608      0.006536
# 440  15.321429       19.375000      1.000000      0.000000
# 441  13.852941       16.294118      1.000000      0.000000
# 442  15.532468       18.662338      1.000000      0.000000
# 443  14.397059       18.308824      1.000000      0.000000
# 444  15.395062       17.049383      1.000000      0.012346
# 445  14.893617       18.723404      1.042553      0.000000
# 446  14.586667       18.120000      1.013333      0.013333
# 447  13.944444       17.777778      1.000000      0.000000
#
#      oral_inspection_2011    target
# 0                0.561224  0.006122
# 1                0.535188  0.014730
# 2                0.425532  0.005803
# 3                0.632027  0.003407
# 4                0.528302  0.015094
# 5                0.638009  0.009050
# 6                0.648760  0.008264
# 7                0.590519  0.008126
# 8                0.689038  0.006711
# 9                0.621315  0.009070
# 10               0.679389  0.019084
# 11               0.510204  0.002551
# 12               0.494949  0.006734
# 13               0.564706  0.011765
# 14               0.385728  0.012536
# 15               0.391304  0.014493
# 16               0.555087  0.005362
# 17               0.519526  0.011158
# 18               0.363825  0.012474
# 19               0.607698  0.011275
# 20               0.463262  0.017025
# 21               0.580050  0.013412
# 22               0.707113  0.009205
# 23               0.575730  0.007665
# 24               0.525174  0.006197
# 25               0.595954  0.009827
# 26               0.705212  0.009365
# 27               0.482713  0.012633
# 28               0.490754  0.019915
# 29               0.550642  0.010342
# ..                    ...       ...
# 418              0.116959  0.122807
# 419              0.213873  0.080925
# 420              0.212598  0.133858
# 421              0.108527  0.155039
# 422              0.169811  0.169811
# 423              0.110834  0.123288
# 424              0.076271  0.084746
# 425              0.071749  0.112108
# 426              0.085165  0.112637
# 427              0.157100  0.093656
# 428              0.032333  0.122402
# 429              0.037924  0.089820
# 430              0.079404  0.109181
# 431              0.166667  0.138889
# 432              0.104839  0.072581
# 433              0.214286  0.160714
# 434              0.033333  0.266667
# 435              0.175000  0.125000
# 436              0.120000  0.240000
# 437              0.105263  0.157895
# 438              0.111111  0.222222
# 439              0.065359  0.078431
# 440              0.053571  0.178571
# 441              0.117647  0.088235
# 442              0.000000  0.142857
# 443              0.029412  0.117647
# 444              0.024691  0.148148
# 445              0.021277  0.127660
# 446              0.026667  0.160000
# 447              0.111111  0.055556
#
# [448 rows x 26 columns]

# %%
GJ_2011_group.to_csv("GJ_2011_group.csv")

# 2011년 건강검진정보 데이터전처리 -> 448개 범주화된 자료를 csv로 저장
# https://tariat.tistory.com/583

# %%
# 척도화
# https://mkjjo.github.io/python/2019/01/10/scaler.html

# 데이터 분할
# https://pythonanalysis.tistory.com/7

# 데이터 분포 변환
# https://wikidocs.net/16582
