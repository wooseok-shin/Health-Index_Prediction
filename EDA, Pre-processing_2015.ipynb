# %% [markdown]
# # 데이터 불러오기 및 전처리

# %%
import pandas as pd
import numpy as np

# 데이터 전처리에 필요한 패키지 장착

# %%
GJ_2015=pd.read_csv("./NHIS_OPEN_GJ_2015.csv",encoding='CP949') # 데이터 불러오기
GJ_2015.head() # 데이터 일부 확인
# Out:
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0  2015        1     2           15    45        155          60    88    0.6
# 1  2015        2     2           15    11        155          65    98    1.2
# 2  2015        3     2           11    26        155          65    85    1.2
# 3  2015        4     1            9    41        175          75    89    0.2
# 4  2015        5     1           16    47        160          50    78    0.5
#
#    시력(우)  ...  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부  \
# 0    0.7  ...      1.1          17          28     23   1.0   1.0          0
# 1    0.6  ...      1.0          25          30     41   1.0   1.0          1
# 2    0.9  ...      0.6          18          16     25   1.0   0.0          0
# 3    0.2  ...      0.9          28          40     50   1.0   1.0          1
# 4    0.6  ...      1.0          20          13     19   2.0   0.0          1
#
#    치아우식증유무  치석유무  데이터 기준일자
# 0      NaN   NaN  20161220
# 1      NaN   0.0  20161220
# 2      NaN   NaN  20161220
# 3      0.0   NaN  20161220
# 4      NaN   0.0  20161220
#
# [5 rows x 31 columns]

# %%
GJ_2015.shape # 데이터 차원 : 1000000 x 31
# Out:
# (1000000, 31)

# %%
GJ_2015.info() # 31개 변수 타입 : 정수형 또는 실수형
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 31 columns):
# 기준년도           1000000 non-null int64
# 가입자일련번호        1000000 non-null int64
# 성별코드           1000000 non-null int64
# 연령대코드(5세단위)    1000000 non-null int64
# 시도코드           1000000 non-null int64
# 신장(5Cm단위)      1000000 non-null int64
# 체중(5Kg 단위)     1000000 non-null int64
# 허리둘레           1000000 non-null int64
# 시력(좌)          999856 non-null float64
# 시력(우)          999845 non-null float64
# 청력(좌)          999887 non-null float64
# 청력(우)          999881 non-null float64
# 수축기혈압          1000000 non-null int64
# 이완기혈압          1000000 non-null int64
# 식전혈당(공복혈당)     1000000 non-null int64
# 총콜레스테롤         1000000 non-null int64
# 트리글리세라이드       1000000 non-null int64
# HDL콜레스테롤       1000000 non-null int64
# LDL콜레스테롤       996811 non-null float64
# 혈색소            1000000 non-null float64
# 요단백            995456 non-null float64
# 혈청크레아티닌        1000000 non-null float64
# (혈청지오티)AST     1000000 non-null int64
# (혈청지오티)ALT     1000000 non-null int64
# 감마지티피          1000000 non-null int64
# 흡연상태           999599 non-null float64
# 음주여부           999164 non-null float64
# 구강검진 수검여부      1000000 non-null int64
# 치아우식증유무        104629 non-null float64
# 치석유무           381123 non-null float64
# 데이터 기준일자       1000000 non-null int64
# dtypes: float64(12), int64(19)
# memory usage: 236.5 MB

# %%
GJ_2015.isna().sum()

# 결측치가 있는 변수 : 시력좌/시력우/청력좌/청력우/LDL/요단백/흡연상태/음주여부/치아우식증유무/치석유무
# Out:
# 기준년도                0
# 가입자일련번호             0
# 성별코드                0
# 연령대코드(5세단위)         0
# 시도코드                0
# 신장(5Cm단위)           0
# 체중(5Kg 단위)          0
# 허리둘레                0
# 시력(좌)             144
# 시력(우)             155
# 청력(좌)             113
# 청력(우)             119
# 수축기혈압               0
# 이완기혈압               0
# 식전혈당(공복혈당)          0
# 총콜레스테롤              0
# 트리글리세라이드            0
# HDL콜레스테롤            0
# LDL콜레스테롤         3189
# 혈색소                 0
# 요단백              4544
# 혈청크레아티닌             0
# (혈청지오티)AST          0
# (혈청지오티)ALT          0
# 감마지티피               0
# 흡연상태              401
# 음주여부              836
# 구강검진 수검여부           0
# 치아우식증유무        895371
# 치석유무           618877
# 데이터 기준일자            0
# dtype: int64

# %%
GJ_2015=GJ_2015.drop(['치아우식증유무','치석유무'],axis=1)

# 결측비율이 약 90%인 '치아우식증유무' 변수와 결측비율이 약 60%인 '치석' 변수 제거

# %%
GJ_2015.shape # 5개의 변수가 제거됨
# Out:
# (1000000, 29)

# %%
GJ_2015.describe()

# 영-분산에 해당하는 변수 : 기준년도/데이터공개일자
# Out:
#             기준년도         가입자일련번호            성별코드     연령대코드(5세단위)  \
# count  1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean      2015.0   500000.500000        1.461937       10.404782
# std          0.0   288675.278933        0.498549        2.823456
# min       2015.0        1.000000        1.000000        5.000000
# 25%       2015.0   250000.750000        1.000000        8.000000
# 50%       2015.0   500000.500000        1.000000       10.000000
# 75%       2015.0   750000.250000        2.000000       12.000000
# max       2015.0  1000000.000000        2.000000       18.000000
#
#                  시도코드       신장(5Cm단위)      체중(5Kg 단위)            허리둘레  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        33.554957      166.354490       66.950910       80.840007
# std         12.746188        9.324175       12.365557        9.467994
# min         11.000000      130.000000       30.000000       51.000000
# 25%         26.000000      160.000000       60.000000       74.000000
# 50%         41.000000      165.000000       65.000000       81.000000
# 75%         44.000000      175.000000       75.000000       87.000000
# max         49.000000      200.000000      145.000000      129.000000
#
#                시력(좌)          시력(우)  ...             혈색소            요단백  \
# count  999856.000000  999845.000000  ...  1000000.000000  995456.000000
# mean        0.985312       0.982907  ...       14.122612       1.085987
# std         0.629268       0.626382  ...        1.641841       0.420917
# min         0.100000       0.100000  ...        0.600000       1.000000
# 25%         0.700000       0.700000  ...       13.000000       1.000000
# 50%         1.000000       1.000000  ...       14.200000       1.000000
# 75%         1.200000       1.200000  ...       15.300000       1.000000
# max         9.900000       9.900000  ...       25.000000       6.000000
#
#               혈청크레아티닌      (혈청지오티)AST      (혈청지오티)ALT           감마지티피  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.876990       25.712818       25.476939       37.083030
# std          0.561258       15.860220       21.339325       50.047157
# min          0.100000        1.000000        1.000000        1.000000
# 25%          0.700000       19.000000       15.000000       16.000000
# 50%          0.900000       23.000000       20.000000       23.000000
# 75%          1.000000       28.000000       29.000000       39.000000
# max         99.000000      999.000000      991.000000      999.000000
#
#                 흡연상태           음주여부       구강검진 수검여부    데이터 기준일자
# count  999599.000000  999164.000000  1000000.000000   1000000.0
# mean        1.614563       0.499905        0.403213  20161220.0
# std         0.820393       0.500000        0.490543         0.0
# min         1.000000       0.000000        0.000000  20161220.0
# 25%         1.000000       0.000000        0.000000  20161220.0
# 50%         1.000000       0.000000        0.000000  20161220.0
# 75%         2.000000       1.000000        1.000000  20161220.0
# max         3.000000       1.000000        1.000000  20161220.0
#
# [8 rows x 29 columns]

# %%
GJ_2015=GJ_2015.drop(['기준년도','데이터 기준일자'],axis=1)

# 영-분산을 가지는 2개의 변수를 제거

# %%
GJ_2015.shape # 2개의 변수가 제거됨
# Out:
# (1000000, 27)

# %%
GJ_2015

# '가입자일련번호-1'와 index가 일치함
# Out:
#         가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0             1     2           15    45        155          60    88    0.6
# 1             2     2           15    11        155          65    98    1.2
# 2             3     2           11    26        155          65    85    1.2
# 3             4     1            9    41        175          75    89    0.2
# 4             5     1           16    47        160          50    78    0.5
# 5             6     1           11    26        170          60    74    1.0
# 6             7     1           10    44        180          90    94    0.7
# 7             8     2            5    43        165          60    73    0.5
# 8             9     2           11    47        165          55    72    1.0
# 9            10     1            6    26        185          90    81    1.5
# 10           11     2            7    46        155          40    58    1.0
# 11           12     2           18    44        145          45    84    0.1
# 12           13     2            6    11        165          55    68    0.3
# 13           14     1           18    30        160          60    85    0.7
# 14           15     2           18    46        150          55    82    0.8
# 15           16     2           18    48        145          40    67    0.4
# 16           17     2           18    41        150          60    99    0.1
# 17           18     2           18    47        160          60    94    9.9
# 18           19     2           12    47        165          70    92    0.6
# 19           20     2           18    45        155          50    85    0.6
# 20           21     2           18    41        150          60    91    0.4
# 21           22     2           18    41        140          50    80    0.4
# 22           23     1           18    44        165          50    76    0.5
# 23           24     2           18    41        145          50    65    0.3
# 24           25     1            6    41        185          90    85    1.2
# 25           26     2            6    11        175          60    71    0.8
# 26           27     2           18    41        145          50    98    0.9
# 27           28     1            5    41        175          65    70    0.6
# 28           29     1           18    45        155          50    74    1.0
# 29           30     1           18    44        165          65    83    0.4
# ...         ...   ...          ...   ...        ...         ...   ...    ...
# 999970   999971     1            5    43        165          60    65    1.0
# 999971   999972     1           12    47        180         110   106    1.2
# 999972   999973     2           11    41        170          60    79    1.2
# 999973   999974     1            5    41        170          65    79    2.0
# 999974   999975     2           13    47        165          55    76    0.5
# 999975   999976     1            5    26        165          55    68    1.5
# 999976   999977     2           10    31        150          50    72    0.7
# 999977   999978     1            7    41        170          90    93    1.5
# 999978   999979     1            7    36        170          60    76    0.5
# 999979   999980     1            6    41        165          55    70    1.0
# 999980   999981     2            6    41        150          45    76    0.8
# 999981   999982     1            5    41        170          70    89    1.0
# 999982   999983     1            6    48        170          65    77    0.9
# 999983   999984     1            5    48        170          70    72    1.5
# 999984   999985     1            8    47        170          75    90    0.8
# 999985   999986     1            9    47        170          70    79    1.0
# 999986   999987     1            8    41        175          65    76    1.2
# 999987   999988     1            7    44        170          60    67    1.5
# 999988   999989     1            6    41        170          70    81    1.2
# 999989   999990     2           10    11        160          55    75    1.0
# 999990   999991     1            7    41        160          70    88    1.5
# 999991   999992     1            7    47        175          90    97    0.6
# 999992   999993     1            6    41        160          50    76    0.9
# 999993   999994     1            5    44        180          85    95    1.0
# 999994   999995     1            6    41        165          70    82    0.5
# 999995   999996     1            8    41        170          70    88    1.2
# 999996   999997     1            7    41        175          60    73    1.2
# 999997   999998     1           13    42        165          70    94    0.9
# 999998   999999     1           12    28        175          65    82    0.6
# 999999  1000000     1           11    11        160          65    84    0.4
#
#         시력(우)  청력(좌)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0         0.7    1.0  ...      91.0   9.8  1.0      1.1          17
# 1         0.6    1.0  ...      79.0  13.5  1.0      1.0          25
# 2         0.9    1.0  ...      95.0  13.0  1.0      0.6          18
# 3         0.2    1.0  ...      80.0  15.1  1.0      0.9          28
# 4         0.6    2.0  ...     123.0  14.4  3.0      1.0          20
# 5         0.8    1.0  ...      74.0  12.0  1.0      0.9          22
# 6         0.8    1.0  ...     117.0  15.3  1.0      0.8          66
# 7         0.6    1.0  ...     101.0  13.6  1.0      0.8          17
# 8         1.2    1.0  ...     118.0  13.2  1.0      0.6          23
# 9         1.5    1.0  ...     157.0  16.0  1.0      0.9          20
# 10        0.9    1.0  ...     107.0  12.0  1.0      0.8          19
# 11        0.5    1.0  ...      99.0  11.9  1.0      1.2          18
# 12        0.5    1.0  ...     114.0  12.1  1.0      0.7          25
# 13        0.6    2.0  ...     108.0  14.8  1.0      1.1          28
# 14        0.5    2.0  ...     134.0  12.7  1.0      0.8          45
# 15        0.5    1.0  ...      71.0   9.0  1.0      0.4          16
# 16        0.1    1.0  ...      68.0  11.5  1.0      0.6          27
# 17        0.4    1.0  ...     148.0   9.6  4.0      0.9          16
# 18        0.6    1.0  ...      97.0  12.2  1.0      1.0          16
# 19        0.3    1.0  ...     144.0  13.0  1.0      1.0          17
# 20        0.7    1.0  ...      85.0  11.3  1.0      2.5          10
# 21        0.4    2.0  ...     107.0  11.1  1.0      1.4          31
# 22        0.3    1.0  ...     149.0  13.3  1.0      0.9          26
# 23        0.3    1.0  ...      67.0  13.0  1.0      0.9          24
# 24        1.2    1.0  ...      69.0  16.3  1.0      0.8          15
# 25        0.9    1.0  ...      94.0  14.3  1.0      0.5          20
# 26        0.7    1.0  ...     139.0  11.6  1.0      1.1          23
# 27        0.6    1.0  ...     113.0  15.2  1.0      0.9          17
# 28        1.0    1.0  ...     105.0  12.1  1.0      0.9          26
# 29        0.1    1.0  ...      71.0  11.9  1.0      1.0          26
# ...       ...    ...  ...       ...   ...  ...      ...         ...
# 999970    1.5    1.0  ...     116.0  14.8  1.0      0.9          27
# 999971    1.2    1.0  ...     194.0  15.8  1.0      1.3          29
# 999972    0.9    1.0  ...     122.0  12.6  1.0      0.5          25
# 999973    1.0    1.0  ...      78.0  16.2  1.0      1.0          30
# 999974    0.4    1.0  ...     109.0  13.1  1.0      0.7          19
# 999975    1.5    1.0  ...      83.0  14.3  2.0      1.1          24
# 999976    0.4    1.0  ...      96.0  13.6  1.0      0.7          21
# 999977    1.5    1.0  ...     137.0  14.7  1.0      1.2          19
# 999978    0.5    1.0  ...      84.0  15.9  1.0      1.0          23
# 999979    1.0    1.0  ...     106.0  14.8  1.0      1.2          13
# 999980    0.7    1.0  ...      73.0  12.1  1.0      0.7          20
# 999981    1.2    1.0  ...     123.0  14.7  1.0      1.3          46
# 999982    1.0    1.0  ...      71.0  13.8  1.0      0.8          23
# 999983    1.5    1.0  ...      69.0  14.2  1.0      1.0          27
# 999984    0.8    1.0  ...     142.0  16.7  1.0      0.8          24
# 999985    1.0    1.0  ...     140.0  16.6  1.0      0.8          25
# 999986    1.0    1.0  ...     117.0  15.4  1.0      0.1          37
# 999987    1.5    2.0  ...      82.0  16.0  1.0      1.0          16
# 999988    1.2    1.0  ...      65.0  14.4  1.0      0.7          24
# 999989    1.2    1.0  ...     101.0  12.9  1.0      0.7          18
# 999990    1.5    1.0  ...     163.0  14.6  1.0      1.0          46
# 999991    0.4    1.0  ...     118.0  14.4  1.0      0.7          29
# 999992    1.0    1.0  ...     100.0  13.5  1.0      1.2          22
# 999993    0.6    1.0  ...     115.0  16.1  1.0      1.0          23
# 999994    0.6    1.0  ...      73.0  15.3  1.0      1.2          20
# 999995    1.0    1.0  ...     123.0  14.9  1.0      1.1          16
# 999996    1.0    1.0  ...      95.0  15.7  1.0      0.9          20
# 999997    0.9    1.0  ...     100.0  16.4  1.0      0.9          19
# 999998    0.7    1.0  ...      72.0  14.4  1.0      1.1          25
# 999999    0.2    1.0  ...     102.0  15.4  1.0      1.0          29
#
#         (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부
# 0               28     23   1.0   1.0          0
# 1               30     41   1.0   1.0          1
# 2               16     25   1.0   0.0          0
# 3               40     50   1.0   1.0          1
# 4               13     19   2.0   0.0          1
# 5               16     12   1.0   1.0          0
# 6               61    152   3.0   0.0          1
# 7               12     14   1.0   0.0          1
# 8               12     46   1.0   0.0          0
# 9               22     41   3.0   0.0          1
# 10              18     12   1.0   1.0          1
# 11               9     15   1.0   1.0          0
# 12              10     11   1.0   1.0          1
# 13              20     43   3.0   1.0          1
# 14              37     69   1.0   1.0          0
# 15               5     12   1.0   1.0          0
# 16              18     27   1.0   1.0          0
# 17              10     13   1.0   1.0          0
# 18               6      7   1.0   1.0          0
# 19              11     14   1.0   1.0          0
# 20               5     15   1.0   1.0          0
# 21              19     13   1.0   1.0          1
# 22              10     13   1.0   1.0          0
# 23              13     32   1.0   1.0          0
# 24              14     23   3.0   0.0          0
# 25              19     13   3.0   0.0          0
# 26              10     16   1.0   1.0          0
# 27              20     23   3.0   0.0          0
# 28              18     20   1.0   1.0          0
# 29              12     19   2.0   0.0          0
# ...            ...    ...   ...   ...        ...
# 999970          19     19   1.0   1.0          0
# 999971          39     51   3.0   1.0          0
# 999972          15     13   1.0   1.0          1
# 999973           8     20   1.0   1.0          0
# 999974          17     23   1.0   1.0          1
# 999975          10     25   1.0   0.0          0
# 999976          15     12   1.0   1.0          1
# 999977          22     20   1.0   0.0          0
# 999978          16     13   3.0   1.0          1
# 999979           7     27   3.0   0.0          0
# 999980          12     10   1.0   1.0          0
# 999981          44     47   1.0   0.0          0
# 999982          24     34   1.0   1.0          0
# 999983          17     25   3.0   1.0          0
# 999984          52     43   3.0   1.0          1
# 999985          25     16   1.0   0.0          1
# 999986          24     30   3.0   0.0          0
# 999987          17     13   3.0   0.0          0
# 999988          13     35   3.0   0.0          1
# 999989          15     13   1.0   NaN          1
# 999990          99     58   2.0   1.0          1
# 999991          30     21   3.0   0.0          0
# 999992          14     13   1.0   1.0          0
# 999993          26     35   3.0   1.0          1
# 999994          18     39   3.0   1.0          1
# 999995          23     28   1.0   1.0          0
# 999996          11     14   1.0   1.0          1
# 999997          20     75   3.0   0.0          0
# 999998          20     30   3.0   1.0          0
# 999999          37     33   2.0   1.0          0
#
# [1000000 rows x 27 columns]

# %%
GJ_2015.rename(index=GJ_2015['가입자일련번호'])
# index를 가입자 일련번호로 설정
# Out:
#          가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 1              1     2           15    45        155          60    88    0.6
# 2              2     2           15    11        155          65    98    1.2
# 3              3     2           11    26        155          65    85    1.2
# 4              4     1            9    41        175          75    89    0.2
# 5              5     1           16    47        160          50    78    0.5
# 6              6     1           11    26        170          60    74    1.0
# 7              7     1           10    44        180          90    94    0.7
# 8              8     2            5    43        165          60    73    0.5
# 9              9     2           11    47        165          55    72    1.0
# 10            10     1            6    26        185          90    81    1.5
# 11            11     2            7    46        155          40    58    1.0
# 12            12     2           18    44        145          45    84    0.1
# 13            13     2            6    11        165          55    68    0.3
# 14            14     1           18    30        160          60    85    0.7
# 15            15     2           18    46        150          55    82    0.8
# 16            16     2           18    48        145          40    67    0.4
# 17            17     2           18    41        150          60    99    0.1
# 18            18     2           18    47        160          60    94    9.9
# 19            19     2           12    47        165          70    92    0.6
# 20            20     2           18    45        155          50    85    0.6
# 21            21     2           18    41        150          60    91    0.4
# 22            22     2           18    41        140          50    80    0.4
# 23            23     1           18    44        165          50    76    0.5
# 24            24     2           18    41        145          50    65    0.3
# 25            25     1            6    41        185          90    85    1.2
# 26            26     2            6    11        175          60    71    0.8
# 27            27     2           18    41        145          50    98    0.9
# 28            28     1            5    41        175          65    70    0.6
# 29            29     1           18    45        155          50    74    1.0
# 30            30     1           18    44        165          65    83    0.4
# ...          ...   ...          ...   ...        ...         ...   ...    ...
# 999971    999971     1            5    43        165          60    65    1.0
# 999972    999972     1           12    47        180         110   106    1.2
# 999973    999973     2           11    41        170          60    79    1.2
# 999974    999974     1            5    41        170          65    79    2.0
# 999975    999975     2           13    47        165          55    76    0.5
# 999976    999976     1            5    26        165          55    68    1.5
# 999977    999977     2           10    31        150          50    72    0.7
# 999978    999978     1            7    41        170          90    93    1.5
# 999979    999979     1            7    36        170          60    76    0.5
# 999980    999980     1            6    41        165          55    70    1.0
# 999981    999981     2            6    41        150          45    76    0.8
# 999982    999982     1            5    41        170          70    89    1.0
# 999983    999983     1            6    48        170          65    77    0.9
# 999984    999984     1            5    48        170          70    72    1.5
# 999985    999985     1            8    47        170          75    90    0.8
# 999986    999986     1            9    47        170          70    79    1.0
# 999987    999987     1            8    41        175          65    76    1.2
# 999988    999988     1            7    44        170          60    67    1.5
# 999989    999989     1            6    41        170          70    81    1.2
# 999990    999990     2           10    11        160          55    75    1.0
# 999991    999991     1            7    41        160          70    88    1.5
# 999992    999992     1            7    47        175          90    97    0.6
# 999993    999993     1            6    41        160          50    76    0.9
# 999994    999994     1            5    44        180          85    95    1.0
# 999995    999995     1            6    41        165          70    82    0.5
# 999996    999996     1            8    41        170          70    88    1.2
# 999997    999997     1            7    41        175          60    73    1.2
# 999998    999998     1           13    42        165          70    94    0.9
# 999999    999999     1           12    28        175          65    82    0.6
# 1000000  1000000     1           11    11        160          65    84    0.4
#
#          시력(우)  청력(좌)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 1          0.7    1.0  ...      91.0   9.8  1.0      1.1          17
# 2          0.6    1.0  ...      79.0  13.5  1.0      1.0          25
# 3          0.9    1.0  ...      95.0  13.0  1.0      0.6          18
# 4          0.2    1.0  ...      80.0  15.1  1.0      0.9          28
# 5          0.6    2.0  ...     123.0  14.4  3.0      1.0          20
# 6          0.8    1.0  ...      74.0  12.0  1.0      0.9          22
# 7          0.8    1.0  ...     117.0  15.3  1.0      0.8          66
# 8          0.6    1.0  ...     101.0  13.6  1.0      0.8          17
# 9          1.2    1.0  ...     118.0  13.2  1.0      0.6          23
# 10         1.5    1.0  ...     157.0  16.0  1.0      0.9          20
# 11         0.9    1.0  ...     107.0  12.0  1.0      0.8          19
# 12         0.5    1.0  ...      99.0  11.9  1.0      1.2          18
# 13         0.5    1.0  ...     114.0  12.1  1.0      0.7          25
# 14         0.6    2.0  ...     108.0  14.8  1.0      1.1          28
# 15         0.5    2.0  ...     134.0  12.7  1.0      0.8          45
# 16         0.5    1.0  ...      71.0   9.0  1.0      0.4          16
# 17         0.1    1.0  ...      68.0  11.5  1.0      0.6          27
# 18         0.4    1.0  ...     148.0   9.6  4.0      0.9          16
# 19         0.6    1.0  ...      97.0  12.2  1.0      1.0          16
# 20         0.3    1.0  ...     144.0  13.0  1.0      1.0          17
# 21         0.7    1.0  ...      85.0  11.3  1.0      2.5          10
# 22         0.4    2.0  ...     107.0  11.1  1.0      1.4          31
# 23         0.3    1.0  ...     149.0  13.3  1.0      0.9          26
# 24         0.3    1.0  ...      67.0  13.0  1.0      0.9          24
# 25         1.2    1.0  ...      69.0  16.3  1.0      0.8          15
# 26         0.9    1.0  ...      94.0  14.3  1.0      0.5          20
# 27         0.7    1.0  ...     139.0  11.6  1.0      1.1          23
# 28         0.6    1.0  ...     113.0  15.2  1.0      0.9          17
# 29         1.0    1.0  ...     105.0  12.1  1.0      0.9          26
# 30         0.1    1.0  ...      71.0  11.9  1.0      1.0          26
# ...        ...    ...  ...       ...   ...  ...      ...         ...
# 999971     1.5    1.0  ...     116.0  14.8  1.0      0.9          27
# 999972     1.2    1.0  ...     194.0  15.8  1.0      1.3          29
# 999973     0.9    1.0  ...     122.0  12.6  1.0      0.5          25
# 999974     1.0    1.0  ...      78.0  16.2  1.0      1.0          30
# 999975     0.4    1.0  ...     109.0  13.1  1.0      0.7          19
# 999976     1.5    1.0  ...      83.0  14.3  2.0      1.1          24
# 999977     0.4    1.0  ...      96.0  13.6  1.0      0.7          21
# 999978     1.5    1.0  ...     137.0  14.7  1.0      1.2          19
# 999979     0.5    1.0  ...      84.0  15.9  1.0      1.0          23
# 999980     1.0    1.0  ...     106.0  14.8  1.0      1.2          13
# 999981     0.7    1.0  ...      73.0  12.1  1.0      0.7          20
# 999982     1.2    1.0  ...     123.0  14.7  1.0      1.3          46
# 999983     1.0    1.0  ...      71.0  13.8  1.0      0.8          23
# 999984     1.5    1.0  ...      69.0  14.2  1.0      1.0          27
# 999985     0.8    1.0  ...     142.0  16.7  1.0      0.8          24
# 999986     1.0    1.0  ...     140.0  16.6  1.0      0.8          25
# 999987     1.0    1.0  ...     117.0  15.4  1.0      0.1          37
# 999988     1.5    2.0  ...      82.0  16.0  1.0      1.0          16
# 999989     1.2    1.0  ...      65.0  14.4  1.0      0.7          24
# 999990     1.2    1.0  ...     101.0  12.9  1.0      0.7          18
# 999991     1.5    1.0  ...     163.0  14.6  1.0      1.0          46
# 999992     0.4    1.0  ...     118.0  14.4  1.0      0.7          29
# 999993     1.0    1.0  ...     100.0  13.5  1.0      1.2          22
# 999994     0.6    1.0  ...     115.0  16.1  1.0      1.0          23
# 999995     0.6    1.0  ...      73.0  15.3  1.0      1.2          20
# 999996     1.0    1.0  ...     123.0  14.9  1.0      1.1          16
# 999997     1.0    1.0  ...      95.0  15.7  1.0      0.9          20
# 999998     0.9    1.0  ...     100.0  16.4  1.0      0.9          19
# 999999     0.7    1.0  ...      72.0  14.4  1.0      1.1          25
# 1000000    0.2    1.0  ...     102.0  15.4  1.0      1.0          29
#
#          (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부
# 1                28     23   1.0   1.0          0
# 2                30     41   1.0   1.0          1
# 3                16     25   1.0   0.0          0
# 4                40     50   1.0   1.0          1
# 5                13     19   2.0   0.0          1
# 6                16     12   1.0   1.0          0
# 7                61    152   3.0   0.0          1
# 8                12     14   1.0   0.0          1
# 9                12     46   1.0   0.0          0
# 10               22     41   3.0   0.0          1
# 11               18     12   1.0   1.0          1
# 12                9     15   1.0   1.0          0
# 13               10     11   1.0   1.0          1
# 14               20     43   3.0   1.0          1
# 15               37     69   1.0   1.0          0
# 16                5     12   1.0   1.0          0
# 17               18     27   1.0   1.0          0
# 18               10     13   1.0   1.0          0
# 19                6      7   1.0   1.0          0
# 20               11     14   1.0   1.0          0
# 21                5     15   1.0   1.0          0
# 22               19     13   1.0   1.0          1
# 23               10     13   1.0   1.0          0
# 24               13     32   1.0   1.0          0
# 25               14     23   3.0   0.0          0
# 26               19     13   3.0   0.0          0
# 27               10     16   1.0   1.0          0
# 28               20     23   3.0   0.0          0
# 29               18     20   1.0   1.0          0
# 30               12     19   2.0   0.0          0
# ...             ...    ...   ...   ...        ...
# 999971           19     19   1.0   1.0          0
# 999972           39     51   3.0   1.0          0
# 999973           15     13   1.0   1.0          1
# 999974            8     20   1.0   1.0          0
# 999975           17     23   1.0   1.0          1
# 999976           10     25   1.0   0.0          0
# 999977           15     12   1.0   1.0          1
# 999978           22     20   1.0   0.0          0
# 999979           16     13   3.0   1.0          1
# 999980            7     27   3.0   0.0          0
# 999981           12     10   1.0   1.0          0
# 999982           44     47   1.0   0.0          0
# 999983           24     34   1.0   1.0          0
# 999984           17     25   3.0   1.0          0
# 999985           52     43   3.0   1.0          1
# 999986           25     16   1.0   0.0          1
# 999987           24     30   3.0   0.0          0
# 999988           17     13   3.0   0.0          0
# 999989           13     35   3.0   0.0          1
# 999990           15     13   1.0   NaN          1
# 999991           99     58   2.0   1.0          1
# 999992           30     21   3.0   0.0          0
# 999993           14     13   1.0   1.0          0
# 999994           26     35   3.0   1.0          1
# 999995           18     39   3.0   1.0          1
# 999996           23     28   1.0   1.0          0
# 999997           11     14   1.0   1.0          1
# 999998           20     75   3.0   0.0          0
# 999999           20     30   3.0   1.0          0
# 1000000          37     33   2.0   1.0          0
#
# [1000000 rows x 27 columns]

# %%
GJ_2015=GJ_2015.drop(['가입자일련번호'],axis=1)
# 가입자일련번호 변수 제거

# %%
GJ_2015.shape # 1개의 변수가 제거됨
# Out:
# (1000000, 26)

# %%
GJ_2015.isna().sum()

# 결측치가 있는 변수 : 시력좌/시력우/청력좌/청력우/LDL/요단백/흡연상태/음주여부
# Out:
# 성별코드              0
# 연령대코드(5세단위)       0
# 시도코드              0
# 신장(5Cm단위)         0
# 체중(5Kg 단위)        0
# 허리둘레              0
# 시력(좌)           144
# 시력(우)           155
# 청력(좌)           113
# 청력(우)           119
# 수축기혈압             0
# 이완기혈압             0
# 식전혈당(공복혈당)        0
# 총콜레스테롤            0
# 트리글리세라이드          0
# HDL콜레스테롤          0
# LDL콜레스테롤       3189
# 혈색소               0
# 요단백            4544
# 혈청크레아티닌           0
# (혈청지오티)AST        0
# (혈청지오티)ALT        0
# 감마지티피             0
# 흡연상태            401
# 음주여부            836
# 구강검진 수검여부         0
# dtype: int64

# %%
fill_mean_func = lambda g: g.fillna(g.mean())
GJ_2015=GJ_2015.groupby(['성별코드','연령대코드(5세단위)','시도코드']).apply(fill_mean_func)

# sex, age, sido 그룹별로 결측값 평균치 대체
# mean, median, mode 중 UE(비편향) 성질을 만족하는 평균값으로 대체
# 각 변수별로 이상치가 많으나, 데이터의 갯수가 충분히 확보(100만개)된 상태이므로, mean 사용
# 전반적으로 히스토그램이 우측 긴 꼬리의 형태를 나타내고 있으므로, 평균 > 중앙값 > 최빈값 순서를 따름
# https://rfriend.tistory.com/402 : 결측값을 그룹 평균값으로 채우기 (Fill missing values by Group means)
# 출처: https://rfriend.tistory.com/402 [R, Python 분석과 프로그래밍 (by R Friend)]

# %%
GJ_2015=GJ_2015.drop(['성별코드','연령대코드(5세단위)','시도코드'], axis=1)

# %%
GJ_2015.reset_index(inplace=True)

# 인덱스 초기화
# inplace=True : 객체 반환 x(결과물 안보이게 하기)
# https://nittaku.tistory.com/122

# %%
del GJ_2015['level_3']

# del health['변수명'] : 특정 변수 제거

# %%
GJ_2015.head()
# Out:
#    성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0     1            5    11        175          55    71    0.9    1.2    1.0
# 1     1            5    11        175          90    91    1.5    1.5    1.0
# 2     1            5    11        180          75    82    0.9    0.7    1.0
# 3     1            5    11        170          60    65    0.8    0.5    1.0
# 4     1            5    11        185         105   100    1.2    0.9    1.0
#
#    청력(우)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  \
# 0    1.0  ...      55.0  15.3  1.0      0.7          19          10     24
# 1    1.0  ...      42.0  17.4  1.0      1.0          31          40    221
# 2    1.0  ...      85.0  15.9  1.0      1.0          22          23     34
# 3    1.0  ...      74.0  15.4  1.0      0.8          16          15     14
# 4    1.0  ...      67.0  15.9  1.0      1.0          25          40     50
#
#    흡연상태  음주여부  구강검진 수검여부
# 0   3.0   0.0          0
# 1   3.0   0.0          0
# 2   3.0   0.0          0
# 3   3.0   0.0          1
# 4   3.0   0.0          0
#
# [5 rows x 26 columns]

# %%
GJ_2015.shape
# Out:
# (1000000, 26)

# %%
GJ_2015.describe()
# Out:
#                  성별코드     연령대코드(5세단위)            시도코드       신장(5Cm단위)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.461937       10.404782       33.554957      166.354490
# std          0.498549        2.823456       12.746188        9.324175
# min          1.000000        5.000000       11.000000      130.000000
# 25%          1.000000        8.000000       26.000000      160.000000
# 50%          1.000000       10.000000       41.000000      165.000000
# 75%          2.000000       12.000000       44.000000      175.000000
# max          2.000000       18.000000       49.000000      200.000000
#
#            체중(5Kg 단위)            허리둘레           시력(좌)           시력(우)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        66.950910       80.840007        0.985309        0.982906
# std         12.365557        9.467994        0.629224        0.626336
# min         30.000000       51.000000        0.100000        0.100000
# 25%         60.000000       74.000000        0.700000        0.700000
# 50%         65.000000       81.000000        1.000000        1.000000
# 75%         75.000000       87.000000        1.200000        1.200000
# max        145.000000      129.000000        9.900000        9.900000
#
#                 청력(좌)           청력(우)  ...        LDL콜레스테롤             혈색소  \
# count  1000000.000000  1000000.000000  ...  1000000.000000  1000000.000000
# mean         1.029306        1.027946  ...      113.793894       14.122612
# std          0.168650        0.164805  ...       35.536119        1.641841
# min          1.000000        1.000000  ...        1.000000        0.600000
# 25%          1.000000        1.000000  ...       90.000000       13.000000
# 50%          1.000000        1.000000  ...      112.000000       14.200000
# 75%          1.000000        1.000000  ...      135.000000       15.300000
# max          2.000000        2.000000  ...     9999.000000       25.000000
#
#                   요단백         혈청크레아티닌      (혈청지오티)AST      (혈청지오티)ALT  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.086048        0.876990       25.712818       25.476939
# std          0.419970        0.561258       15.860220       21.339325
# min          1.000000        0.100000        1.000000        1.000000
# 25%          1.000000        0.700000       19.000000       15.000000
# 50%          1.000000        0.900000       23.000000       20.000000
# 75%          1.000000        1.000000       28.000000       29.000000
# max          6.000000       99.000000      999.000000      991.000000
#
#                 감마지티피            흡연상태            음주여부       구강검진 수검여부
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        37.083030        1.614510        0.499932        0.403213
# std         50.047157        0.820289        0.499839        0.490543
# min          1.000000        1.000000        0.000000        0.000000
# 25%         16.000000        1.000000        0.000000        0.000000
# 50%         23.000000        1.000000        0.411819        0.000000
# 75%         39.000000        2.000000        1.000000        1.000000
# max        999.000000        3.000000        1.000000        1.000000
#
# [8 rows x 26 columns]

# %%
GJ_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
# 성별코드           1000000 non-null int64
# 연령대코드(5세단위)    1000000 non-null int64
# 시도코드           1000000 non-null int64
# 신장(5Cm단위)      1000000 non-null int64
# 체중(5Kg 단위)     1000000 non-null int64
# 허리둘레           1000000 non-null int64
# 시력(좌)          1000000 non-null float64
# 시력(우)          1000000 non-null float64
# 청력(좌)          1000000 non-null float64
# 청력(우)          1000000 non-null float64
# 수축기혈압          1000000 non-null int64
# 이완기혈압          1000000 non-null int64
# 식전혈당(공복혈당)     1000000 non-null int64
# 총콜레스테롤         1000000 non-null int64
# 트리글리세라이드       1000000 non-null int64
# HDL콜레스테롤       1000000 non-null int64
# LDL콜레스테롤       1000000 non-null float64
# 혈색소            1000000 non-null float64
# 요단백            1000000 non-null float64
# 혈청크레아티닌        1000000 non-null float64
# (혈청지오티)AST     1000000 non-null int64
# (혈청지오티)ALT     1000000 non-null int64
# 감마지티피          1000000 non-null int64
# 흡연상태           1000000 non-null float64
# 음주여부           1000000 non-null float64
# 구강검진 수검여부      1000000 non-null int64
# dtypes: float64(10), int64(16)
# memory usage: 198.4 MB

# %%
GJ_2015 = GJ_2015.rename(columns = {'성별코드' : 'sex',
                    '연령대코드(5세단위)' : 'year',
                    '시도코드' : 'sido',
                    '신장(5Cm단위)' : 'height',
                    '체중(5Kg 단위)' : 'weight',
                    '허리둘레' : 'waist',
                    '시력(좌)' : 'sight_left',
                    '시력(우)' : 'sight_right',
                    '청력(좌)' : 'hearing_left',
                    '청력(우)' : 'hearing_right',
                    '수축기혈압' : 'SBP',
                    '이완기혈압' : 'RPBP',
                    '식전혈당(공복혈당)' : 'pred_blood_sugar',
                    '총콜레스테롤' : 'cholesterol',
                    '트리글리세라이드' : 'triglycerides',
                    'HDL콜레스테롤' : 'HDL',
                    'LDL콜레스테롤' : 'LDL',
                    '혈색소' : 'blood_pigment',
                    '요단백' : 'urine_protein',
                    '혈청크레아티닌' : 'serum_creatinine',
                    '(혈청지오티)AST' : 'AST',
                    '(혈청지오티)ALT' : 'ALT',
                    '감마지티피' : 'gamma_gtp',
                    '흡연상태' : 'smoking',
                    '음주여부' : 'alcohol',
                    '구강검진 수검여부' : 'oral_inspection'})

# 시각화에서 변수명 출력을 위해 영어로 변경

# %%
GJ_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
# sex                 1000000 non-null int64
# year                1000000 non-null int64
# sido                1000000 non-null int64
# height              1000000 non-null int64
# weight              1000000 non-null int64
# waist               1000000 non-null int64
# sight_left          1000000 non-null float64
# sight_right         1000000 non-null float64
# hearing_left        1000000 non-null float64
# hearing_right       1000000 non-null float64
# SBP                 1000000 non-null int64
# RPBP                1000000 non-null int64
# pred_blood_sugar    1000000 non-null int64
# cholesterol         1000000 non-null int64
# triglycerides       1000000 non-null int64
# HDL                 1000000 non-null int64
# LDL                 1000000 non-null float64
# blood_pigment       1000000 non-null float64
# urine_protein       1000000 non-null float64
# serum_creatinine    1000000 non-null float64
# AST                 1000000 non-null int64
# ALT                 1000000 non-null int64
# gamma_gtp           1000000 non-null int64
# smoking             1000000 non-null float64
# alcohol             1000000 non-null float64
# oral_inspection     1000000 non-null int64
# dtypes: float64(10), int64(16)
# memory usage: 198.4 MB

# %%
import matplotlib
import matplotlib.pyplot as plt

# 데이터 탐색을 위한 시각화 패키지 장착

# %%
plt.hist(GJ_2015['height'], histtype='bar', rwidth=0.9)
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
GJ_2015['pred_blood_sugar'] = np.where(GJ_2015['pred_blood_sugar'] >= 126, 1, 0)

# target 변수인 pred_blood_sugar가 126 이상일 때, 당뇨진단으로 판정
# 이분형 자료로 변환
# https://rfriend.tistory.com/tag/Python

# %%
GJ_2015['pred_blood_sugar'].value_counts()

# 당뇨진단자 비율 : 7 ~ 8 % 사이
# Out:
# 0    927585
# 1     72415
# Name: pred_blood_sugar, dtype: int64

# %%
plt.boxplot(GJ_2015['height'])
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
GJ_2015.hist(bins=50, figsize=(20,15))
plt.show()



# ALT / AST / HDL / LDL / RPBP / SBP / cholesterol / gamma_gtp / height / serum_creatinine / sight_left / sight_right -> skwed distribution
# triglycerides / urine_protein / waist / weight -> skwed distribution
# blood_pigment -> normal distribution
# alcohol / oral_inspection -> 이산형, 비교적 고른 분포
# hearing_left / hearing_right / smoking / pred_blood_sugar -> class unbalance
# sex / year / sido -> groupby 기준변수

# %%
GJ_2015.boxplot(figsize=(30,15))
plt.show()

# %% [markdown]
# # 이상치 처리
# 일반적으로 1) 표준점수로 변환 후 -3 이하 및 +3 제거 2) IQR 방식 3) 도메인 지식 이용하거나 Binning 처리하는 방식이 이용된다.
#
# 표준점수 이용할 경우 평균이 0, 표준편차가 1인 분포로 변환한후 +3 이상이거나 -3 이하인 경우 극단치로 처리한다.
#
# IQR 방식은 75% percentile * 1.5 이상이거나 25 percentile* 1.5 이하인 경우 극단치로 처리하는 방식이다.
# 이해하기 쉽고 적용하기 쉬운 편이지만, 경우에 따라 너무 많은 사례들이 극단치로 고려되는 경우가 있다.
#
# https://wikidocs.net/16582
#
# ![image.png](attachment:image.png)
#
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 3)
    upper_bound = quartile_3 + (iqr * 3)
    return np.where((ys > upper_bound) | (ys < lower_bound))

# %%
print(np.array(outliers_iqr(GJ_2015['height'])).shape[1],
      np.array(outliers_iqr(GJ_2015['weight'])).shape[1],
      np.array(outliers_iqr(GJ_2015['waist'])).shape[1],
      np.array(outliers_iqr(GJ_2015['sight_left'])).shape[1],
      np.array(outliers_iqr(GJ_2015['sight_right'])).shape[1],
      np.array(outliers_iqr(GJ_2015['SBP'])).shape[1],
      np.array(outliers_iqr(GJ_2015['RPBP'])).shape[1],
      np.array(outliers_iqr(GJ_2015['pred_blood_sugar'])).shape[1],
      np.array(outliers_iqr(GJ_2015['cholesterol'])).shape[1],
      np.array(outliers_iqr(GJ_2015['triglycerides'])).shape[1],
      np.array(outliers_iqr(GJ_2015['HDL'])).shape[1],
      np.array(outliers_iqr(GJ_2015['LDL'])).shape[1],
      np.array(outliers_iqr(GJ_2015['blood_pigment'])).shape[1],
      np.array(outliers_iqr(GJ_2015['serum_creatinine'])).shape[1],
      np.array(outliers_iqr(GJ_2015['AST'])).shape[1],
      np.array(outliers_iqr(GJ_2015['ALT'])).shape[1],
      np.array(outliers_iqr(GJ_2015['gamma_gtp'])).shape[1])

# Outer fence(바깥 울타리) 기준 심각한 이상치는 최소 22개를 가진 변수부터 최대 47179개를 가진 변수까지 있음
# gamma_gtp 변수의 OF 기준 이상치 제거할 경우, 데이터 손실율 약 4.7%
# 특정 연령, 성별, 시/도에 해당하는 범주의 경우, 이상치 비율이 많을 경우 문제 발생
# 이상치 제거 방법으로 IQR 정보를 이용하는 것이 바람직하지 않을 수 있음
# Out:
# 0 296 22 3442 3412 440 2061 72415 481 17115 874 395 215 2396 26407 29105 47179

# %% [markdown]
# 데이터 단위 변환
# 데이터의 스케일(측정단위)이 다를 경우 특히 거리를 기반으로 분류하는 모델(KNN 등)에 부정적인 영향을 미치므로, 스케일링을 통해 단위를 일정하게 맞추는 작업을 진행해야 한다. 아래 방식이 주로 스케일링을 위해 쓰이는 방법이다. 대부분의 통계 분석 방법이 정규성 가정을 기반으로 하므로 완벽하지 않더라도 최대한 정규분포로 변환하는 노력이 필요하다.
#
# Scaling: 평균이 0, 분산이 1인 분포로 변환
# MinMax Scaling: 특정 범위 (예, 0~1)로 모든 데이터를 변환
# Box-Cox: 여러 k 값중 가장 작은 SSE 선택
# Robust_scale: median, interquartile range 사용(outlier 영향 최소화)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# http://ko.logpresso.com/documents/anomaly-detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clf = IsolationForest(max_samples=1000, random_state=1, contamination=0.01, max_features=2)
# Isolation Forest 방법을 사용하기 위해, 변수로 선언을 해 준다.
# n_estimators=100 : 학습모형 100개
# max_samples=100 : 모형 당 최대 아웃라이어 갯수 1000개
# contamination='legacy' : 아웃라이어 비율 : 0.01(10000개)
# max_features=2 : 각 학습모형이 2개의 변수로 학습됨
# bootstrap=False : 각 학습모형이 샘플을 비복원 추출함
clf.fit(GJ_2015)
# fit 함수를 이용하여, 데이터셋을 학습
y_pred_outliers = clf.predict(GJ_2015)
# predict 함수를 이용하여, outlier를 판별. 0과 1로 이루어진 Series형태의 데이터가 나옴

out = pd.DataFrame(y_pred_outliers)
out = out.rename(columns={0: "out"})
GJ_2015 = pd.concat([GJ_2015, out], 1)
# 원래의 dataframe에 붙이기. 데이터가 0인 것이 outlier이기 때문에, 0인 것을 제거하면 outlier가 제거된 dataframe을 얻을 수 있음

# https://mkjjo.github.io/python/2019/01/10/outlier.html
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html
# Out:
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
GJ_2015['out'].value_counts()

# 10000개의 이상치를 detecting(label : -1)
# Out:
#  1    990000
# -1     10000
# Name: out, dtype: int64

# %%
GJ_2015=GJ_2015[GJ_2015['out']==1]

# %%
GJ_2015.boxplot(figsize=(30,15))
plt.show()

# %%
GJ_2015=GJ_2015[GJ_2015['LDL']<2000]

# Box-plot에서 불연속이면서 많은 값의 차이를 보이는 이상치 제거

# %%
GJ_2015.boxplot(figsize=(30,15))
plt.show()

# 불연속으로 많이 떨어진 이상치 제거

# %%
del GJ_2015['out']

# %%
GJ_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 989999 entries, 0 to 999999
# Data columns (total 26 columns):
# sex                 989999 non-null int64
# year                989999 non-null int64
# sido                989999 non-null int64
# height              989999 non-null int64
# weight              989999 non-null int64
# waist               989999 non-null int64
# sight_left          989999 non-null float64
# sight_right         989999 non-null float64
# hearing_left        989999 non-null float64
# hearing_right       989999 non-null float64
# SBP                 989999 non-null int64
# RPBP                989999 non-null int64
# pred_blood_sugar    989999 non-null int32
# cholesterol         989999 non-null int64
# triglycerides       989999 non-null int64
# HDL                 989999 non-null int64
# LDL                 989999 non-null float64
# blood_pigment       989999 non-null float64
# urine_protein       989999 non-null float64
# serum_creatinine    989999 non-null float64
# AST                 989999 non-null int64
# ALT                 989999 non-null int64
# gamma_gtp           989999 non-null int64
# smoking             989999 non-null float64
# alcohol             989999 non-null float64
# oral_inspection     989999 non-null int64
# dtypes: float64(10), int32(1), int64(15)
# memory usage: 200.2 MB

# %%
GJ_2015 = GJ_2015.rename(columns = {'height' : 'height_2015',
                    'weight' : 'weight_2015',
                    'waist' : 'waist_2015',
                    'sight_left' : 'sight_left_2015',
                    'sight_right' : 'sight_right_2015',
                    'hearing_left' : 'hearing_left_2015',
                    'hearing_right' : 'hearing_right_2015',
                    'SBP' : 'SBP_2015',
                    'RPBP' : 'RPBP_2015',
                    'cholesterol' : 'cholesterol_2015',
                    'triglycerides' : 'triglycerides_2015',
                    'HDL' : 'HDL_2015',
                    'LDL' : 'LDL_2015',
                    'blood_pigment' : 'blood_pigment_2015',
                    'urine_protein' : 'urine_protein_2015',
                    'serum_creatinine' : 'serum_creatinine_2015',
                    'AST' : 'AST_2015',
                    'ALT' : 'ALT_2015',
                    'gamma_gtp' : 'gamma_gtp_2015',
                    'smoking' : 'smoking_2015',
                    'alcohol' : 'alcohol_2015',
                    'oral_inspection' : 'oral_inspection_2015'})

# 2015년도 건강검진정보 예측변수(22개) rename

# %%
GJ_2015['target'] = GJ_2015['pred_blood_sugar']

# %%
del GJ_2015['pred_blood_sugar']

# %%
plt.hist(GJ_2015['target'], histtype='bar', rwidth=0.9)
plt.xlabel('pre_blood_sugar')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
GJ_2015_group = GJ_2015.groupby(['sex','year','sido']).mean()

# 시/도 그룹별 평균치를 저장

# %%
GJ_2015_group.reset_index(inplace=True)

# %%
GJ_2015_group

# 476개 범주를 가지는 자료형태로 변환
# dimension : 476x26
# Out:
#      sex  year  sido  height_2015  weight_2015  waist_2015  sight_left_2015  \
# 0      1     5    11   176.463861    73.860933   79.830741         1.058737
# 1      1     5    26   175.518092    73.207237   79.386513         1.080263
# 2      1     5    27   175.473485    72.935606   79.704545         1.110417
# 3      1     5    28   175.591398    72.826421   79.403994         1.094931
# 4      1     5    29   175.036765    70.808824   77.757353         1.137868
# 5      1     5    30   176.428571    73.918367   79.730612         1.093061
# 6      1     5    31   175.282776    72.043702   79.408740         1.045244
# 7      1     5    36   176.750000    71.750000   76.700000         1.245000
# 8      1     5    41   175.277991    72.691718   79.213957         1.118259
# 9      1     5    42   176.630435    75.054348   80.267391         1.136522
# 10     1     5    43   175.840909    72.181818   78.740909         1.151818
# 11     1     5    44   175.195473    70.740741   78.456790         1.131276
# 12     1     5    45   175.443350    73.682266   80.130542         1.145320
# 13     1     5    46   175.332326    71.827795   78.356495         1.164955
# 14     1     5    47   174.941003    71.902655   79.078171         1.118142
# 15     1     5    48   175.171265    72.345385   79.013321         1.090953
# 16     1     5    49   175.600000    73.500000   80.370000         1.015000
# 17     1     6    11   177.041166    76.363636   82.371450         1.088908
# 18     1     6    26   176.146030    75.997164   82.329868         1.092533
# 19     1     6    27   176.084788    76.156484   82.763092         1.106047
# 20     1     6    28   176.223639    75.701324   82.023541         1.118302
# 21     1     6    29   176.303100    75.516648   81.863375         1.132491
# 22     1     6    30   176.997919    76.415193   82.502601         1.129032
# 23     1     6    31   175.993998    75.097524   81.755439         1.091823
# 24     1     6    36   175.982143    74.508929   81.839286         1.193750
# 25     1     6    41   175.844636    75.373250   82.093285         1.121945
# 26     1     6    42   176.308213    77.459780   82.615580         1.165961
# 27     1     6    43   176.101449    75.184783   81.821014         1.162681
# 28     1     6    44   175.502092    74.916318   82.265167         1.151987
# 29     1     6    45   175.995726    75.111111   81.841026         1.165556
# ..   ...   ...   ...          ...          ...         ...              ...
# 446    2    17    29   151.536145    56.475904   82.686747         0.594578
# 447    2    17    30   150.182482    55.036496   83.072993         0.797080
# 448    2    17    31   151.011236    55.730337   81.741573         0.617978
# 449    2    17    36   150.000000    54.761905   82.428571         0.552381
# 450    2    17    41   150.939850    55.839599   83.684211         0.636424
# 451    2    17    42   149.650838    54.455307   81.720670         0.723184
# 452    2    17    43   149.812139    53.930636   81.722543         0.648844
# 453    2    17    44   149.270000    52.390000   81.052000         0.628400
# 454    2    17    45   149.481132    53.311321   80.856604         0.606226
# 455    2    17    46   150.126783    52.337559   80.399366         0.604279
# 456    2    17    47   149.568345    52.604317   80.148201         0.676835
# 457    2    17    48   150.212766    52.828014   80.072695         0.728369
# 458    2    17    49   151.421053    56.105263   81.347368         0.609474
# 459    2    18    11   150.153061    51.556122   81.632653         0.687644
# 460    2    18    26   150.886076    54.303797   80.886076         0.640506
# 461    2    18    27   150.744681    52.340426   80.680851         0.689362
# 462    2    18    28   151.090909    53.818182   82.745455         0.812727
# 463    2    18    29   149.756098    52.073171   78.951220         0.724390
# 464    2    18    30   149.883721    51.046512   79.534884         0.500000
# 465    2    18    31   148.214286    53.214286   84.857143         0.542857
# 466    2    18    36   150.000000    55.000000   81.000000         0.700000
# 467    2    18    41   149.417808    51.592466   81.849315         0.538822
# 468    2    18    42   147.666667    51.571429   81.228571         0.530476
# 469    2    18    43   147.786885    47.377049   76.049180         0.747541
# 470    2    18    44   148.938053    48.982301   79.150442         0.407080
# 471    2    18    45   147.991071    50.000000   79.178571         0.519062
# 472    2    18    46   149.815951    50.920245   80.957055         0.535583
# 473    2    18    47   147.446809    48.546099   77.496454         0.597872
# 474    2    18    48   149.234234    49.369369   77.684685         0.442342
# 475    2    18    49   149.821429    51.428571   80.107143         0.509388
#
#      sight_right_2015  hearing_left_2015  hearing_right_2015  ...  \
# 0            1.058554           1.003660            1.000915  ...
# 1            1.063816           1.000000            1.000000  ...
# 2            1.104735           1.007576            1.009470  ...
# 3            1.084485           1.004608            1.004608  ...
# 4            1.144118           1.007353            1.003676  ...
# 5            1.061633           1.000000            1.004082  ...
# 6            1.030334           1.000000            1.000000  ...
# 7            1.030000           1.000000            1.000000  ...
# 8            1.111392           1.006137            1.005754  ...
# 9            1.122609           1.002174            1.002174  ...
# 10           1.118864           1.009091            1.006818  ...
# 11           1.133333           1.000000            1.002058  ...
# 12           1.116749           1.002463            1.002463  ...
# 13           1.145921           1.006042            1.006042  ...
# 14           1.129499           1.002950            1.005900  ...
# 15           1.087524           1.002857            1.004762  ...
# 16           1.083000           1.000000            1.000000  ...
# 17           1.084124           1.001715            1.001906  ...
# 18           1.078544           1.005198            1.002836  ...
# 19           1.114027           1.003117            1.001870  ...
# 20           1.115947           1.002944            1.001472  ...
# 21           1.139610           1.004592            1.004592  ...
# 22           1.119459           1.002081            1.002081  ...
# 23           1.089872           1.004501            1.001500  ...
# 24           1.171429           1.000000            1.000000  ...
# 25           1.118339           1.003087            1.002647  ...
# 26           1.159272           1.001693            1.000847  ...
# 27           1.141957           1.002899            1.002899  ...
# 28           1.140115           1.003138            1.004184  ...
# 29           1.135128           1.001709            1.000855  ...
# ..                ...                ...                 ...  ...
# 446          0.667470           1.198795            1.228916  ...
# 447          0.798540           1.182482            1.204380  ...
# 448          0.629213           1.213483            1.224719  ...
# 449          0.547619           1.190476            1.047619  ...
# 450          0.700919           1.138680            1.135338  ...
# 451          0.711453           1.134078            1.117318  ...
# 452          0.810116           1.173410            1.156069  ...
# 453          0.726200           1.128000            1.136000  ...
# 454          0.634151           1.077358            1.083019  ...
# 455          0.576387           1.099842            1.106181  ...
# 456          0.658417           1.152518            1.138129  ...
# 457          0.708688           1.163469            1.147482  ...
# 458          0.830526           1.136842            1.136842  ...
# 459          0.613288           1.160751            1.160862  ...
# 460          0.864557           1.177215            1.164557  ...
# 461          0.665957           1.170213            1.170213  ...
# 462          0.649091           1.218182            1.218182  ...
# 463          0.743902           1.170732            1.146341  ...
# 464          0.516279           1.232558            1.139535  ...
# 465          0.500000           1.214286            1.142857  ...
# 466          0.500000           1.500000            1.500000  ...
# 467          0.716239           1.174658            1.174658  ...
# 468          0.433333           1.152381            1.142857  ...
# 469          0.772131           1.114754            1.131148  ...
# 470          0.694690           1.115044            1.141593  ...
# 471          0.537418           1.133929            1.125000  ...
# 472          0.488344           1.110429            1.104294  ...
# 473          0.602837           1.092199            1.106383  ...
# 474          0.449550           1.189189            1.216216  ...
# 475          0.827857           1.115306            1.115306  ...
#
#      blood_pigment_2015  urine_protein_2015  serum_creatinine_2015   AST_2015  \
# 0             15.545746            1.064044               0.960659  23.192132
# 1             15.363651            1.059211               0.955921  24.069079
# 2             15.360985            1.041667               0.960985  22.912879
# 3             15.507373            1.061444               0.966820  23.875576
# 4             15.524265            1.055147               0.939338  22.433824
# 5             15.543673            1.057143               0.973878  22.959184
# 6             15.380977            1.028278               0.930334  22.601542
# 7             15.255000            1.000000               0.885000  40.850000
# 8             15.562500            1.038727               0.970897  24.430215
# 9             15.726304            1.032609               0.972174  24.341304
# 10            15.551136            1.027340               0.987273  24.318182
# 11            15.588066            1.049383               0.950206  23.915638
# 12            15.596305            1.027094               0.955665  24.733990
# 13            15.331722            1.030211               0.981269  24.151057
# 14            15.459587            1.025115               0.971239  23.380531
# 15            15.329781            1.030447               0.949477  24.271170
# 16            15.574000            1.040400               0.946000  24.320000
# 17            15.535639            1.055173               0.991252  24.768249
# 18            15.483318            1.051512               0.958365  25.393195
# 19            15.442643            1.034957               0.977618  25.107232
# 20            15.623001            1.053021               0.983914  24.592938
# 21            15.453387            1.036786               0.954305  25.979334
# 22            15.494901            1.051048               0.965036  24.738814
# 23            15.365416            1.035259               0.932708  24.776444
# 24            15.666071            1.044643               0.962500  24.205357
# 25            15.566832            1.043361               0.965277  25.333333
# 26            15.709483            1.033870               0.994073  26.145639
# 27            15.536377            1.023931               0.978406  25.173188
# 28            15.614540            1.045006               0.993619  24.706067
# 29            15.517265            1.035043               0.965299  25.787179
# ..                  ...                 ...                    ...        ...
# 446           12.469880            1.128988               0.880120  23.939759
# 447           12.559854            1.075268               0.827007  25.591241
# 448           12.240449            1.114908               0.843820  24.258427
# 449           12.733333            1.190476               0.804762  22.714286
# 450           12.736926            1.136254               0.899081  24.820384
# 451           12.594413            1.074239               0.877374  24.159218
# 452           12.666474            1.104511               0.845954  24.421965
# 453           12.464200            1.103407               0.815800  24.112000
# 454           12.138679            1.056347               0.865660  23.994340
# 455           11.963550            1.101390               0.849762  25.047544
# 456           12.411655            1.108166               0.817554  23.976978
# 457           12.129433            1.119002               0.843440  23.625887
# 458           12.762105            1.032122               0.866316  24.315789
# 459           12.290306            1.165644               0.875510  24.352041
# 460           12.275949            1.101266               0.892405  25.822785
# 461           12.068085            1.106383               1.031915  24.468085
# 462           12.518182            1.266667               0.865455  24.145455
# 463           12.060976            1.010379               0.831707  22.878049
# 464           12.123256            1.097753               0.867442  22.581395
# 465           12.564286            1.000000               0.807143  22.642857
# 466           11.900000            1.000000               0.750000  14.000000
# 467           12.405137            1.172210               0.901712  22.934932
# 468           12.433333            1.150413               0.912381  22.866667
# 469           12.077049            1.053734               0.818033  25.426230
# 470           12.400885            1.041298               0.838938  24.566372
# 471           11.773214            1.130727               0.966071  22.375000
# 472           11.876687            1.067090               0.860736  25.159509
# 473           12.070213            1.077565               0.821986  23.120567
# 474           11.853153            1.102650               0.858559  22.891892
# 475           12.957143            1.042857               0.882143  24.285714
#
#       ALT_2015  gamma_gtp_2015  smoking_2015  alcohol_2015  \
# 0    23.237877       26.827996      2.008234      0.266063
# 1    23.728618       25.837171      2.026316      0.291118
# 2    23.047348       25.526515      2.058830      0.320681
# 3    24.574501       28.030722      2.109063      0.325653
# 4    21.327206       25.176471      2.102941      0.290441
# 5    23.714286       27.787755      2.073469      0.244898
# 6    20.131105       22.699229      2.205656      0.231362
# 7    33.150000       24.050000      2.150000      0.250000
# 8    24.353144       28.130368      1.963945      0.333844
# 9    24.260870       27.330435      2.273913      0.280435
# 10   23.336364       28.213636      2.093182      0.238636
# 11   24.074074       26.358025      2.074074      0.323045
# 12   24.396552       25.103448      2.093596      0.327586
# 13   23.268882       27.480363      1.963746      0.320242
# 14   23.526549       27.653392      2.032448      0.320059
# 15   23.729781       25.989534      2.038059      0.359657
# 16   23.660000       27.700000      1.870000      0.280000
# 17   27.162760       32.925481      1.946983      0.201869
# 18   28.327505       34.586484      2.049149      0.228733
# 19   28.858479       33.943890      2.020587      0.250780
# 20   27.911721       36.052967      2.060814      0.231486
# 21   29.979334       36.487945      2.024110      0.254024
# 22   28.995838       34.746098      2.002081      0.217482
# 23   26.085521       31.524381      2.042761      0.232558
# 24   27.785714       30.401786      1.839286      0.223214
# 25   28.852134       35.781343      1.995589      0.253695
# 26   29.057578       35.559695      2.143099      0.236240
# 27   28.489130       35.622464      2.031159      0.223188
# 28   27.866632       34.566423      2.030350      0.248954
# 29   28.346154       33.695726      2.019676      0.283147
# ..         ...             ...           ...           ...
# 446  18.680723       22.686747      1.036145      0.975904
# 447  18.919708       20.890511      1.029197      0.970803
# 448  16.719101       20.584270      1.011236      0.988764
# 449  14.952381       15.476190      1.142857      1.000000
# 450  18.690894       23.076023      1.032581      0.967419
# 451  17.525140       22.963687      1.016760      0.972067
# 452  17.132948       23.043353      1.037802      0.965104
# 453  16.674000       20.258000      1.032000      0.964000
# 454  16.716981       21.175472      1.026415      0.971698
# 455  17.729002       21.763867      1.012678      0.949287
# 456  17.716547       20.736691      1.037410      0.969784
# 457  16.726950       22.322695      1.042553      0.952128
# 458  17.368421       21.463158      1.021053      0.989474
# 459  16.265306       20.729592      1.035714      0.984694
# 460  16.265823       23.063291      1.000000      0.962025
# 461  17.021277       23.361702      1.106383      0.957447
# 462  16.090909       18.781818      1.036364      1.000000
# 463  17.926829       22.268293      1.048780      0.951220
# 464  17.139535       20.093023      1.000000      0.976744
# 465  14.142857       25.785714      1.000000      0.928571
# 466  10.500000       19.000000      1.000000      1.000000
# 467  15.304795       19.958904      1.037671      0.972508
# 468  15.200000       19.704762      1.028571      0.961905
# 469  15.819672       20.836066      1.065574      1.000000
# 470  14.920354       20.238938      1.026549      0.964602
# 471  14.526786       18.500000      1.044643      0.982143
# 472  16.257669       19.527607      1.012270      0.975460
# 473  14.893617       18.893617      1.028369      0.978723
# 474  13.747748       19.684685      1.081081      0.981982
# 475  17.464286       21.250000      1.000000      1.000000
#
#      oral_inspection_2015    target
# 0                0.559012  0.003660
# 1                0.560855  0.006579
# 2                0.401515  0.003788
# 3                0.698925  0.004608
# 4                0.566176  0.011029
# 5                0.689796  0.008163
# 6                0.478149  0.007712
# 7                0.550000  0.000000
# 8                0.569402  0.006902
# 9                0.736957  0.002174
# 10               0.613636  0.004545
# 11               0.635802  0.006173
# 12               0.655172  0.012315
# 13               0.507553  0.003021
# 14               0.550147  0.002950
# 15               0.428164  0.009515
# 16               0.440000  0.000000
# 17               0.588146  0.008957
# 18               0.516068  0.006144
# 19               0.389027  0.008105
# 20               0.665522  0.010299
# 21               0.535017  0.017222
# 22               0.650364  0.011446
# 23               0.683421  0.009002
# 24               0.705357  0.008929
# 25               0.604477  0.009152
# 26               0.649450  0.007621
# 27               0.647101  0.010145
# 28               0.680439  0.013075
# 29               0.596581  0.008547
# ..                    ...       ...
# 446              0.283133  0.168675
# 447              0.240876  0.153285
# 448              0.292135  0.089888
# 449              0.095238  0.047619
# 450              0.142022  0.131997
# 451              0.148045  0.114525
# 452              0.187861  0.086705
# 453              0.080000  0.100000
# 454              0.198113  0.133962
# 455              0.044374  0.106181
# 456              0.060432  0.125180
# 457              0.079787  0.113475
# 458              0.200000  0.084211
# 459              0.122449  0.096939
# 460              0.139241  0.139241
# 461              0.127660  0.170213
# 462              0.181818  0.109091
# 463              0.073171  0.195122
# 464              0.116279  0.046512
# 465              0.214286  0.285714
# 466              0.000000  0.000000
# 467              0.113014  0.116438
# 468              0.076190  0.114286
# 469              0.016393  0.147541
# 470              0.008850  0.097345
# 471              0.160714  0.107143
# 472              0.024540  0.110429
# 473              0.007092  0.106383
# 474              0.054054  0.144144
# 475              0.107143  0.071429
#
# [476 rows x 26 columns]

# %%
GJ_2015_group.to_csv("GJ_2015_group.csv")

# 2017년 건강검진정보 데이터전처리 -> 476개 범주화된 자료를 csv로 저장
# https://tariat.tistory.com/583

# %%
# 척도화
# https://mkjjo.github.io/python/2019/01/10/scaler.html

# 데이터 분할
# https://pythonanalysis.tistory.com/7

# 데이터 분포 변환
# https://wikidocs.net/16582
