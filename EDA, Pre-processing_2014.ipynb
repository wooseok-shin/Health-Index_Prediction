# %% [markdown]
# # 데이터 불러오기 및 전처리

# %%
import pandas as pd
import numpy as np

# 데이터 전처리에 필요한 패키지 장착

# %%
GJ_2014=pd.read_csv("./NHIS_OPEN_GJ_2014.csv",encoding='CP949') # 데이터 불러오기
GJ_2014.head() # 데이터 일부 확인
# Out:
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0  2014        1     1            6    42        180          75    79    1.5
# 1  2014        2     2           18    41        150          65    79    0.1
# 2  2014        3     1           12    41        170          70    95    0.8
# 3  2014        4     2           11    41        165          80   104    0.8
# 4  2014        5     1            6    44        175          75    81    1.5
#
#    시력(우)  ...  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부  \
# 0    1.2  ...      1.2          31          18     23   3.0   0.0          1
# 1    0.1  ...      0.8          11           4     15   1.0   1.0          0
# 2    1.0  ...      0.6         138          73    112   3.0   1.0          1
# 3    0.2  ...      0.9          19          14     21   1.0   0.0          1
# 4    1.5  ...      1.0          32          39     98   1.0   1.0          1
#
#    치아우식증유무  치석유무  데이터 기준일자
# 0      0.0   0.0  20161220
# 1      NaN   NaN  20161220
# 2      0.0   1.0  20161220
# 3      0.0   1.0  20161220
# 4      NaN   1.0  20161220
#
# [5 rows x 31 columns]

# %%
GJ_2014.shape # 데이터 차원 : 1000000 x 31
# Out:
# (1000000, 31)

# %%
GJ_2014.info() # 34개 변수 타입 : 정수형 또는 실수형
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 31 columns):
# 기준년도           1000000 non-null int64
# 가입자일련번호        1000000 non-null int64
# 성별코드           1000000 non-null int64
# 연령대코드(5세단위)    1000000 non-null int64
# 시도코드           1000000 non-null int64
# 신장(5Cm단위)      1000000 non-null int64
# 체중(5Kg 단위)     1000000 non-null int64
# 허리둘레           1000000 non-null int64
# 시력(좌)          999838 non-null float64
# 시력(우)          999840 non-null float64
# 청력(좌)          999863 non-null float64
# 청력(우)          999866 non-null float64
# 수축기혈압          1000000 non-null int64
# 이완기혈압          1000000 non-null int64
# 식전혈당(공복혈당)     1000000 non-null int64
# 총콜레스테롤         1000000 non-null int64
# 트리글리세라이드       1000000 non-null int64
# HDL콜레스테롤       1000000 non-null int64
# LDL콜레스테롤       995758 non-null float64
# 혈색소            1000000 non-null float64
# 요단백            995661 non-null float64
# 혈청크레아티닌        1000000 non-null float64
# (혈청지오티)AST     1000000 non-null int64
# (혈청지오티)ALT     1000000 non-null int64
# 감마지티피          1000000 non-null int64
# 흡연상태           999618 non-null float64
# 음주여부           999016 non-null float64
# 구강검진 수검여부      1000000 non-null int64
# 치아우식증유무        110048 non-null float64
# 치석유무           382722 non-null float64
# 데이터 기준일자       1000000 non-null int64
# dtypes: float64(12), int64(19)
# memory usage: 236.5 MB

# %%
GJ_2014.isna().sum()

# 결측치가 있는 변수 : 시력좌/시력우/청력좌/청력우
# 결측치가 있는 변수 : LDL/요단백/흡연상태/음주여부
# 결측치가 있는 변수 : 치아우식증유무/치석유무
# Out:
# 기준년도                0
# 가입자일련번호             0
# 성별코드                0
# 연령대코드(5세단위)         0
# 시도코드                0
# 신장(5Cm단위)           0
# 체중(5Kg 단위)          0
# 허리둘레                0
# 시력(좌)             162
# 시력(우)             160
# 청력(좌)             137
# 청력(우)             134
# 수축기혈압               0
# 이완기혈압               0
# 식전혈당(공복혈당)          0
# 총콜레스테롤              0
# 트리글리세라이드            0
# HDL콜레스테롤            0
# LDL콜레스테롤         4242
# 혈색소                 0
# 요단백              4339
# 혈청크레아티닌             0
# (혈청지오티)AST          0
# (혈청지오티)ALT          0
# 감마지티피               0
# 흡연상태              382
# 음주여부              984
# 구강검진 수검여부           0
# 치아우식증유무        889952
# 치석유무           617278
# 데이터 기준일자            0
# dtype: int64

# %%
GJ_2014=GJ_2014.drop(['치아우식증유무','치석유무'],axis=1)

# 결측비율이 약 90%인 '치아우식증유무' 변수와 결측비율이 약 60%인 치석유무 변수 제거

# %%
GJ_2014.shape # 2개의 변수가 제거됨
# Out:
# (1000000, 29)

# %%
GJ_2014.describe()

# 영-분산에 해당하는 변수 : 기준년도/데이터 기준일자
# Out:
#             기준년도         가입자일련번호            성별코드     연령대코드(5세단위)  \
# count  1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean      2014.0   500000.500000        1.457211       10.337172
# std          0.0   288675.278933        0.498166        2.819087
# min       2014.0        1.000000        1.000000        5.000000
# 25%       2014.0   250000.750000        1.000000        8.000000
# 50%       2014.0   500000.500000        1.000000       10.000000
# 75%       2014.0   750000.250000        2.000000       12.000000
# max       2014.0  1000000.000000        2.000000       18.000000
#
#                  시도코드       신장(5Cm단위)      체중(5Kg 단위)            허리둘레  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        33.627936      166.307190       66.610625       80.516598
# std         12.721441        9.335261       12.181895        9.329093
# min         11.000000      130.000000       30.000000       51.000000
# 25%         26.000000      160.000000       60.000000       74.000000
# 50%         41.000000      165.000000       65.000000       81.000000
# 75%         44.000000      175.000000       75.000000       87.000000
# max         49.000000      195.000000      140.000000      129.000000
#
#                시력(좌)          시력(우)  ...             혈색소            요단백  \
# count  999838.000000  999840.000000  ...  1000000.000000  995661.000000
# mean        0.984893       0.981145  ...       14.118909       1.079945
# std         0.631128       0.622700  ...        1.634710       0.401875
# min         0.100000       0.100000  ...        0.100000       1.000000
# 25%         0.700000       0.700000  ...       13.000000       1.000000
# 50%         1.000000       1.000000  ...       14.200000       1.000000
# 75%         1.200000       1.200000  ...       15.300000       1.000000
# max         9.900000       9.900000  ...       23.700000       6.000000
#
#               혈청크레아티닌      (혈청지오티)AST      (혈청지오티)ALT           감마지티피  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.886300       25.400075       25.071998       36.413858
# std          0.665678       15.863441       20.954440       49.121305
# min          0.100000        1.000000        1.000000        1.000000
# 25%          0.700000       19.000000       14.000000       15.000000
# 50%          0.900000       22.000000       20.000000       23.000000
# 75%          1.000000       28.000000       29.000000       39.000000
# max         98.000000      999.000000      999.000000      999.000000
#
#                 흡연상태           음주여부       구강검진 수검여부    데이터 기준일자
# count  999618.000000  999016.000000  1000000.000000   1000000.0
# mean        1.635798       0.502629        0.405838  20161220.0
# std         0.838917       0.499993        0.491054         0.0
# min         1.000000       0.000000        0.000000  20161220.0
# 25%         1.000000       0.000000        0.000000  20161220.0
# 50%         1.000000       1.000000        0.000000  20161220.0
# 75%         2.000000       1.000000        1.000000  20161220.0
# max         3.000000       1.000000        1.000000  20161220.0
#
# [8 rows x 29 columns]

# %%
GJ_2014=GJ_2014.drop(['기준년도','데이터 기준일자'],axis=1)

# 영-분산을 가지는 2개의 변수를 제거

# %%
GJ_2014.shape # 2개의 변수가 제거됨
# Out:
# (1000000, 27)

# %%
GJ_2014

# '가입자일련번호-1'와 index가 일치함
# Out:
#         가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0             1     1            6    42        180          75    79    1.5
# 1             2     2           18    41        150          65    79    0.1
# 2             3     1           12    41        170          70    95    0.8
# 3             4     2           11    41        165          80   104    0.8
# 4             5     1            6    44        175          75    81    1.5
# 5             6     2           11    47        155          60    88    0.6
# 6             7     1           11    45        165          50    66    0.8
# 7             8     2           11    41        145          55    93    0.9
# 8             9     2           18    41        140          35    78    0.2
# 9            10     1            7    26        175          80    90    0.6
# 10           11     2           18    46        140          50    79    0.1
# 11           12     2           18    44        145          40    67    0.5
# 12           13     1            7    29        170          65    83    1.5
# 13           14     1           18    46        165          60    63    0.1
# 14           15     1           18    41        160          45    63    0.5
# 15           16     2            6    47        155          50    66    1.2
# 16           17     2            6    48        165          40    59    0.7
# 17           18     2           16    46        145          45    74    0.5
# 18           19     2           18    44        130          35    68    0.3
# 19           20     1            5    45        175          70    77    1.5
# 20           21     2           18    47        140          45    76    0.1
# 21           22     2           18    47        145          45    75    0.1
# 22           23     1           18    44        170          65    88    0.6
# 23           24     2            7    47        155          60    88    1.5
# 24           25     1            6    26        175          70    78    1.5
# 25           26     2           13    43        165          65    88    0.7
# 26           27     2           18    11        150          65    95    0.4
# 27           28     2           18    41        155          60    86    0.6
# 28           29     1            9    11        175          80    92    1.2
# 29           30     2           11    26        155          70    84    0.7
# ...         ...   ...          ...   ...        ...         ...   ...    ...
# 999970   999971     1           11    43        170          75    85    0.5
# 999971   999972     1            7    11        185          70    70    0.5
# 999972   999973     1            6    41        175          70    72    0.2
# 999973   999974     2           10    44        150          55    76    0.9
# 999974   999975     1            8    43        180          70    93    1.2
# 999975   999976     1            6    42        175          80    89    1.5
# 999976   999977     1           10    11        160          55    68    1.5
# 999977   999978     1            7    11        170          70    80    0.5
# 999978   999979     2           10    49        160          80    86    1.0
# 999979   999980     1            7    41        170          70    82    2.0
# 999980   999981     1            6    44        165          50    68    1.0
# 999981   999982     2           10    44        160          65    87    0.8
# 999982   999983     1            5    47        180          75    73    1.0
# 999983   999984     1           14    11        170          55    71    0.8
# 999984   999985     2           10    36        165          70    82    1.2
# 999985   999986     1            8    41        180          80    90    1.0
# 999986   999987     1            5    45        165          60    78    1.5
# 999987   999988     2            5    45        170          60    71    1.5
# 999988   999989     1            6    41        165          65    74    1.5
# 999989   999990     2           14    11        150          65    93    0.9
# 999990   999991     1            6    41        165          75    85    1.0
# 999991   999992     1            6    28        175          70    81    0.6
# 999992   999993     1            7    41        170          75    82    0.8
# 999993   999994     2            6    27        160          55    73    1.2
# 999994   999995     1           13    11        170          60    80    0.7
# 999995   999996     2           12    11        160          55    75    1.2
# 999996   999997     2            9    11        150          45    59    1.0
# 999997   999998     2            8    43        165          50    68    0.4
# 999998   999999     2           10    11        160          60    77    1.0
# 999999  1000000     1           11    43        160          80    94    1.2
#
#         시력(우)  청력(좌)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0         1.2    1.0  ...      96.0  15.9  1.0      1.2          31
# 1         0.1    1.0  ...     106.0  10.6  1.0      0.8          11
# 2         1.0    1.0  ...     109.0  11.5  3.0      0.6         138
# 3         0.2    1.0  ...     189.0  13.5  1.0      0.9          19
# 4         1.5    1.0  ...     111.0  14.4  1.0      1.0          32
# 5         0.8    1.0  ...     102.0  12.9  1.0      0.7          25
# 6         0.9    1.0  ...     176.0  14.3  1.0      1.0          21
# 7         0.9    2.0  ...     163.0  14.9  1.0      1.2          34
# 8         0.1    1.0  ...      98.0  10.9  1.0      0.5          30
# 9         0.4    1.0  ...      94.0  14.9  1.0      0.7          25
# 10        0.1    1.0  ...     162.0  11.6  1.0      0.6          19
# 11        0.5    1.0  ...      66.0  12.4  1.0      0.6          21
# 12        1.5    1.0  ...     129.0  16.2  1.0      0.9          34
# 13        9.9    1.0  ...      98.0  12.8  NaN      0.8          28
# 14        9.9    1.0  ...     150.0  15.1  1.0      0.9          24
# 15        1.2    1.0  ...     102.0  13.4  1.0      0.8          15
# 16        0.8    1.0  ...      74.0  13.7  1.0      0.9          20
# 17        0.2    2.0  ...     116.0  10.6  1.0      1.1          23
# 18        0.3    1.0  ...     107.0  10.8  1.0      0.8          21
# 19        1.5    1.0  ...      74.0  15.7  1.0      0.9          14
# 20        0.1    1.0  ...      71.0  10.2  NaN      0.7          40
# 21        0.2    1.0  ...     115.0  10.8  1.0      0.6          20
# 22        0.6    2.0  ...      70.0  13.1  1.0      1.2          21
# 23        1.5    1.0  ...     112.0  13.3  1.0      0.5          19
# 24        1.2    1.0  ...      77.0  15.1  1.0      0.9          19
# 25        0.9    1.0  ...      61.0  14.3  1.0      0.6          20
# 26        0.3    1.0  ...     193.0  14.4  1.0      0.9          24
# 27        0.6    1.0  ...     131.0  12.6  3.0      1.1          18
# 28        1.2    1.0  ...     112.0  14.7  1.0      1.0          20
# 29        0.7    1.0  ...      82.0  12.8  1.0      0.9          37
# ...       ...    ...  ...       ...   ...  ...      ...         ...
# 999970    1.0    1.0  ...      99.0  15.9  1.0      1.1          19
# 999971    0.6    1.0  ...      74.0  14.7  1.0      1.0          32
# 999972    0.4    1.0  ...      68.0  15.6  1.0      1.0          18
# 999973    1.0    1.0  ...     159.0  12.0  1.0      0.7          26
# 999974    0.9    1.0  ...      69.0  16.6  1.0      0.9          23
# 999975    1.5    1.0  ...     119.0  15.1  1.0      1.0          41
# 999976    0.7    1.0  ...      95.0  14.2  1.0      1.1          17
# 999977    0.8    1.0  ...      82.0  13.1  1.0      0.8          17
# 999978    1.2    1.0  ...      73.0  13.0  1.0      0.8          49
# 999979    1.5    1.0  ...     135.0  15.0  1.0      1.0          22
# 999980    0.9    1.0  ...     130.0  15.1  1.0      0.8          23
# 999981    0.9    1.0  ...      95.0  13.7  1.0      0.5          13
# 999982    0.9    1.0  ...      63.0  15.0  1.0      0.9          32
# 999983    0.8    1.0  ...     122.0  15.0  1.0      1.0          26
# 999984    0.7    1.0  ...      51.0  14.0  1.0      1.0          20
# 999985    0.9    1.0  ...     154.0  14.0  1.0      1.1          14
# 999986    1.2    1.0  ...      74.0  15.4  1.0      1.0          33
# 999987    1.5    1.0  ...     108.0  13.9  1.0      0.6          17
# 999988    1.5    1.0  ...      75.0  14.5  1.0      0.9          20
# 999989    0.3    1.0  ...     131.0  13.1  1.0      0.9          27
# 999990    0.7    1.0  ...     105.0  16.4  1.0      0.9          30
# 999991    1.2    1.0  ...     104.0  15.8  1.0      0.9          20
# 999992    1.2    1.0  ...     208.0  15.4  1.0      1.2          36
# 999993    1.0    1.0  ...     145.0  13.4  1.0      0.8          18
# 999994    0.8    1.0  ...     167.0  15.0  1.0      0.9          32
# 999995    1.2    1.0  ...     117.0  11.8  1.0      0.7          18
# 999996    1.2    1.0  ...      67.0  12.5  1.0      0.7          21
# 999997    0.4    1.0  ...     141.0  11.6  1.0      0.8          19
# 999998    1.0    1.0  ...     125.0  14.1  1.0      0.7          27
# 999999    1.2    1.0  ...      97.0  17.1  1.0      0.9          26
#
#         (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부
# 0               18     23   3.0   0.0          1
# 1                4     15   1.0   1.0          0
# 2               73    112   3.0   1.0          1
# 3               14     21   1.0   0.0          1
# 4               39     98   1.0   1.0          1
# 5               27     27   3.0   0.0          0
# 6                8     55   3.0   0.0          0
# 7               16    175   1.0   1.0          0
# 8               10     10   1.0   1.0          0
# 9               21     18   1.0   0.0          0
# 10               8     14   1.0   1.0          0
# 11              12     11   1.0   1.0          0
# 12              53     43   3.0   0.0          0
# 13              19     21   1.0   1.0          0
# 14              14     15   2.0   1.0          1
# 15              10     13   1.0   1.0          0
# 16              15     40   1.0   1.0          1
# 17              17     44   1.0   1.0          0
# 18               7     32   1.0   1.0          0
# 19               8     21   3.0   0.0          0
# 20              21     11   1.0   1.0          0
# 21              11     25   1.0   1.0          0
# 22              22     82   1.0   1.0          0
# 23              29     68   1.0   1.0          0
# 24              16     17   1.0   0.0          1
# 25              25     20   1.0   1.0          0
# 26              13     26   1.0   1.0          1
# 27              11     13   1.0   1.0          0
# 28              29     59   1.0   0.0          1
# 29              36     23   1.0   1.0          0
# ...            ...    ...   ...   ...        ...
# 999970          11     27   3.0   0.0          0
# 999971          15     12   3.0   0.0          0
# 999972          16     16   3.0   1.0          0
# 999973          17      8   1.0   1.0          0
# 999974          23     90   3.0   1.0          0
# 999975          33     31   1.0   1.0          0
# 999976          18     18   2.0   0.0          0
# 999977          15     17   1.0   1.0          0
# 999978          56     34   1.0   1.0          0
# 999979          14     60   3.0   0.0          0
# 999980          17     14   3.0   1.0          0
# 999981          10      8   1.0   0.0          0
# 999982          40     18   1.0   1.0          0
# 999983          20     31   2.0   1.0          0
# 999984          20     16   1.0   1.0          0
# 999985          18     53   3.0   1.0          0
# 999986          30     60   1.0   1.0          0
# 999987          10     20   1.0   1.0          0
# 999988          18     14   1.0   1.0          0
# 999989          43     48   1.0   1.0          0
# 999990          37     71   3.0   0.0          0
# 999991          19     12   1.0   1.0          0
# 999992          30     66   1.0   0.0          0
# 999993          17     14   1.0   1.0          0
# 999994          33    123   1.0   1.0          0
# 999995          18     12   1.0   1.0          0
# 999996          14     19   1.0   1.0          0
# 999997          14     14   1.0   1.0          0
# 999998          21     40   3.0   1.0          0
# 999999          27     31   3.0   0.0          0
#
# [1000000 rows x 27 columns]

# %%
GJ_2014.rename(index=GJ_2014['가입자일련번호'])
# index를 가입자 일련번호로 설정
# Out:
#          가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 1              1     1            6    42        180          75    79    1.5
# 2              2     2           18    41        150          65    79    0.1
# 3              3     1           12    41        170          70    95    0.8
# 4              4     2           11    41        165          80   104    0.8
# 5              5     1            6    44        175          75    81    1.5
# 6              6     2           11    47        155          60    88    0.6
# 7              7     1           11    45        165          50    66    0.8
# 8              8     2           11    41        145          55    93    0.9
# 9              9     2           18    41        140          35    78    0.2
# 10            10     1            7    26        175          80    90    0.6
# 11            11     2           18    46        140          50    79    0.1
# 12            12     2           18    44        145          40    67    0.5
# 13            13     1            7    29        170          65    83    1.5
# 14            14     1           18    46        165          60    63    0.1
# 15            15     1           18    41        160          45    63    0.5
# 16            16     2            6    47        155          50    66    1.2
# 17            17     2            6    48        165          40    59    0.7
# 18            18     2           16    46        145          45    74    0.5
# 19            19     2           18    44        130          35    68    0.3
# 20            20     1            5    45        175          70    77    1.5
# 21            21     2           18    47        140          45    76    0.1
# 22            22     2           18    47        145          45    75    0.1
# 23            23     1           18    44        170          65    88    0.6
# 24            24     2            7    47        155          60    88    1.5
# 25            25     1            6    26        175          70    78    1.5
# 26            26     2           13    43        165          65    88    0.7
# 27            27     2           18    11        150          65    95    0.4
# 28            28     2           18    41        155          60    86    0.6
# 29            29     1            9    11        175          80    92    1.2
# 30            30     2           11    26        155          70    84    0.7
# ...          ...   ...          ...   ...        ...         ...   ...    ...
# 999971    999971     1           11    43        170          75    85    0.5
# 999972    999972     1            7    11        185          70    70    0.5
# 999973    999973     1            6    41        175          70    72    0.2
# 999974    999974     2           10    44        150          55    76    0.9
# 999975    999975     1            8    43        180          70    93    1.2
# 999976    999976     1            6    42        175          80    89    1.5
# 999977    999977     1           10    11        160          55    68    1.5
# 999978    999978     1            7    11        170          70    80    0.5
# 999979    999979     2           10    49        160          80    86    1.0
# 999980    999980     1            7    41        170          70    82    2.0
# 999981    999981     1            6    44        165          50    68    1.0
# 999982    999982     2           10    44        160          65    87    0.8
# 999983    999983     1            5    47        180          75    73    1.0
# 999984    999984     1           14    11        170          55    71    0.8
# 999985    999985     2           10    36        165          70    82    1.2
# 999986    999986     1            8    41        180          80    90    1.0
# 999987    999987     1            5    45        165          60    78    1.5
# 999988    999988     2            5    45        170          60    71    1.5
# 999989    999989     1            6    41        165          65    74    1.5
# 999990    999990     2           14    11        150          65    93    0.9
# 999991    999991     1            6    41        165          75    85    1.0
# 999992    999992     1            6    28        175          70    81    0.6
# 999993    999993     1            7    41        170          75    82    0.8
# 999994    999994     2            6    27        160          55    73    1.2
# 999995    999995     1           13    11        170          60    80    0.7
# 999996    999996     2           12    11        160          55    75    1.2
# 999997    999997     2            9    11        150          45    59    1.0
# 999998    999998     2            8    43        165          50    68    0.4
# 999999    999999     2           10    11        160          60    77    1.0
# 1000000  1000000     1           11    43        160          80    94    1.2
#
#          시력(우)  청력(좌)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 1          1.2    1.0  ...      96.0  15.9  1.0      1.2          31
# 2          0.1    1.0  ...     106.0  10.6  1.0      0.8          11
# 3          1.0    1.0  ...     109.0  11.5  3.0      0.6         138
# 4          0.2    1.0  ...     189.0  13.5  1.0      0.9          19
# 5          1.5    1.0  ...     111.0  14.4  1.0      1.0          32
# 6          0.8    1.0  ...     102.0  12.9  1.0      0.7          25
# 7          0.9    1.0  ...     176.0  14.3  1.0      1.0          21
# 8          0.9    2.0  ...     163.0  14.9  1.0      1.2          34
# 9          0.1    1.0  ...      98.0  10.9  1.0      0.5          30
# 10         0.4    1.0  ...      94.0  14.9  1.0      0.7          25
# 11         0.1    1.0  ...     162.0  11.6  1.0      0.6          19
# 12         0.5    1.0  ...      66.0  12.4  1.0      0.6          21
# 13         1.5    1.0  ...     129.0  16.2  1.0      0.9          34
# 14         9.9    1.0  ...      98.0  12.8  NaN      0.8          28
# 15         9.9    1.0  ...     150.0  15.1  1.0      0.9          24
# 16         1.2    1.0  ...     102.0  13.4  1.0      0.8          15
# 17         0.8    1.0  ...      74.0  13.7  1.0      0.9          20
# 18         0.2    2.0  ...     116.0  10.6  1.0      1.1          23
# 19         0.3    1.0  ...     107.0  10.8  1.0      0.8          21
# 20         1.5    1.0  ...      74.0  15.7  1.0      0.9          14
# 21         0.1    1.0  ...      71.0  10.2  NaN      0.7          40
# 22         0.2    1.0  ...     115.0  10.8  1.0      0.6          20
# 23         0.6    2.0  ...      70.0  13.1  1.0      1.2          21
# 24         1.5    1.0  ...     112.0  13.3  1.0      0.5          19
# 25         1.2    1.0  ...      77.0  15.1  1.0      0.9          19
# 26         0.9    1.0  ...      61.0  14.3  1.0      0.6          20
# 27         0.3    1.0  ...     193.0  14.4  1.0      0.9          24
# 28         0.6    1.0  ...     131.0  12.6  3.0      1.1          18
# 29         1.2    1.0  ...     112.0  14.7  1.0      1.0          20
# 30         0.7    1.0  ...      82.0  12.8  1.0      0.9          37
# ...        ...    ...  ...       ...   ...  ...      ...         ...
# 999971     1.0    1.0  ...      99.0  15.9  1.0      1.1          19
# 999972     0.6    1.0  ...      74.0  14.7  1.0      1.0          32
# 999973     0.4    1.0  ...      68.0  15.6  1.0      1.0          18
# 999974     1.0    1.0  ...     159.0  12.0  1.0      0.7          26
# 999975     0.9    1.0  ...      69.0  16.6  1.0      0.9          23
# 999976     1.5    1.0  ...     119.0  15.1  1.0      1.0          41
# 999977     0.7    1.0  ...      95.0  14.2  1.0      1.1          17
# 999978     0.8    1.0  ...      82.0  13.1  1.0      0.8          17
# 999979     1.2    1.0  ...      73.0  13.0  1.0      0.8          49
# 999980     1.5    1.0  ...     135.0  15.0  1.0      1.0          22
# 999981     0.9    1.0  ...     130.0  15.1  1.0      0.8          23
# 999982     0.9    1.0  ...      95.0  13.7  1.0      0.5          13
# 999983     0.9    1.0  ...      63.0  15.0  1.0      0.9          32
# 999984     0.8    1.0  ...     122.0  15.0  1.0      1.0          26
# 999985     0.7    1.0  ...      51.0  14.0  1.0      1.0          20
# 999986     0.9    1.0  ...     154.0  14.0  1.0      1.1          14
# 999987     1.2    1.0  ...      74.0  15.4  1.0      1.0          33
# 999988     1.5    1.0  ...     108.0  13.9  1.0      0.6          17
# 999989     1.5    1.0  ...      75.0  14.5  1.0      0.9          20
# 999990     0.3    1.0  ...     131.0  13.1  1.0      0.9          27
# 999991     0.7    1.0  ...     105.0  16.4  1.0      0.9          30
# 999992     1.2    1.0  ...     104.0  15.8  1.0      0.9          20
# 999993     1.2    1.0  ...     208.0  15.4  1.0      1.2          36
# 999994     1.0    1.0  ...     145.0  13.4  1.0      0.8          18
# 999995     0.8    1.0  ...     167.0  15.0  1.0      0.9          32
# 999996     1.2    1.0  ...     117.0  11.8  1.0      0.7          18
# 999997     1.2    1.0  ...      67.0  12.5  1.0      0.7          21
# 999998     0.4    1.0  ...     141.0  11.6  1.0      0.8          19
# 999999     1.0    1.0  ...     125.0  14.1  1.0      0.7          27
# 1000000    1.2    1.0  ...      97.0  17.1  1.0      0.9          26
#
#          (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부
# 1                18     23   3.0   0.0          1
# 2                 4     15   1.0   1.0          0
# 3                73    112   3.0   1.0          1
# 4                14     21   1.0   0.0          1
# 5                39     98   1.0   1.0          1
# 6                27     27   3.0   0.0          0
# 7                 8     55   3.0   0.0          0
# 8                16    175   1.0   1.0          0
# 9                10     10   1.0   1.0          0
# 10               21     18   1.0   0.0          0
# 11                8     14   1.0   1.0          0
# 12               12     11   1.0   1.0          0
# 13               53     43   3.0   0.0          0
# 14               19     21   1.0   1.0          0
# 15               14     15   2.0   1.0          1
# 16               10     13   1.0   1.0          0
# 17               15     40   1.0   1.0          1
# 18               17     44   1.0   1.0          0
# 19                7     32   1.0   1.0          0
# 20                8     21   3.0   0.0          0
# 21               21     11   1.0   1.0          0
# 22               11     25   1.0   1.0          0
# 23               22     82   1.0   1.0          0
# 24               29     68   1.0   1.0          0
# 25               16     17   1.0   0.0          1
# 26               25     20   1.0   1.0          0
# 27               13     26   1.0   1.0          1
# 28               11     13   1.0   1.0          0
# 29               29     59   1.0   0.0          1
# 30               36     23   1.0   1.0          0
# ...             ...    ...   ...   ...        ...
# 999971           11     27   3.0   0.0          0
# 999972           15     12   3.0   0.0          0
# 999973           16     16   3.0   1.0          0
# 999974           17      8   1.0   1.0          0
# 999975           23     90   3.0   1.0          0
# 999976           33     31   1.0   1.0          0
# 999977           18     18   2.0   0.0          0
# 999978           15     17   1.0   1.0          0
# 999979           56     34   1.0   1.0          0
# 999980           14     60   3.0   0.0          0
# 999981           17     14   3.0   1.0          0
# 999982           10      8   1.0   0.0          0
# 999983           40     18   1.0   1.0          0
# 999984           20     31   2.0   1.0          0
# 999985           20     16   1.0   1.0          0
# 999986           18     53   3.0   1.0          0
# 999987           30     60   1.0   1.0          0
# 999988           10     20   1.0   1.0          0
# 999989           18     14   1.0   1.0          0
# 999990           43     48   1.0   1.0          0
# 999991           37     71   3.0   0.0          0
# 999992           19     12   1.0   1.0          0
# 999993           30     66   1.0   0.0          0
# 999994           17     14   1.0   1.0          0
# 999995           33    123   1.0   1.0          0
# 999996           18     12   1.0   1.0          0
# 999997           14     19   1.0   1.0          0
# 999998           14     14   1.0   1.0          0
# 999999           21     40   3.0   1.0          0
# 1000000          27     31   3.0   0.0          0
#
# [1000000 rows x 27 columns]

# %%
GJ_2014=GJ_2014.drop(['가입자일련번호'],axis=1)
# 가입자일련번호 변수 제거

# %%
GJ_2014.shape # 1개의 변수가 제거됨
# Out:
# (1000000, 26)

# %%
GJ_2014.isna().sum()

# 결측치가 있는 변수 : 시력좌/시력우/청력좌/청력우/LDL/요단백/흡연상태/음주여부
# Out:
# 성별코드              0
# 연령대코드(5세단위)       0
# 시도코드              0
# 신장(5Cm단위)         0
# 체중(5Kg 단위)        0
# 허리둘레              0
# 시력(좌)           162
# 시력(우)           160
# 청력(좌)           137
# 청력(우)           134
# 수축기혈압             0
# 이완기혈압             0
# 식전혈당(공복혈당)        0
# 총콜레스테롤            0
# 트리글리세라이드          0
# HDL콜레스테롤          0
# LDL콜레스테롤       4242
# 혈색소               0
# 요단백            4339
# 혈청크레아티닌           0
# (혈청지오티)AST        0
# (혈청지오티)ALT        0
# 감마지티피             0
# 흡연상태            382
# 음주여부            984
# 구강검진 수검여부         0
# dtype: int64

# %%
fill_mean_func = lambda g: g.fillna(g.mean())
GJ_2014=GJ_2014.groupby(['성별코드','연령대코드(5세단위)','시도코드']).apply(fill_mean_func)

# sex, age, sido 그룹별로 결측값 평균치 대체
# mean, median, mode 중 UE(비편향) 성질을 만족하는 평균값으로 대체
# 각 변수별로 이상치가 많으나, 데이터의 갯수가 충분히 확보(100만개)된 상태이므로, mean 사용
# 전반적으로 히스토그램이 우측 긴 꼬리의 형태를 나타내고 있으므로, 평균 > 중앙값 > 최빈값 순서를 따름
# https://rfriend.tistory.com/402 : 결측값을 그룹 평균값으로 채우기 (Fill missing values by Group means)
# 출처: https://rfriend.tistory.com/402 [R, Python 분석과 프로그래밍 (by R Friend)]

# %%
GJ_2014=GJ_2014.drop(['성별코드','연령대코드(5세단위)','시도코드'], axis=1)

# %%
GJ_2014.reset_index(inplace=True)

# 인덱스 초기화
# inplace=True : 객체 반환 x(결과물 안보이게 하기)
# https://nittaku.tistory.com/122

# %%
del GJ_2014['level_3']

# del health['변수명'] : 특정 변수 제거

# %%
GJ_2014.head()
# Out:
#    성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0     1            5    11        180         105   107    0.9    0.5    1.0
# 1     1            5    11        170          60    76    0.3    0.7    1.0
# 2     1            5    11        165          55    71    1.2    1.5    1.0
# 3     1            5    11        175          60    73    0.8    0.8    1.0
# 4     1            5    11        170          65    76    1.5    1.2    1.0
#
#    청력(우)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  \
# 0    1.0  ...     104.0  15.9  1.0      1.0          25          57     52
# 1    1.0  ...     101.0  16.2  1.0      0.7          21          35     24
# 2    1.0  ...     109.0  17.6  3.0      0.9          25          18     23
# 3    1.0  ...      44.0  15.7  1.0      0.8          16          11     19
# 4    1.0  ...     132.0  12.4  1.0      1.1          26          18     31
#
#    흡연상태  음주여부  구강검진 수검여부
# 0   1.0   0.0          0
# 1   3.0   0.0          0
# 2   3.0   0.0          0
# 3   3.0   1.0          0
# 4   3.0   0.0          1
#
# [5 rows x 26 columns]

# %%
GJ_2014.shape
# Out:
# (1000000, 26)

# %%
GJ_2014.describe()
# Out:
#                  성별코드     연령대코드(5세단위)            시도코드       신장(5Cm단위)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.457211       10.337172       33.627936      166.307190
# std          0.498166        2.819087       12.721441        9.335261
# min          1.000000        5.000000       11.000000      130.000000
# 25%          1.000000        8.000000       26.000000      160.000000
# 50%          1.000000       10.000000       41.000000      165.000000
# 75%          2.000000       12.000000       44.000000      175.000000
# max          2.000000       18.000000       49.000000      195.000000
#
#            체중(5Kg 단위)            허리둘레           시력(좌)           시력(우)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        66.610625       80.516598        0.984891        0.981142
# std         12.181895        9.329093        0.631080        0.622653
# min         30.000000       51.000000        0.100000        0.100000
# 25%         60.000000       74.000000        0.700000        0.700000
# 50%         65.000000       81.000000        1.000000        1.000000
# 75%         75.000000       87.000000        1.200000        1.200000
# max        140.000000      129.000000        9.900000        9.900000
#
#                 청력(좌)           청력(우)  ...        LDL콜레스테롤             혈색소  \
# count  1000000.000000  1000000.000000  ...  1000000.000000  1000000.000000
# mean         1.027641        1.026613  ...      113.981940       14.118909
# std          0.163929        0.160936  ...       41.883212        1.634710
# min          1.000000        1.000000  ...        1.000000        0.100000
# 25%          1.000000        1.000000  ...       90.000000       13.000000
# 50%          1.000000        1.000000  ...      111.000000       14.200000
# 75%          1.000000        1.000000  ...      134.000000       15.300000
# max          2.000000        2.000000  ...     9999.000000       23.700000
#
#                   요단백         혈청크레아티닌      (혈청지오티)AST      (혈청지오티)ALT  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.079996        0.886300       25.400075       25.071998
# std          0.401009        0.665678       15.863441       20.954440
# min          1.000000        0.100000        1.000000        1.000000
# 25%          1.000000        0.700000       19.000000       14.000000
# 50%          1.000000        0.900000       22.000000       20.000000
# 75%          1.000000        1.000000       28.000000       29.000000
# max          6.000000       98.000000      999.000000      999.000000
#
#                 감마지티피            흡연상태            음주여부       구강검진 수검여부
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        36.413858        1.635751        0.502672        0.405838
# std         49.121305        0.838818        0.499803        0.491054
# min          1.000000        1.000000        0.000000        0.000000
# 25%         15.000000        1.000000        0.000000        0.000000
# 50%         23.000000        1.000000        1.000000        0.000000
# 75%         39.000000        2.000000        1.000000        1.000000
# max        999.000000        3.000000        1.000000        1.000000
#
# [8 rows x 26 columns]

# %%
GJ_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
# 성별코드           1000000 non-null int64
# 연령대코드(5세단위)    1000000 non-null int64
# 시도코드           1000000 non-null int64
# 신장(5Cm단위)      1000000 non-null int64
# 체중(5Kg 단위)     1000000 non-null int64
# 허리둘레           1000000 non-null int64
# 시력(좌)          1000000 non-null float64
# 시력(우)          1000000 non-null float64
# 청력(좌)          1000000 non-null float64
# 청력(우)          1000000 non-null float64
# 수축기혈압          1000000 non-null int64
# 이완기혈압          1000000 non-null int64
# 식전혈당(공복혈당)     1000000 non-null int64
# 총콜레스테롤         1000000 non-null int64
# 트리글리세라이드       1000000 non-null int64
# HDL콜레스테롤       1000000 non-null int64
# LDL콜레스테롤       1000000 non-null float64
# 혈색소            1000000 non-null float64
# 요단백            1000000 non-null float64
# 혈청크레아티닌        1000000 non-null float64
# (혈청지오티)AST     1000000 non-null int64
# (혈청지오티)ALT     1000000 non-null int64
# 감마지티피          1000000 non-null int64
# 흡연상태           1000000 non-null float64
# 음주여부           1000000 non-null float64
# 구강검진 수검여부      1000000 non-null int64
# dtypes: float64(10), int64(16)
# memory usage: 198.4 MB

# %%
GJ_2014 = GJ_2014.rename(columns = {'성별코드' : 'sex',
                    '연령대코드(5세단위)' : 'year',
                    '시도코드' : 'sido',
                    '신장(5Cm단위)' : 'height',
                    '체중(5Kg 단위)' : 'weight',
                    '허리둘레' : 'waist',
                    '시력(좌)' : 'sight_left',
                    '시력(우)' : 'sight_right',
                    '청력(좌)' : 'hearing_left',
                    '청력(우)' : 'hearing_right',
                    '수축기혈압' : 'SBP',
                    '이완기혈압' : 'RPBP',
                    '식전혈당(공복혈당)' : 'pred_blood_sugar',
                    '총콜레스테롤' : 'cholesterol',
                    '트리글리세라이드' : 'triglycerides',
                    'HDL콜레스테롤' : 'HDL',
                    'LDL콜레스테롤' : 'LDL',
                    '혈색소' : 'blood_pigment',
                    '요단백' : 'urine_protein',
                    '혈청크레아티닌' : 'serum_creatinine',
                    '(혈청지오티)AST' : 'AST',
                    '(혈청지오티)ALT' : 'ALT',
                    '감마지티피' : 'gamma_gtp',
                    '흡연상태' : 'smoking',
                    '음주여부' : 'alcohol',
                    '구강검진 수검여부' : 'oral_inspection'})

# 시각화에서 변수명 출력을 위해 영어로 변경

# %%
GJ_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
# sex                 1000000 non-null int64
# year                1000000 non-null int64
# sido                1000000 non-null int64
# height              1000000 non-null int64
# weight              1000000 non-null int64
# waist               1000000 non-null int64
# sight_left          1000000 non-null float64
# sight_right         1000000 non-null float64
# hearing_left        1000000 non-null float64
# hearing_right       1000000 non-null float64
# SBP                 1000000 non-null int64
# RPBP                1000000 non-null int64
# pred_blood_sugar    1000000 non-null int64
# cholesterol         1000000 non-null int64
# triglycerides       1000000 non-null int64
# HDL                 1000000 non-null int64
# LDL                 1000000 non-null float64
# blood_pigment       1000000 non-null float64
# urine_protein       1000000 non-null float64
# serum_creatinine    1000000 non-null float64
# AST                 1000000 non-null int64
# ALT                 1000000 non-null int64
# gamma_gtp           1000000 non-null int64
# smoking             1000000 non-null float64
# alcohol             1000000 non-null float64
# oral_inspection     1000000 non-null int64
# dtypes: float64(10), int64(16)
# memory usage: 198.4 MB

# %%
import matplotlib
import matplotlib.pyplot as plt

# 데이터 탐색을 위한 시각화 패키지 장착

# %%
plt.hist(GJ_2014['height'], histtype='bar', rwidth=0.9)
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
plt.boxplot(GJ_2014['height'])
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# %%
GJ_2014['pred_blood_sugar'] = np.where(GJ_2014['pred_blood_sugar'] >= 126, 1, 0)

# target 변수인 pred_blood_sugar가 126 이상일 때, 당뇨진단으로 판정
# 이분형 자료로 변환
# https://rfriend.tistory.com/tag/Python

# %%
GJ_2014['pred_blood_sugar'].value_counts()

# 당뇨진단자 비율 : 약 7%
# Out:
# 0    931010
# 1     68990
# Name: pred_blood_sugar, dtype: int64

# %% [markdown]
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
GJ_2014.hist(bins=50, figsize=(20,15))
plt.show()



# ALT / AST / HDL / LDL / RPBP / SBP / cholesterol / gamma_gtp / height / serum_creatinine / sight_left / sight_right -> skwed distribution
# triglycerides / urine_protein / waist / weight -> skwed distribution
# blood_pigment -> normal distribution
# alcohol / oral_inspection -> 이산형, 비교적 고른 분포
# hearing_left / hearing_right / smoking / pred_blood_sugar -> class unbalance
# sex / year / sido -> groupby 기준변수

# %%
GJ_2014.boxplot(figsize=(30,15))
plt.show()

# %% [markdown]
# # 이상치 처리
# 일반적으로 1) 표준점수로 변환 후 -3 이하 및 +3 제거 2) IQR 방식 3) 도메인 지식 이용하거나 Binning 처리하는 방식이 이용된다.
#
# 표준점수 이용할 경우 평균이 0, 표준편차가 1인 분포로 변환한후 +3 이상이거나 -3 이하인 경우 극단치로 처리한다.
#
# IQR 방식은 75% percentile * 1.5 이상이거나 25 percentile* 1.5 이하인 경우 극단치로 처리하는 방식이다.
# 이해하기 쉽고 적용하기 쉬운 편이지만, 경우에 따라 너무 많은 사례들이 극단치로 고려되는 경우가 있다.
#
# https://wikidocs.net/16582
#
# ![image.png](attachment:image.png)
#
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 3)
    upper_bound = quartile_3 + (iqr * 3)
    return np.where((ys > upper_bound) | (ys < lower_bound))

# %%
print(np.array(outliers_iqr(GJ_2014['height'])).shape[1],
      np.array(outliers_iqr(GJ_2014['weight'])).shape[1],
      np.array(outliers_iqr(GJ_2014['waist'])).shape[1],
      np.array(outliers_iqr(GJ_2014['sight_left'])).shape[1],
      np.array(outliers_iqr(GJ_2014['sight_right'])).shape[1],
      np.array(outliers_iqr(GJ_2014['SBP'])).shape[1],
      np.array(outliers_iqr(GJ_2014['RPBP'])).shape[1],
      np.array(outliers_iqr(GJ_2014['pred_blood_sugar'])).shape[1],
      np.array(outliers_iqr(GJ_2014['cholesterol'])).shape[1],
      np.array(outliers_iqr(GJ_2014['triglycerides'])).shape[1],
      np.array(outliers_iqr(GJ_2014['HDL'])).shape[1],
      np.array(outliers_iqr(GJ_2014['LDL'])).shape[1],
      np.array(outliers_iqr(GJ_2014['blood_pigment'])).shape[1],
      np.array(outliers_iqr(GJ_2014['serum_creatinine'])).shape[1],
      np.array(outliers_iqr(GJ_2014['AST'])).shape[1],
      np.array(outliers_iqr(GJ_2014['ALT'])).shape[1],
      np.array(outliers_iqr(GJ_2014['gamma_gtp'])).shape[1])

# Outer fence(바깥 울타리) 기준 심각한 이상치는 최소 23개를 가진 변수부터 최대 43045개를 가진 변수까지 있음
# gamma_gtp 변수의 OF 기준 이상치 제거할 경우, 데이터 손실율 약 4.3%
# 특정 연령, 성별, 시/도에 해당하는 범주의 경우, 이상치 비율이 많을 경우 문제 발생
# 이상치 제거 방법으로 IQR 정보를 이용하는 것이 바람직하지 않을 수 있음
# Out:
# 0 238 23 3455 3338 392 1943 68990 465 17075 793 1017 192 2842 24633 24303 43045

# %% [markdown]
# 데이터 단위 변환
# 데이터의 스케일(측정단위)이 다를 경우 특히 거리를 기반으로 분류하는 모델(KNN 등)에 부정적인 영향을 미치므로, 스케일링을 통해 단위를 일정하게 맞추는 작업을 진행해야 한다. 아래 방식이 주로 스케일링을 위해 쓰이는 방법이다. 대부분의 통계 분석 방법이 정규성 가정을 기반으로 하므로 완벽하지 않더라도 최대한 정규분포로 변환하는 노력이 필요하다.
#
# Scaling: 평균이 0, 분산이 1인 분포로 변환
# MinMax Scaling: 특정 범위 (예, 0~1)로 모든 데이터를 변환
# Box-Cox: 여러 k 값중 가장 작은 SSE 선택
# Robust_scale: median, interquartile range 사용(outlier 영향 최소화)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# http://ko.logpresso.com/documents/anomaly-detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clf = IsolationForest(max_samples=1000, random_state=1, contamination=0.01, max_features=2)
# Isolation Forest 방법을 사용하기 위해, 변수로 선언을 해 준다.
# n_estimators=100 : 학습모형 100개
# max_samples=100 : 모형 당 최대 아웃라이어 갯수 1000개
# contamination='legacy' : 아웃라이어 비율 : 0.01(10000개)
# max_features=2 : 각 학습모형이 2개의 변수로 학습됨
# bootstrap=False : 각 학습모형이 샘플을 비복원 추출함
clf.fit(GJ_2014)
# fit 함수를 이용하여, 데이터셋을 학습
y_pred_outliers = clf.predict(GJ_2014)
# predict 함수를 이용하여, outlier를 판별. 0과 1로 이루어진 Series형태의 데이터가 나옴

out = pd.DataFrame(y_pred_outliers)
out = out.rename(columns={0: "out"})
GJ_2014 = pd.concat([GJ_2014, out], 1)
# 원래의 dataframe에 붙이기. 데이터가 0인 것이 outlier이기 때문에, 0인 것을 제거하면 outlier가 제거된 dataframe을 얻을 수 있음

# https://mkjjo.github.io/python/2019/01/10/outlier.html
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html
# Out:
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
GJ_2014['out'].value_counts()

# 10000개의 이상치를 detecting(label : -1)
# Out:
#  1    990000
# -1     10000
# Name: out, dtype: int64

# %%
GJ_2014=GJ_2014[GJ_2014['out']==1]

# %%
GJ_2014.boxplot(figsize=(30,15))
plt.show()

# %%
GJ_2014=GJ_2014[GJ_2014['LDL']<4000]

# Box-plot에서 불연속이면서 많은 값의 차이를 보이는 이상치 제거

# %%
GJ_2014.boxplot(figsize=(30,15))
plt.show()

# 불연속으로 많이 떨어진 이상치 제거

# %%
del GJ_2014['out']

# %%
GJ_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 989999 entries, 0 to 999999
# Data columns (total 26 columns):
# sex                 989999 non-null int64
# year                989999 non-null int64
# sido                989999 non-null int64
# height              989999 non-null int64
# weight              989999 non-null int64
# waist               989999 non-null int64
# sight_left          989999 non-null float64
# sight_right         989999 non-null float64
# hearing_left        989999 non-null float64
# hearing_right       989999 non-null float64
# SBP                 989999 non-null int64
# RPBP                989999 non-null int64
# pred_blood_sugar    989999 non-null int32
# cholesterol         989999 non-null int64
# triglycerides       989999 non-null int64
# HDL                 989999 non-null int64
# LDL                 989999 non-null float64
# blood_pigment       989999 non-null float64
# urine_protein       989999 non-null float64
# serum_creatinine    989999 non-null float64
# AST                 989999 non-null int64
# ALT                 989999 non-null int64
# gamma_gtp           989999 non-null int64
# smoking             989999 non-null float64
# alcohol             989999 non-null float64
# oral_inspection     989999 non-null int64
# dtypes: float64(10), int32(1), int64(15)
# memory usage: 200.2 MB

# %%
GJ_2014 = GJ_2014.rename(columns = {'height' : 'height_2014',
                    'weight' : 'weight_2014',
                    'waist' : 'waist_2014',
                    'sight_left' : 'sight_left_2014',
                    'sight_right' : 'sight_right_2014',
                    'hearing_left' : 'hearing_left_2014',
                    'hearing_right' : 'hearing_right_2014',
                    'SBP' : 'SBP_2014',
                    'RPBP' : 'RPBP_2014',
                    'cholesterol' : 'cholesterol_2014',
                    'triglycerides' : 'triglycerides_2014',
                    'HDL' : 'HDL_2014',
                    'LDL' : 'LDL_2014',
                    'blood_pigment' : 'blood_pigment_2014',
                    'urine_protein' : 'urine_protein_2014',
                    'serum_creatinine' : 'serum_creatinine_2014',
                    'AST' : 'AST_2014',
                    'ALT' : 'ALT_2014',
                    'gamma_gtp' : 'gamma_gtp_2014',
                    'smoking' : 'smoking_2014',
                    'alcohol' : 'alcohol_2014',
                    'oral_inspection' : 'oral_inspection_2014'})

# 2017년도 건강검진정보 예측변수(22개) rename

# %%
GJ_2014['target'] = GJ_2014['pred_blood_sugar']

# %%
del GJ_2014['pred_blood_sugar']

# %%
plt.hist(GJ_2014['target'], histtype='bar', rwidth=0.9)
plt.xlabel('pre_blood_sugar')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
GJ_2014_group = GJ_2014.groupby(['sex','year','sido']).mean()

# 시/도 그룹별 평균치를 저장

# %%
GJ_2014_group.reset_index(inplace=True)

# %%
GJ_2014_group

# 474개 범주를 가지는 자료형태로 변환
# dimension : 474x26
# Out:
#      sex  year  sido  height_2014  weight_2014  waist_2014  sight_left_2014  \
# 0      1     5    11   176.522334    72.821331   78.927985         1.095260
# 1      1     5    26   175.736000    72.520000   78.753600         1.067200
# 2      1     5    27   175.757840    72.290941   79.113240         1.075261
# 3      1     5    28   175.770370    72.155556   78.746667         1.145630
# 4      1     5    29   175.326460    69.621993   77.065292         1.135395
# 5      1     5    30   176.323529    72.867647   79.176471         1.129044
# 6      1     5    31   175.969945    71.994536   79.226776         1.099727
# 7      1     5    36   172.812500    68.437500   77.687500         1.143750
# 8      1     5    41   175.112994    71.429379   78.247834         1.141710
# 9      1     5    42   176.588022    74.392015   79.036298         1.173140
# 10     1     5    43   175.408879    70.560748   77.385514         1.151987
# 11     1     5    44   175.633270    70.916824   78.122873         1.147540
# 12     1     5    45   176.143868    72.193396   78.556604         1.175236
# 13     1     5    46   175.663130    71.976127   78.732095         1.127321
# 14     1     5    47   175.716096    71.780735   78.765526         1.139213
# 15     1     5    48   174.718526    70.972364   78.136131         1.085773
# 16     1     5    49   175.505618    71.011236   77.786517         1.105618
# 17     1     6    11   176.993731    75.806199   82.007487         1.099182
# 18     1     6    26   175.979130    75.768206   82.042185         1.106350
# 19     1     6    27   176.328079    74.976649   81.708114         1.104904
# 20     1     6    28   176.078210    75.167269   81.621609         1.124684
# 21     1     6    29   175.993624    74.250797   81.445271         1.107439
# 22     1     6    30   177.063267    76.421152   82.118980         1.123354
# 23     1     6    31   176.234097    74.766751   81.580153         1.070059
# 24     1     6    36   175.769231    73.653846   80.974359         1.132051
# 25     1     6    41   175.914274    74.947213   81.651921         1.132246
# 26     1     6    42   176.767502    76.456353   81.655143         1.168453
# 27     1     6    43   176.029309    74.207955   80.689463         1.143824
# 28     1     6    44   175.621011    73.964163   81.384880         1.149779
# 29     1     6    45   176.121739    74.708696   81.306087         1.148435
# ..   ...   ...   ...          ...          ...         ...              ...
# 444    2    17    29   150.637755    53.903061   82.331633         0.583673
# 445    2    17    30   150.866667    54.200000   81.966667         0.820667
# 446    2    17    31   150.958904    53.698630   80.465753         0.642466
# 447    2    17    36   150.600000    51.800000   78.600000         0.536000
# 448    2    17    41   150.754039    55.206463   83.208259         0.602065
# 449    2    17    42   150.100000    53.783333   80.610000         0.694333
# 450    2    17    43   148.979933    52.892977   82.551839         0.535932
# 451    2    17    44   149.223195    52.067834   80.693654         0.647671
# 452    2    17    45   149.730849    52.153209   79.759834         0.577640
# 453    2    17    46   150.007837    52.680251   80.333856         0.610502
# 454    2    17    47   150.349014    52.663126   79.974203         0.576328
# 455    2    17    48   150.423077    52.423077   79.913462         0.674286
# 456    2    17    49   151.569767    54.127907   81.000000         0.466935
# 457    2    18    11   150.416667    52.166667   81.827778         0.526957
# 458    2    18    26   150.172414    54.051724   80.810345         0.479310
# 459    2    18    27   150.740741    50.185185   78.296296         0.477778
# 460    2    18    28   150.185185    52.407407   80.981481         0.525926
# 461    2    18    29   150.694444    50.833333   81.916667         0.688889
# 462    2    18    30   148.500000    51.250000   80.700000         0.593438
# 463    2    18    31   150.000000    50.000000   75.923077         0.407692
# 464    2    18    36   145.000000    47.500000   85.250000         0.550000
# 465    2    18    41   149.379562    52.135036   80.905109         0.678467
# 466    2    18    42   149.333333    50.066667   79.120000         0.437333
# 467    2    18    43   147.300000    48.900000   79.900000         0.608000
# 468    2    18    44   148.148148    48.456790   78.246914         0.554321
# 469    2    18    45   148.620690    48.965517   77.560345         0.461207
# 470    2    18    46   149.841270    51.031746   78.658730         0.569048
# 471    2    18    47   148.795620    48.905109   78.167883         0.466861
# 472    2    18    48   150.116279    50.697674   77.988372         0.458140
# 473    2    18    49   149.166667    48.333333   77.333333         0.416667
#
#      sight_right_2014  hearing_left_2014  hearing_right_2014  ...  \
# 0            1.072470           1.004558            1.003646  ...
# 1            1.087200           1.004800            1.001600  ...
# 2            1.069861           1.006969            1.003484  ...
# 3            1.104296           1.000000            1.001481  ...
# 4            1.147423           1.003436            1.000000  ...
# 5            1.113235           1.003676            1.007353  ...
# 6            1.074044           1.000000            1.000000  ...
# 7            1.118750           1.000000            1.000000  ...
# 8            1.125923           1.004145            1.004145  ...
# 9            1.167332           1.001815            1.001815  ...
# 10           1.144496           1.007026            1.009368  ...
# 11           1.135417           1.001894            1.003788  ...
# 12           1.119340           1.009434            1.014151  ...
# 13           1.156499           1.002653            1.002653  ...
# 14           1.138453           1.007614            1.006345  ...
# 15           1.083419           1.006141            1.003071  ...
# 16           1.066292           1.000000            1.011236  ...
# 17           1.101463           1.003309            1.003657  ...
# 18           1.089609           1.004440            1.003552  ...
# 19           1.108231           1.002919            1.003503  ...
# 20           1.129476           1.002712            1.002712  ...
# 21           1.123273           1.004251            1.004251  ...
# 22           1.116926           1.002836            1.000946  ...
# 23           1.057676           1.005089            1.003393  ...
# 24           1.178205           1.000000            1.000000  ...
# 25           1.130810           1.002112            1.002640  ...
# 26           1.141487           1.000000            1.000000  ...
# 27           1.141452           1.000000            1.002094  ...
# 28           1.140452           1.002455            1.003927  ...
# 29           1.136261           1.004348            1.003478  ...
# ..                ...                ...                 ...  ...
# 444          0.839796           1.174415            1.184694  ...
# 445          0.608667           1.153333            1.160000  ...
# 446          0.675342           1.164384            1.082192  ...
# 447          0.520000           1.000000            1.080000  ...
# 448          0.682496           1.131059            1.120287  ...
# 449          0.569667           1.093333            1.126667  ...
# 450          0.644274           1.094066            1.087387  ...
# 451          0.667760           1.127271            1.103137  ...
# 452          0.592754           1.101449            1.101449  ...
# 453          0.698903           1.106583            1.076803  ...
# 454          0.616540           1.144158            1.159332  ...
# 455          0.666457           1.105769            1.125000  ...
# 456          0.579738           1.070510            1.071004  ...
# 457          0.774217           1.194444            1.177778  ...
# 458          0.505172           1.189655            1.224138  ...
# 459          0.488889           1.185185            1.148148  ...
# 460          0.894444           1.092593            1.074074  ...
# 461          0.983333           1.055556            1.138889  ...
# 462          0.547187           1.217188            1.321875  ...
# 463          1.092308           1.076923            1.076923  ...
# 464          0.550000           1.250000            1.250000  ...
# 465          0.630292           1.149635            1.167883  ...
# 466          0.597333           1.093333            1.093333  ...
# 467          0.662000           1.100000            1.120000  ...
# 468          0.670370           1.135802            1.086420  ...
# 469          0.549138           1.163793            1.146552  ...
# 470          0.578571           1.095238            1.095238  ...
# 471          0.488040           1.153285            1.160584  ...
# 472          0.796512           1.116279            1.069767  ...
# 473          1.175000           1.098958            1.182292  ...
#
#      blood_pigment_2014  urine_protein_2014  serum_creatinine_2014   AST_2014  \
# 0             15.506928            1.057481               0.959526  23.028259
# 1             15.374880            1.032000               0.958880  23.320000
# 2             15.418118            1.043630               0.966725  23.334495
# 3             15.534667            1.050445               0.982370  23.345185
# 4             15.227148            1.044674               0.969759  23.505155
# 5             15.526471            1.040589               0.981985  26.922794
# 6             15.202186            1.024590               1.156011  23.879781
# 7             15.225000            1.000000               1.031250  23.375000
# 8             15.520904            1.032818               0.964972  23.732957
# 9             15.596007            1.029038               0.981670  23.693285
# 10            15.466822            1.028037               1.008645  23.677570
# 11            15.541399            1.047348               0.953875  24.119093
# 12            15.418160            1.040094               0.941274  23.334906
# 13            15.250663            1.055850               0.966844  22.896552
# 14            15.449937            1.027883               0.970215  24.050697
# 15            15.290890            1.045083               0.965916  24.133060
# 16            15.643820            1.022472               0.982022  22.853933
# 17            15.575292            1.055229               0.986558  24.502699
# 18            15.423979            1.042670               0.969272  25.287744
# 19            15.450671            1.046145               0.977466  24.492119
# 20            15.588110            1.040255               0.988879  24.564647
# 21            15.457917            1.046971               0.971838  24.748140
# 22            15.512559            1.034109               0.986969  24.325779
# 23            15.302545            1.025445               0.931383  24.376590
# 24            15.601282            1.012821               1.001282  24.000000
# 25            15.567536            1.045558               0.964443  25.200908
# 26            15.663872            1.029386               1.006396  25.486603
# 27            15.575506            1.032149               0.975506  24.260991
# 28            15.640206            1.033403               0.961119  24.365734
# 29            15.512870            1.032202               0.956000  24.713043
# ..                  ...                 ...                    ...        ...
# 444           12.116327            1.036421               0.851020  24.234694
# 445           12.721333            1.026667               0.818667  24.533333
# 446           12.471233            1.054795               0.869863  25.123288
# 447           12.248000            1.128889               0.808000  23.360000
# 448           12.668851            1.115763               0.968133  24.660682
# 449           12.520667            1.107753               0.851333  24.383333
# 450           12.662542            1.080674               0.863545  23.879599
# 451           12.459081            1.113579               0.815755  23.286652
# 452           12.120911            1.081111               0.885714  23.447205
# 453           12.065831            1.065826               0.848433  24.622257
# 454           12.296358            1.095291               0.835660  23.760243
# 455           12.106923            1.058607               0.820192  23.980769
# 456           12.737209            1.150634               0.809302  23.313953
# 457           12.170000            1.200000               0.871111  23.444444
# 458           12.220690            1.034483               0.874138  22.586207
# 459           12.222222            1.039352               0.922222  24.611111
# 460           12.314815            1.172325               1.138889  24.407407
# 461           11.497222            1.083333               0.883333  22.944444
# 462           12.155000            1.335484               0.775000  27.150000
# 463           11.815385            1.000000               0.969231  23.615385
# 464           13.575000            1.500000               0.825000  31.750000
# 465           12.124088            1.102629               0.908029  25.350365
# 466           12.345333            1.084898               0.845333  23.053333
# 467           12.202000            1.082951               0.890000  23.420000
# 468           12.146914            1.070070               0.838272  23.679012
# 469           11.597414            1.039690               0.884483  22.698276
# 470           11.780952            1.039634               0.877778  22.476190
# 471           11.897810            1.102726               0.832117  22.897810
# 472           11.805814            1.061022               0.805814  21.534884
# 473           12.466667            1.000000               0.833333  24.416667
#
#       ALT_2014  gamma_gtp_2014  smoking_2014  alcohol_2014  \
# 0    22.360073       26.964448      2.043796      0.270321
# 1    22.566400       25.136000      2.075200      0.304000
# 2    23.116725       24.566202      1.970383      0.327526
# 3    23.448889       26.527407      2.118519      0.264488
# 4    21.910653       25.065292      1.934708      0.316151
# 5    24.227941       24.790441      2.033088      0.319853
# 6    21.887978       22.218579      1.969856      0.287669
# 7    21.375000       25.562500      1.937500      0.125000
# 8    23.267043       26.497175      2.073446      0.317634
# 9    23.047187       25.996370      2.261343      0.284936
# 10   21.371495       25.724299      2.200935      0.252336
# 11   22.453686       25.102079      2.064272      0.347826
# 12   22.660377       25.349057      2.141509      0.306604
# 13   22.493369       23.705570      1.989390      0.297082
# 14   23.624842       25.311787      2.038023      0.326996
# 15   22.664278       24.298874      2.050154      0.313204
# 16   20.550562       25.595506      2.314607      0.247191
# 17   27.113007       33.235417      1.953493      0.202198
# 18   28.199822       35.099911      2.062611      0.225577
# 19   27.517805       31.265616      2.036778      0.259648
# 20   28.273508       34.385172      2.065099      0.263562
# 21   27.893730       34.158342      2.043571      0.255048
# 22   28.281398       33.373938      2.039660      0.216242
# 23   25.252757       29.680237      2.122986      0.227311
# 24   29.051282       37.564103      2.128205      0.256410
# 25   27.919341       34.799198      2.045407      0.252825
# 26   28.271392       36.057044      2.148660      0.243292
# 27   26.456385       32.288904      2.118632      0.254887
# 28   27.323515       33.342170      2.085420      0.255894
# 29   27.709565       32.483478      2.160870      0.270435
# ..         ...             ...           ...           ...
# 444  17.510204       20.938776      1.010204      0.984694
# 445  18.006667       20.700000      1.046667      0.973333
# 446  18.315068       20.739726      1.054795      0.986301
# 447  16.200000       19.040000      1.000000      0.880000
# 448  18.140934       22.632855      1.031418      0.963098
# 449  16.760000       21.580000      1.000000      0.980000
# 450  16.678930       19.612040      1.060411      0.946318
# 451  17.074398       20.400438      1.028446      0.971554
# 452  17.113872       21.293996      1.026915      0.964803
# 453  17.336991       21.542320      1.021944      0.960815
# 454  17.183612       21.116844      1.080425      0.963581
# 455  16.573077       22.367308      1.063462      0.969231
# 456  16.546512       19.860465      1.000000      1.000000
# 457  15.622222       19.427778      1.033333      0.961111
# 458  15.396552       23.224138      1.086207      0.982759
# 459  17.092593       18.314815      1.129630      0.962963
# 460  15.370370       22.444444      1.037037      0.981481
# 461  15.888889       19.944444      1.000000      0.972222
# 462  17.600000       21.950000      1.050000      0.950000
# 463  15.384615       17.153846      1.307692      0.923077
# 464  22.250000       17.000000      1.000000      1.000000
# 465  16.259124       22.160584      1.043796      0.974296
# 466  15.293333       18.200000      1.053333      0.906667
# 467  15.560000       15.320000      1.020000      1.000000
# 468  14.962963       17.913580      1.000000      0.950617
# 469  13.827586       16.965517      1.025862      0.974138
# 470  14.222222       19.079365      1.000000      0.960317
# 471  15.043796       18.591241      1.036496      0.978102
# 472  14.081395       19.941860      1.034884      0.930233
# 473  15.000000       14.833333      1.000000      1.000000
#
#      oral_inspection_2014    target
# 0                0.567912  0.005469
# 1                0.539200  0.004800
# 2                0.425087  0.013937
# 3                0.663704  0.001481
# 4                0.591065  0.006873
# 5                0.698529  0.000000
# 6                0.592896  0.002732
# 7                0.812500  0.000000
# 8                0.617702  0.007910
# 9                0.724138  0.005445
# 10               0.614486  0.007009
# 11               0.693762  0.009452
# 12               0.698113  0.002358
# 13               0.570292  0.010610
# 14               0.589354  0.005070
# 15               0.407369  0.008188
# 16               0.505618  0.000000
# 17               0.590806  0.005224
# 18               0.526199  0.010657
# 19               0.414478  0.011092
# 20               0.663653  0.007685
# 21               0.553666  0.007439
# 22               0.676110  0.005666
# 23               0.692960  0.005937
# 24               0.743590  0.025641
# 25               0.627851  0.011402
# 26               0.631806  0.010372
# 27               0.622470  0.011863
# 28               0.688267  0.012273
# 29               0.655652  0.012174
# ..                    ...       ...
# 444              0.188776  0.178571
# 445              0.260000  0.100000
# 446              0.164384  0.054795
# 447              0.080000  0.160000
# 448              0.182226  0.128366
# 449              0.143333  0.096667
# 450              0.153846  0.173913
# 451              0.087527  0.100656
# 452              0.190476  0.120083
# 453              0.042320  0.139498
# 454              0.054628  0.132018
# 455              0.061538  0.119231
# 456              0.162791  0.069767
# 457              0.172222  0.100000
# 458              0.120690  0.137931
# 459              0.055556  0.111111
# 460              0.222222  0.129630
# 461              0.055556  0.138889
# 462              0.250000  0.100000
# 463              0.076923  0.230769
# 464              0.000000  0.250000
# 465              0.109489  0.076642
# 466              0.093333  0.106667
# 467              0.080000  0.200000
# 468              0.074074  0.074074
# 469              0.120690  0.077586
# 470              0.007937  0.111111
# 471              0.036496  0.124088
# 472              0.023256  0.174419
# 473              0.000000  0.250000
#
# [474 rows x 26 columns]

# %%
GJ_2014_group.to_csv("GJ_2014_group.csv")

# 2017년 건강검진정보 데이터전처리 -> 476개 범주화된 자료를 csv로 저장
# https://tariat.tistory.com/583

# %%
# 척도화
# https://mkjjo.github.io/python/2019/01/10/scaler.html

# 데이터 분할
# https://pythonanalysis.tistory.com/7

# 데이터 분포 변환
# https://wikidocs.net/16582
