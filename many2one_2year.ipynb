# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

import keras
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Activation, BatchNormalization

import keras
from keras.models import Sequential
from keras import optimizers
from sklearn.metrics import mean_squared_error
from keras.models import load_model

import time
from keras.callbacks import TensorBoard

# %%
GJ_2009 = pd.read_csv("./data/final_group_2009.csv")
GJ_2010 = pd.read_csv("./data/final_group_2010.csv")
GJ_2011 = pd.read_csv("./data/final_group_2011.csv")
GJ_2012 = pd.read_csv("./data/final_group_2012.csv")
GJ_2013 = pd.read_csv("./data/final_group_2013.csv")
GJ_2014 = pd.read_csv("./data/final_group_2014.csv")
GJ_2015 = pd.read_csv("./data/final_group_2015.csv")
GJ_2016 = pd.read_csv("./data/final_group_2016.csv")
GJ_2017 = pd.read_csv("./data/final_group_2017.csv")

# 2016년도는 알코올 변수가 없어서 제거

del GJ_2009['alcohol_2009']
del GJ_2010['alcohol_2010']
del GJ_2011['alcohol_2011']
del GJ_2012['alcohol_2012']
del GJ_2013['alcohol_2013']
del GJ_2014['alcohol_2014']
del GJ_2015['alcohol_2015']
# del GJ_2016['alcohol_2016']
del GJ_2017['alcohol_2017']

# %%
group_01_Y =pd.concat( [ pd.Series(GJ_2009.loc[0,'target']),pd.Series(GJ_2010.loc[0,'target']), 
                       pd.Series(GJ_2011.loc[0,'target']), pd.Series(GJ_2012.loc[0,'target']), 
                       pd.Series(GJ_2013.loc[0,'target']), pd.Series(GJ_2014.loc[0,'target']), 
                       pd.Series(GJ_2015.loc[0,'target']), pd.Series(GJ_2016.loc[0,'target']), 
                       pd.Series(GJ_2017.loc[0,'target']) ])

group_01_Y
# Out:
# 0    0.123966
# 0    0.128567
# 0    0.127495
# 0    0.126737
# 0    0.133388
# 0    0.065369
# 0    0.070101
# 0    0.070171
# 0    0.072436
# dtype: float64

# %%
del GJ_2009['target']
del GJ_2010['target']
del GJ_2011['target']
del GJ_2012['target']
del GJ_2013['target']
del GJ_2014['target']
del GJ_2015['target']
del GJ_2016['target']
del GJ_2017['target']

# %%
GJ_01 = pd.concat([ GJ_2009.iloc[0, :], GJ_2010.iloc[0, :],GJ_2011.iloc[0, :]
           ,GJ_2012.iloc[0, :],GJ_2013.iloc[0, :],GJ_2014.iloc[0, :],GJ_2015.iloc[0, :],
           GJ_2016.iloc[0, :],GJ_2017.iloc[0, :] ], axis=0)

GJ_01.shape
# Out:
# (261,)

# %%
group_01_X = pd.DataFrame(np.array(GJ_01).reshape(9,29))

group_01_X
# Out:
#     0    1     2           3          4          5         6         7   \
# 0  1.0  5.0  11.0  164.082246  64.275584  85.066084  0.835089  0.849314
# 1  1.0  5.0  11.0  164.286355  64.587731  85.115767  0.850260  0.853051
# 2  1.0  5.0  11.0  164.192092  64.525130  85.025088  0.842970  0.854034
# 3  1.0  5.0  11.0  164.198746  64.522639  85.004177  0.858097  0.857639
# 4  1.0  5.0  11.0  164.299008  64.643790  84.942024  0.867557  0.870964
# 5  1.0  5.0  11.0  173.919558  75.197807  84.784052  1.070561  1.069871
# 6  1.0  5.0  11.0  174.242687  75.816172  85.122337  1.064436  1.068575
# 7  1.0  5.0  11.0  170.479056  72.408390  85.412760  1.073057  1.071174
# 8  1.0  5.0  11.0  170.454959  72.630210  85.666327  1.068981  1.072022
#
#          8         9   ...         19         20         21        22  \
# 0  1.050541  1.042505  ...  26.763948  25.433064  42.639791  1.882801
# 1  1.051059  1.044525  ...  26.514485  25.274991  42.498773  1.879216
# 2  1.046306  1.040214  ...  26.404203  24.761978  42.412784  1.908642
# 3  1.047118  1.042304  ...  26.956529  25.581728  42.685983  1.902737
# 4  1.046491  1.042075  ...  26.880975  25.444710  42.365930  1.912343
# 5  1.011224  1.010149  ...  26.435925  30.281621  50.007288  2.199261
# 6  1.011531  1.011322  ...  26.859070  31.107678  50.635732  2.173336
# 7  1.010183  1.010425  ...  26.545301  31.076026  51.031457  2.205851
# 8  1.010127  1.009610  ...  27.067681  31.658272  50.963437  2.177280
#
#          23        24         25        26        27        28
# 0  0.331779  6.022633   9.439318  5.269804  9.477925  4.864434
# 1  0.339532  5.447836  10.318163  5.139831  6.487352  4.312068
# 2  0.313033  5.242181   9.025001  5.395798  7.162394  5.991064
# 3  0.341636  5.344020   9.481327  5.324866  7.163669  5.152478
# 4  0.352282  5.163603   9.145865  4.934956  7.030884  5.430357
# 5  0.458504  5.642267  10.299977  4.922783  5.907340  5.093187
# 6  0.456646  5.862395   8.605695  5.185965  6.613984  5.336282
# 7  0.447156  5.716449   8.174336  4.785431  6.610226  5.735070
# 8  0.444054  4.928141   8.545803  5.020429  5.020429  4.965056
#
# [9 rows x 29 columns]

# %%
group_01_X.shape, group_01_Y.shape
# Out:
# ((9, 29), (9,))

# %%
group_01_Y = np.array(group_01_Y[0])

group_01_Y
# Out:
# array([0.12396598, 0.12856729, 0.12749516, 0.12673694, 0.13338816,
#        0.06536944, 0.07010094, 0.07017115, 0.07243579])

# %%
# 3개년으로 2년후를 예측

seq_length = 3
predict_year = 3   # 2년후


dataX= []
dataY= []

for i in range(0, int( len(group_01_Y) - seq_length - (predict_year -1) )):
    _x = group_01_X[i : i+seq_length]
    _x = np.array(_x)
    _y = group_01_Y[i + seq_length + (predict_year -1) ]
    _y = np.array(_y)
    dataX.append(_x) # dataX 리스트에 추가 / add to dataX's list
    dataY.append(_y) # dataY 리스트에 추가 / add to dataY's list

# %%
np.array(dataX).shape,  np.array(dataY).shape
# Out:
# ((4, 3, 29), (4,))

# %%
dataY
# Out:
# [array(0.06536944), array(0.07010094), array(0.07017115), array(0.07243579)]

# %%
# 학습용/테스트용 데이터 생성
train_size = int(len(dataY) * 0.9)
test_size = len(dataY) - train_size

train_size
# Out:
# 3

# %%
# 데이터를 잘라 학습용 데이터 생성
trainX = np.array(dataX[0:train_size])
trainY = np.array(dataY[0:train_size])

# %%
# 데이터를 잘라 테스트용 데이터 생성
testX = np.array(dataX[train_size:len(dataX)])
testY = np.array(dataY[train_size:len(dataY)])

# %%
trainX.shape, trainY.shape ,  testX.shape, testY.shape
# Out:
# ((3, 3, 29), (3,), (1, 3, 29), (1,))

# %%
## LSTM 모델

input_columns = 29

model = Sequential()
model.add(LSTM(128, input_shape=(seq_length, input_columns) , return_sequences=True, stateful=False))
model.add(LSTM(128, return_sequences=False, stateful=False))
model.add(Dense(1))
model.add(Activation('linear'))
# , dropout=0.2

model.summary()

# 텐서보드
now = time.strftime("%H%M%S"); now
callbacks_list = [TensorBoard(log_dir='C:/Users/swoos/Desktop/AI/project/LSTM/'+'LSTM'+now)]  #histogram_freq=1
# Out:
# WARNING:tensorflow:From C:\Users\swoos\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 3, 128)            80896
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 212,609
# Trainable params: 212,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 학습 설정 및 진행
keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
print("="*50)
hist = model.fit(trainX, trainY, epochs=50, batch_size=2, verbose=1, callbacks=callbacks_list) #validation_data=(testX, testY))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 3, 128)            80896
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 212,609
# Trainable params: 212,609
# Non-trainable params: 0
# _________________________________________________________________
# ==================================================
# WARNING:tensorflow:From C:\Users\swoos\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 3/3 [==============================] - 2s 590ms/step - loss: 0.1281
# Epoch 2/50
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0647
# Epoch 3/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0152
# Epoch 4/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0091
# Epoch 5/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0137
# Epoch 6/50
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 7/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0051
# Epoch 8/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0066
# Epoch 9/50
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7392e-04
# Epoch 10/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 11/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 12/50
# 3/3 [==============================] - 0s 7ms/step - loss: 7.5665e-04
# Epoch 13/50
# 3/3 [==============================] - 0s 7ms/step - loss: 7.2514e-04
# Epoch 14/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0022
# Epoch 15/50
# 3/3 [==============================] - 0s 8ms/step - loss: 7.2065e-04
# Epoch 16/50
# 3/3 [==============================] - 0s 9ms/step - loss: 2.8791e-04
# Epoch 17/50
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 18/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.3956e-04
# Epoch 19/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.5616e-04
# Epoch 20/50
# 3/3 [==============================] - 0s 7ms/step - loss: 6.2481e-04
# Epoch 21/50
# 3/3 [==============================] - 0s 8ms/step - loss: 2.5759e-04
# Epoch 22/50
# 3/3 [==============================] - 0s 12ms/step - loss: 4.8869e-05
# Epoch 23/50
# 3/3 [==============================] - 0s 8ms/step - loss: 3.3938e-04
# Epoch 24/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4839e-04
# Epoch 25/50
# 3/3 [==============================] - 0s 8ms/step - loss: 4.1522e-05
# Epoch 26/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.7808e-04
# Epoch 27/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.8766e-05
# Epoch 28/50
# 3/3 [==============================] - 0s 8ms/step - loss: 4.1176e-05
# Epoch 29/50
# 3/3 [==============================] - 0s 9ms/step - loss: 8.4308e-05
# Epoch 30/50
# 3/3 [==============================] - 0s 9ms/step - loss: 2.4909e-05
# Epoch 31/50
# 3/3 [==============================] - 0s 8ms/step - loss: 3.5399e-05
# Epoch 32/50
# 3/3 [==============================] - 0s 7ms/step - loss: 3.7117e-05
# Epoch 33/50
# 3/3 [==============================] - 0s 6ms/step - loss: 9.6148e-06
# Epoch 34/50
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0310e-05
# Epoch 35/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0761e-05
# Epoch 36/50
# 3/3 [==============================] - 0s 10ms/step - loss: 3.9821e-06
# Epoch 37/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7803e-05
# Epoch 38/50
# 3/3 [==============================] - 0s 7ms/step - loss: 9.5967e-06
# Epoch 39/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1693e-05
# Epoch 40/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2026e-05
# Epoch 41/50
# 3/3 [==============================] - 0s 6ms/step - loss: 7.4259e-06
# Epoch 42/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.3970e-06
# Epoch 43/50
# 3/3 [==============================] - 0s 8ms/step - loss: 7.4144e-06
# Epoch 44/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0163e-05
# Epoch 45/50
# 3/3 [==============================] - 0s 7ms/step - loss: 3.5730e-06
# Epoch 46/50
# 3/3 [==============================] - 0s 9ms/step - loss: 7.2724e-06
# Epoch 47/50
# 3/3 [==============================] - 0s 7ms/step - loss: 3.3310e-06
# Epoch 48/50
# 3/3 [==============================] - 0s 7ms/step - loss: 8.8403e-06
# Epoch 49/50
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0381e-06
# Epoch 50/50
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0110e-05

# %%
# 학습 과정 살펴보기
import matplotlib.pyplot as plt
# %matplotlib inline

# print(hist.history['loss'])
# print(hist.history['val_loss'])
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')
plt.show()
;
# Out:
# No handles with labels found to put in legend.
# ''

# %%
# 13,14,15 년도로 17년도 예측
y_pred_17 = model.predict(testX, batch_size=1, verbose=1) # , steps=5
# Out:
# 1/1 [==============================] - 0s 290ms/step

# %%
testY, y_pred_17 , testX.shape
# Out:
# (array([0.07243579]), array([[0.07168811]], dtype=float32), (1, 3, 29))

# %%
from sklearn.metrics import mean_squared_error
RMSE = np.sqrt(mean_squared_error(testY,y_pred_17))
RMSE
# Out:
# 0.0007476798538093576

# %%
group_01_X
# Out:
#     0    1     2           3          4          5         6         7   \
# 0  1.0  5.0  11.0  164.082246  64.275584  85.066084  0.835089  0.849314
# 1  1.0  5.0  11.0  164.286355  64.587731  85.115767  0.850260  0.853051
# 2  1.0  5.0  11.0  164.192092  64.525130  85.025088  0.842970  0.854034
# 3  1.0  5.0  11.0  164.198746  64.522639  85.004177  0.858097  0.857639
# 4  1.0  5.0  11.0  164.299008  64.643790  84.942024  0.867557  0.870964
# 5  1.0  5.0  11.0  173.919558  75.197807  84.784052  1.070561  1.069871
# 6  1.0  5.0  11.0  174.242687  75.816172  85.122337  1.064436  1.068575
# 7  1.0  5.0  11.0  170.479056  72.408390  85.412760  1.073057  1.071174
# 8  1.0  5.0  11.0  170.454959  72.630210  85.666327  1.068981  1.072022
#
#          8         9   ...         19         20         21        22  \
# 0  1.050541  1.042505  ...  26.763948  25.433064  42.639791  1.882801
# 1  1.051059  1.044525  ...  26.514485  25.274991  42.498773  1.879216
# 2  1.046306  1.040214  ...  26.404203  24.761978  42.412784  1.908642
# 3  1.047118  1.042304  ...  26.956529  25.581728  42.685983  1.902737
# 4  1.046491  1.042075  ...  26.880975  25.444710  42.365930  1.912343
# 5  1.011224  1.010149  ...  26.435925  30.281621  50.007288  2.199261
# 6  1.011531  1.011322  ...  26.859070  31.107678  50.635732  2.173336
# 7  1.010183  1.010425  ...  26.545301  31.076026  51.031457  2.205851
# 8  1.010127  1.009610  ...  27.067681  31.658272  50.963437  2.177280
#
#          23        24         25        26        27        28
# 0  0.331779  6.022633   9.439318  5.269804  9.477925  4.864434
# 1  0.339532  5.447836  10.318163  5.139831  6.487352  4.312068
# 2  0.313033  5.242181   9.025001  5.395798  7.162394  5.991064
# 3  0.341636  5.344020   9.481327  5.324866  7.163669  5.152478
# 4  0.352282  5.163603   9.145865  4.934956  7.030884  5.430357
# 5  0.458504  5.642267  10.299977  4.922783  5.907340  5.093187
# 6  0.456646  5.862395   8.605695  5.185965  6.613984  5.336282
# 7  0.447156  5.716449   8.174336  4.785431  6.610226  5.735070
# 8  0.444054  4.928141   8.545803  5.020429  5.020429  4.965056
#
# [9 rows x 29 columns]

# %%
# 2015, 2016, 2017 - 3개년 X값들

group_01_X[-3:]
# Out:
#     0    1     2           3          4          5         6         7   \
# 6  1.0  5.0  11.0  174.242687  75.816172  85.122337  1.064436  1.068575
# 7  1.0  5.0  11.0  170.479056  72.408390  85.412760  1.073057  1.071174
# 8  1.0  5.0  11.0  170.454959  72.630210  85.666327  1.068981  1.072022
#
#          8         9   ...         19         20         21        22  \
# 6  1.011531  1.011322  ...  26.859070  31.107678  50.635732  2.173336
# 7  1.010183  1.010425  ...  26.545301  31.076026  51.031457  2.205851
# 8  1.010127  1.009610  ...  27.067681  31.658272  50.963437  2.177280
#
#          23        24        25        26        27        28
# 6  0.456646  5.862395  8.605695  5.185965  6.613984  5.336282
# 7  0.447156  5.716449  8.174336  4.785431  6.610226  5.735070
# 8  0.444054  4.928141  8.545803  5.020429  5.020429  4.965056
#
# [3 rows x 29 columns]

# %%
# 2019년 Y예측

test_2019 = list()

test_2019_X = group_01_X[-3:]
test_2019_X = np.array(test_2019_X)
test_2019.append(test_2019_X)

test_2019 = np.array(test_2019)

test_2019.shape
# Out:
# (1, 3, 29)

# %%
y_pred_19 = model.predict(test_2019, batch_size=1)
y_pred_19
# Out:
# array([[0.0998865]], dtype=float32)

# %%
group_01_Y
# Out:
# array([0.12396598, 0.12856729, 0.12749516, 0.12673694, 0.13338816,
#        0.06536944, 0.07010094, 0.07017115, 0.07243579])
