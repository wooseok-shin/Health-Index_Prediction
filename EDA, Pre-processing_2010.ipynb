# %% [markdown]
# # 데이터 불러오기 및 전처리

# %%
import pandas as pd
import numpy as np

# 데이터 전처리에 필요한 패키지 장착

# %%
GJ_2010=pd.read_csv("./NHIS_OPEN_GJ_2010.csv",encoding='CP949') # 데이터 불러오기
GJ_2010.head() # 데이터 일부 확인
# Out:
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0  2010   141216     2           14    45        125          25    56    1.2
# 1  2010   393051     1           14    45        125          25    54    1.0
# 2  2010    78703     1           14    29        125          30    71    1.0
# 3  2010     7861     1           14    27        130          25    59    0.8
# 4  2010     5978     1           14    45        130          25    58    0.7
#
#    시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 0    0.9  ...     12   1.0   0.0          0      NaN    NaN      NaN
# 1    1.0  ...      9   1.0   0.0          0      NaN    NaN      NaN
# 2    1.2  ...     19   1.0   0.0          1      NaN    0.0      0.0
# 3    0.7  ...      8   1.0   0.0          1      NaN    0.0      0.0
# 4    0.5  ...     17   1.0   0.0          0      NaN    NaN      NaN
#
#    제3대구치(사랑니)이상   치석   데이터공개일자
# 0           NaN  NaN  20151220
# 1           NaN  NaN  20151220
# 2           0.0  0.0  20151220
# 3           0.0  0.0  20151220
# 4           NaN  NaN  20151220
#
# [5 rows x 34 columns]

# %%
GJ_2010.shape # 데이터 차원 : 1000000 x 34
# Out:
# (1000000, 34)

# %%
GJ_2010.info() # 34개 변수 타입 : 정수형 또는 실수형
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
# 기준년도            1000000 non-null int64
# 가입자일련번호         1000000 non-null int64
# 성별코드            1000000 non-null int64
# 연령대코드(5세단위)     1000000 non-null int64
# 시도코드            1000000 non-null int64
# 신장(5Cm단위)       1000000 non-null int64
# 체중(5Kg 단위)      1000000 non-null int64
# 허리둘레            1000000 non-null int64
# 시력(좌)           999898 non-null float64
# 시력(우)           999900 non-null float64
# 청력(좌)           999911 non-null float64
# 청력(우)           999909 non-null float64
# 수축기혈압           1000000 non-null int64
# 이완기혈압           1000000 non-null int64
# 식전혈당(공복혈당)      1000000 non-null int64
# 총콜레스테롤          1000000 non-null int64
# 트리글리세라이드        1000000 non-null int64
# HDL콜레스테롤        1000000 non-null int64
# LDL콜레스테롤        990315 non-null float64
# 혈색소             1000000 non-null float64
# 요단백             996337 non-null float64
# 혈청크레아티닌         1000000 non-null float64
# (혈청지오티)AST      1000000 non-null int64
# (혈청지오티)ALT      1000000 non-null int64
# 감마지티피           1000000 non-null int64
# 흡연상태            999033 non-null float64
# 음주여부            998859 non-null float64
# 구강검진 수검여부       1000000 non-null int64
# 치아우식증유무         157084 non-null float64
# 결손치유무           374595 non-null float64
# 치아마모증유무         374592 non-null float64
# 제3대구치(사랑니)이상    294080 non-null float64
# 치석              374578 non-null float64
# 데이터공개일자         1000000 non-null int64
# dtypes: float64(15), int64(19)
# memory usage: 259.4 MB

# %%
GJ_2010.isna().sum()

# 결측치가 있는 변수 : 시력좌/시력우/청력좌/청력우/LDL/요단백/흡연상태/음주여부/치아우식증유무/결손치유무/치아마모증유무/사랑니이상/치석
# Out:
# 기준년도                 0
# 가입자일련번호              0
# 성별코드                 0
# 연령대코드(5세단위)          0
# 시도코드                 0
# 신장(5Cm단위)            0
# 체중(5Kg 단위)           0
# 허리둘레                 0
# 시력(좌)              102
# 시력(우)              100
# 청력(좌)               89
# 청력(우)               91
# 수축기혈압                0
# 이완기혈압                0
# 식전혈당(공복혈당)           0
# 총콜레스테롤               0
# 트리글리세라이드             0
# HDL콜레스테롤             0
# LDL콜레스테롤          9685
# 혈색소                  0
# 요단백               3663
# 혈청크레아티닌              0
# (혈청지오티)AST           0
# (혈청지오티)ALT           0
# 감마지티피                0
# 흡연상태               967
# 음주여부              1141
# 구강검진 수검여부            0
# 치아우식증유무         842916
# 결손치유무           625405
# 치아마모증유무         625408
# 제3대구치(사랑니)이상    705920
# 치석              625422
# 데이터공개일자              0
# dtype: int64

# %%
GJ_2010=GJ_2010.drop(['치아우식증유무','결손치유무','치아마모증유무','제3대구치(사랑니)이상','치석'],axis=1)

# 결측비율이 60%를 넘어가는 5개 변수 제거

# %%
GJ_2010.shape # 5개의 변수가 제거됨
# Out:
# (1000000, 29)

# %%
GJ_2010.describe()

# 영-분산에 해당하는 변수 : 기준년도/데이터공개일자
# Out:
#             기준년도         가입자일련번호            성별코드     연령대코드(5세단위)  \
# count  1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean      2010.0   500000.500000        1.452642        6.092389
# std          0.0   288675.278933        0.497752        2.773606
# min       2010.0        1.000000        1.000000        1.000000
# 25%       2010.0   250000.750000        1.000000        4.000000
# 50%       2010.0   500000.500000        1.000000        6.000000
# 75%       2010.0   750000.250000        2.000000        8.000000
# max       2010.0  1000000.000000        2.000000       14.000000
#
#                  시도코드       신장(5Cm단위)      체중(5Kg 단위)            허리둘레  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        33.286892      162.062345       61.996700       80.131820
# std         12.841314        9.198760       11.535381        9.008045
# min         11.000000      120.000000       25.000000       51.000000
# 25%         26.000000      155.000000       55.000000       74.000000
# 50%         41.000000      160.000000       60.000000       80.000000
# 75%         43.000000      170.000000       70.000000       86.000000
# max         49.000000      190.000000      125.000000      129.000000
#
#                시력(좌)          시력(우)  ...             혈색소            요단백  \
# count  999898.000000  999900.000000  ...  1000000.000000  996337.000000
# mean        0.983323       0.980739  ...       13.957065       1.078338
# std         0.618283       0.612346  ...        1.617119       0.407008
# min         0.100000       0.100000  ...        0.100000       1.000000
# 25%         0.700000       0.700000  ...       12.900000       1.000000
# 50%         1.000000       1.000000  ...       14.000000       1.000000
# 75%         1.200000       1.200000  ...       15.100000       1.000000
# max         9.900000       9.900000  ...       23.700000       6.000000
#
#               혈청크레아티닌      (혈청지오티)AST      (혈청지오티)ALT           감마지티피  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.047596       25.170089       25.087415       36.221478
# std          1.177039       15.633365       21.388287       48.401883
# min          0.100000        1.000000        1.000000        1.000000
# 25%          0.800000       19.000000       15.000000       15.000000
# 50%          0.900000       22.000000       20.000000       23.000000
# 75%          1.000000       28.000000       29.000000       39.000000
# max         99.900000      980.000000      996.000000      999.000000
#
#                 흡연상태           음주여부       구강검진 수검여부     데이터공개일자
# count  999033.000000  998859.000000  1000000.000000   1000000.0
# mean        1.651077       0.483313        0.374604  20151220.0
# std         0.853489       0.499722        0.484021         0.0
# min         1.000000       0.000000        0.000000  20151220.0
# 25%         1.000000       0.000000        0.000000  20151220.0
# 50%         1.000000       0.000000        0.000000  20151220.0
# 75%         3.000000       1.000000        1.000000  20151220.0
# max         3.000000       1.000000        1.000000  20151220.0
#
# [8 rows x 29 columns]

# %%
GJ_2010=GJ_2010.drop(['기준년도','데이터공개일자'],axis=1)

# 영-분산을 가지는 2개의 변수를 제거

# %%
GJ_2010.shape # 2개의 변수가 제거됨
# Out:
# (1000000, 27)

# %%
GJ_2010
# Out:
#         가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0        141216     2           14    45        125          25    56    1.2
# 1        393051     1           14    45        125          25    54    1.0
# 2         78703     1           14    29        125          30    71    1.0
# 3          7861     1           14    27        130          25    59    0.8
# 4          5978     1           14    45        130          25    58    0.7
# 5          8094     1           14    11        130          25    58    0.6
# 6        662204     2           14    11        130          25    51    0.2
# 7          6255     1           14    46        130          25    55    0.8
# 8          7800     2           14    29        140          30    60    0.9
# 9        259244     2           14    42        140          30    59    0.2
# 10         4102     1           14    41        140          30    56    1.0
# 11       205011     2           14    41        140          35    59    0.3
# 12         7125     1           14    27        140          35    60    0.6
# 13        11481     2            1    11        145          35    58    1.0
# 14       996516     2            1    27        145          35    61    0.9
# 15       848830     2            1    44        145          35    59    0.2
# 16       304723     2            1    44        145          40    58    0.7
# 17       267175     2            1    44        145          45    68    1.5
# 18        76146     2            1    28        145          45    60    1.0
# 19        95998     2            1    41        145          45    66    0.8
# 20       981510     2            1    28        150          40    56    1.0
# 21       277404     2            1    41        150          40    74    1.2
# 22       887795     2            1    44        150          40    66    1.0
# 23       911932     2            1    41        150          40    60    1.2
# 24        77121     2            1    41        150          40    58    0.5
# 25       955996     2            1    41        150          40    61    0.7
# 26       252775     2            1    44        150          40    61    1.2
# 27       149132     2            1    46        150          40    54    0.9
# 28         1951     2            1    47        150          40    60    1.5
# 29       151532     2            1    41        150          40    60    1.2
# ...         ...   ...          ...   ...        ...         ...   ...    ...
# 999970   411038     1           14    11        155          55    73    0.2
# 999971   755054     1           14    47        155          55    86    0.1
# 999972   852956     1           14    44        160          50    80    0.1
# 999973   455709     1           14    11        160          50    76    9.9
# 999974   982786     1           14    45        160          50    83    0.6
# 999975   761537     1           14    11        165          65    85    0.7
# 999976   322808     1           14    42        165          65    87    0.2
# 999977   661145     1           14    11        165          65    89    0.7
# 999978   300533     2           14    11        150          40    74    0.1
# 999979   301766     2           14    48        150          40    71    0.1
# 999980   254930     2           14    42        155          45    66    9.9
# 999981   220116     2           14    11        155          45    63    0.2
# 999982   264565     2           14    29        130          30    63    0.3
# 999983   831898     2           14    41        130          30    59    0.2
# 999984   264878     2           14    45        135          35    79    0.2
# 999985   279866     2           14    28        135          35    60    0.1
# 999986   151650     1           14    46        140          35    70    0.2
# 999987    19553     2           14    11        140          40    60    0.2
# 999988   601389     2           14    11        140          40    71    0.5
# 999989   235023     2           14    11        140          40    80    0.7
# 999990   715438     2           14    26        145          35    65    0.2
# 999991   470083     2           14    28        145          35    79    0.3
# 999992   240334     2           14    48        150          35    79    0.1
# 999993   662389     1           14    45        150          40    69    0.4
# 999994   588952     2           14    11        150          45    80    0.8
# 999995   301198     2           14    29        150          50   100    0.5
# 999996   379283     2           14    29        155          45    70    0.2
# 999997   294685     2           14    41        155          45    60    0.2
# 999998   508493     2           14    11        150          45    65    0.1
# 999999   156937     2           14    47        140          35    66    0.1
#
#         시력(우)  청력(좌)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0         0.9    1.0  ...      93.0  11.8  1.0      0.7          21
# 1         1.0    1.0  ...     101.0  12.8  1.0      0.6          31
# 2         1.2    1.0  ...      68.0  14.3  1.0      0.6          23
# 3         0.7    1.0  ...      66.0  11.8  1.0      0.6          21
# 4         0.5    1.0  ...     103.0  11.8  1.0      0.6          35
# 5         0.7    1.0  ...      84.0  13.1  1.0      0.6          24
# 6         0.6    1.0  ...      91.0  14.4  4.0      0.6          28
# 7         0.9    1.0  ...      58.0  10.7  1.0      0.6          24
# 8         1.2    1.0  ...      75.0  11.4  1.0      0.7          32
# 9         0.4    1.0  ...      98.0  11.7  1.0      0.8          26
# 10        1.5    1.0  ...      50.0  13.3  1.0      0.7          26
# 11        0.4    1.0  ...      89.0  14.4  1.0      0.6          18
# 12        0.7    1.0  ...      89.0  11.6  1.0      0.9          19
# 13        1.0    1.0  ...      84.0  13.2  1.0      0.8          18
# 14        1.0    1.0  ...      76.0  10.7  1.0      0.7          20
# 15        0.2    1.0  ...      86.0  13.5  1.0      0.3          15
# 16        0.9    1.0  ...     118.0  11.7  1.0      0.8          21
# 17        1.5    1.0  ...      82.0  13.7  1.0      0.9          29
# 18        1.5    1.0  ...      68.0  12.9  1.0      0.7          17
# 19        0.9    1.0  ...     112.0  13.4  1.0      0.9          13
# 20        0.9    1.0  ...      92.0  14.8  1.0      0.8          25
# 21        0.7    1.0  ...      75.0  13.2  2.0      0.6          20
# 22        1.0    1.0  ...     155.0  13.5  1.0      0.5          20
# 23        1.2    1.0  ...      93.0  13.7  1.0      0.9          19
# 24        0.8    1.0  ...      90.0  13.7  1.0      0.9          22
# 25        1.2    1.0  ...      93.0  11.5  1.0      0.9          20
# 26        1.0    1.0  ...      91.0  14.9  1.0      0.9          24
# 27        0.9    1.0  ...     105.0  13.1  1.0      0.9          24
# 28        1.5    1.0  ...     103.0  13.2  1.0      7.1          14
# 29        0.8    1.0  ...     144.0  13.3  1.0      0.6          15
# ...       ...    ...  ...       ...   ...  ...      ...         ...
# 999970    0.3    2.0  ...      80.0   9.6  3.0      1.2          15
# 999971    0.2    1.0  ...     103.0  12.0  1.0      0.8          24
# 999972    0.4    1.0  ...      75.0  11.2  1.0      0.9          20
# 999973    0.5    2.0  ...      75.0  12.4  1.0      1.4          19
# 999974    0.7    2.0  ...      92.0  11.6  1.0      1.1          21
# 999975    0.9    1.0  ...      70.0  14.6  1.0      1.3          26
# 999976    0.3    1.0  ...      82.0  11.3  1.0      0.9          22
# 999977    0.8    2.0  ...     105.0  12.0  1.0      1.4          25
# 999978    0.1    1.0  ...     114.0  11.7  1.0      0.4          36
# 999979    0.1    1.0  ...     117.0  12.0  NaN      0.9          21
# 999980    0.1    2.0  ...     138.0  10.9  NaN      0.5          19
# 999981    0.1    1.0  ...     139.0  12.8  1.0      1.3          41
# 999982    0.3    1.0  ...      55.0   9.9  1.0      0.7          22
# 999983    0.2    1.0  ...     118.0  12.3  1.0      1.1          21
# 999984    0.2    2.0  ...     156.0  13.7  1.0      0.7          25
# 999985    0.1    1.0  ...     126.0  10.7  NaN      0.6          18
# 999986    0.2    1.0  ...      70.0  12.0  1.0      1.0          34
# 999987    0.3    1.0  ...     114.0  10.9  1.0      0.7          15
# 999988    0.6    2.0  ...      79.0  10.4  1.0      1.1          18
# 999989    0.7    2.0  ...     134.0  11.9  1.0      0.4          21
# 999990    0.2    2.0  ...      79.0   9.8  1.0      0.8          18
# 999991    0.2    1.0  ...      96.0  12.2  1.0      0.8          19
# 999992    0.1    1.0  ...      52.0   7.3  1.0      0.5          18
# 999993    9.9    1.0  ...     193.0  11.7  1.0      1.1          23
# 999994    0.7    1.0  ...     120.0  12.6  1.0      0.6          29
# 999995    0.5    1.0  ...     145.0  12.3  NaN      1.2          26
# 999996    0.2    1.0  ...      85.0   7.9  1.0      1.0          18
# 999997    0.3    1.0  ...      92.0   9.7  1.0      0.7          14
# 999998    0.1    2.0  ...     145.0  12.4  NaN      0.7          16
# 999999    0.1    1.0  ...      84.0   9.7  1.0      0.7          29
#
#         (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부
# 0               17     12   1.0   0.0          0
# 1               23      9   1.0   0.0          0
# 2               16     19   1.0   0.0          1
# 3               11      8   1.0   0.0          1
# 4               17     17   1.0   0.0          0
# 5               11     13   1.0   0.0          1
# 6               10     12   1.0   0.0          0
# 7               12     10   1.0   0.0          1
# 8               25     13   1.0   0.0          1
# 9               13     14   1.0   0.0          0
# 10              13     12   1.0   0.0          0
# 11               9     12   1.0   0.0          0
# 12              10     24   1.0   0.0          1
# 13              10     12   1.0   0.0          1
# 14              15     15   1.0   0.0          0
# 15               7     12   1.0   0.0          1
# 16              12      8   1.0   0.0          0
# 17              17     21   1.0   0.0          1
# 18              13      9   1.0   1.0          1
# 19              10     22   1.0   1.0          1
# 20              22     22   1.0   0.0          1
# 21              11     13   1.0   0.0          0
# 22              11     16   1.0   0.0          1
# 23              13     14   1.0   0.0          1
# 24              19      9   1.0   0.0          1
# 25              13     14   1.0   0.0          0
# 26              17     10   1.0   0.0          1
# 27              13      7   1.0   0.0          1
# 28               8     14   1.0   0.0          1
# 29               9     12   1.0   1.0          1
# ...            ...    ...   ...   ...        ...
# 999970           9      8   1.0   0.0          0
# 999971          10     11   1.0   0.0          0
# 999972          13     23   1.0   0.0          0
# 999973          16     27   1.0   0.0          0
# 999974          19     11   1.0   0.0          1
# 999975          24     37   1.0   0.0          1
# 999976          16      9   1.0   0.0          0
# 999977          17     16   1.0   0.0          0
# 999978          17     34   1.0   0.0          0
# 999979          10     15   1.0   0.0          0
# 999980           9      8   1.0   0.0          0
# 999981          31     13   1.0   0.0          0
# 999982          10     21   1.0   0.0          0
# 999983          10      8   1.0   0.0          0
# 999984          13     11   1.0   0.0          1
# 999985          13      9   1.0   0.0          0
# 999986          28     21   1.0   0.0          0
# 999987           8     11   1.0   0.0          0
# 999988           9      7   1.0   0.0          0
# 999989          14     13   1.0   0.0          0
# 999990           7      8   1.0   0.0          0
# 999991          17     18   1.0   0.0          1
# 999992           6     12   1.0   0.0          0
# 999993          14     14   1.0   0.0          0
# 999994          19     14   1.0   0.0          0
# 999995          24     34   1.0   0.0          0
# 999996           9      8   1.0   0.0          0
# 999997           8      5   1.0   0.0          0
# 999998           6     12   1.0   0.0          0
# 999999          19     16   1.0   0.0          0
#
# [1000000 rows x 27 columns]

# %%
GJ_2010=GJ_2010.drop(['가입자일련번호'],axis=1)
# 편의상 가입자일련번호 변수 제거

# %%
GJ_2010.shape # 1개의 변수가 제거됨
# Out:
# (1000000, 26)

# %%
GJ_2010.isna().sum()

# 결측치가 있는 변수 : 시력좌/시력우/청력좌/청력우/LDL/요단백/흡연상태/음주여부
# Out:
# 성별코드              0
# 연령대코드(5세단위)       0
# 시도코드              0
# 신장(5Cm단위)         0
# 체중(5Kg 단위)        0
# 허리둘레              0
# 시력(좌)           102
# 시력(우)           100
# 청력(좌)            89
# 청력(우)            91
# 수축기혈압             0
# 이완기혈압             0
# 식전혈당(공복혈당)        0
# 총콜레스테롤            0
# 트리글리세라이드          0
# HDL콜레스테롤          0
# LDL콜레스테롤       9685
# 혈색소               0
# 요단백            3663
# 혈청크레아티닌           0
# (혈청지오티)AST        0
# (혈청지오티)ALT        0
# 감마지티피             0
# 흡연상태            967
# 음주여부           1141
# 구강검진 수검여부         0
# dtype: int64

# %%
fill_mean_func = lambda g: g.fillna(g.mean())
GJ_2010=GJ_2010.groupby(['성별코드','연령대코드(5세단위)','시도코드']).apply(fill_mean_func)

# sex, age, sido 그룹별로 결측값 평균치 대체
# mean, median, mode 중 UE(비편향) 성질을 만족하는 평균값으로 대체
# 각 변수별로 이상치가 많으나, 데이터의 갯수가 충분히 확보(100만개)된 상태이므로, mean 사용
# 전반적으로 히스토그램이 우측 긴 꼬리의 형태를 나타내고 있으므로, 평균 > 중앙값 > 최빈값 순서를 따름
# https://rfriend.tistory.com/402 : 결측값을 그룹 평균값으로 채우기 (Fill missing values by Group means)
# 출처: https://rfriend.tistory.com/402 [R, Python 분석과 프로그래밍 (by R Friend)]

# %%
GJ_2010=GJ_2010.drop(['성별코드','연령대코드(5세단위)','시도코드'], axis=1)

# %%
GJ_2010.reset_index(inplace=True)

# 인덱스 초기화
# inplace=True : 객체 반환 x(결과물 안보이게 하기)
# https://nittaku.tistory.com/122

# %%
del GJ_2010['level_3']

# del health['변수명'] : 특정 변수 제거

# %%
GJ_2010.head()
# Out:
#    성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0     1            1    11        150          60    84    0.3    0.3    1.0
# 1     1            1    11        160          55    71    0.2    0.2    1.0
# 2     1            1    11        160          55    67    1.0    1.0    1.0
# 3     1            1    11        165          55    66    0.8    0.8    1.0
# 4     1            1    11        165          55    72    0.5    0.5    1.0
#
#    청력(우)  ...  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  \
# 0    1.0  ...     118.0  15.0  1.0      0.9          19          13     26
# 1    1.0  ...      92.0  15.4  1.0      0.9          19          20     29
# 2    1.0  ...      74.0  14.1  1.0      0.8          14          14     13
# 3    1.0  ...     137.0  13.6  1.0      0.8          27          16     22
# 4    1.0  ...     109.0  16.2  1.0      1.0          29          26     18
#
#    흡연상태  음주여부  구강검진 수검여부
# 0   1.0   0.0          0
# 1   1.0   1.0          0
# 2   2.0   1.0          0
# 3   1.0   0.0          0
# 4   1.0   1.0          1
#
# [5 rows x 26 columns]

# %%
GJ_2010.shape
# Out:
# (1000000, 26)

# %%
GJ_2010.describe()
# Out:
#                  성별코드     연령대코드(5세단위)            시도코드       신장(5Cm단위)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.452642        6.092389       33.286892      162.062345
# std          0.497752        2.773606       12.841314        9.198760
# min          1.000000        1.000000       11.000000      120.000000
# 25%          1.000000        4.000000       26.000000      155.000000
# 50%          1.000000        6.000000       41.000000      160.000000
# 75%          2.000000        8.000000       43.000000      170.000000
# max          2.000000       14.000000       49.000000      190.000000
#
#            체중(5Kg 단위)            허리둘레           시력(좌)           시력(우)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        61.996700       80.131820        0.983317        0.980733
# std         11.535381        9.008045        0.618255        0.612318
# min         25.000000       51.000000        0.100000        0.100000
# 25%         55.000000       74.000000        0.700000        0.700000
# 50%         60.000000       80.000000        1.000000        1.000000
# 75%         70.000000       86.000000        1.200000        1.200000
# max        125.000000      129.000000        9.900000        9.900000
#
#                 청력(좌)           청력(우)  ...        LDL콜레스테롤             혈색소  \
# count  1000000.000000  1000000.000000  ...  1000000.000000  1000000.000000
# mean         1.024686        1.023402  ...      115.078208       13.957065
# std          0.155153        0.151165  ...       67.321453        1.617119
# min          1.000000        1.000000  ...        0.000000        0.100000
# 25%          1.000000        1.000000  ...       91.000000       12.900000
# 50%          1.000000        1.000000  ...      112.000000       14.000000
# 75%          1.000000        1.000000  ...      134.000000       15.100000
# max          2.000000        2.000000  ...     9998.000000       23.700000
#
#                   요단백         혈청크레아티닌      (혈청지오티)AST      (혈청지오티)ALT  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.078407        1.047596       25.170089       25.087415
# std          0.406273        1.177039       15.633365       21.388287
# min          1.000000        0.100000        1.000000        1.000000
# 25%          1.000000        0.800000       19.000000       15.000000
# 50%          1.000000        0.900000       22.000000       20.000000
# 75%          1.000000        1.000000       28.000000       29.000000
# max          6.000000       99.900000      980.000000      996.000000
#
#                 감마지티피            흡연상태            음주여부       구강검진 수검여부
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        36.221478        1.651012        0.483249        0.374604
# std         48.401883        0.853251        0.499519        0.484021
# min          1.000000        1.000000        0.000000        0.000000
# 25%         15.000000        1.000000        0.000000        0.000000
# 50%         23.000000        1.000000        0.000000        0.000000
# 75%         39.000000        3.000000        1.000000        1.000000
# max        999.000000        3.000000        1.000000        1.000000
#
# [8 rows x 26 columns]

# %%
GJ_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
# 성별코드           1000000 non-null int64
# 연령대코드(5세단위)    1000000 non-null int64
# 시도코드           1000000 non-null int64
# 신장(5Cm단위)      1000000 non-null int64
# 체중(5Kg 단위)     1000000 non-null int64
# 허리둘레           1000000 non-null int64
# 시력(좌)          1000000 non-null float64
# 시력(우)          1000000 non-null float64
# 청력(좌)          1000000 non-null float64
# 청력(우)          1000000 non-null float64
# 수축기혈압          1000000 non-null int64
# 이완기혈압          1000000 non-null int64
# 식전혈당(공복혈당)     1000000 non-null int64
# 총콜레스테롤         1000000 non-null int64
# 트리글리세라이드       1000000 non-null int64
# HDL콜레스테롤       1000000 non-null int64
# LDL콜레스테롤       1000000 non-null float64
# 혈색소            1000000 non-null float64
# 요단백            1000000 non-null float64
# 혈청크레아티닌        1000000 non-null float64
# (혈청지오티)AST     1000000 non-null int64
# (혈청지오티)ALT     1000000 non-null int64
# 감마지티피          1000000 non-null int64
# 흡연상태           1000000 non-null float64
# 음주여부           1000000 non-null float64
# 구강검진 수검여부      1000000 non-null int64
# dtypes: float64(10), int64(16)
# memory usage: 198.4 MB

# %%
GJ_2010 = GJ_2010.rename(columns = {'성별코드' : 'sex',
                    '연령대코드(5세단위)' : 'year',
                    '시도코드' : 'sido',
                    '신장(5Cm단위)' : 'height',
                    '체중(5Kg 단위)' : 'weight',
                    '허리둘레' : 'waist',
                    '시력(좌)' : 'sight_left',
                    '시력(우)' : 'sight_right',
                    '청력(좌)' : 'hearing_left',
                    '청력(우)' : 'hearing_right',
                    '수축기혈압' : 'SBP',
                    '이완기혈압' : 'RPBP',
                    '식전혈당(공복혈당)' : 'pred_blood_sugar',
                    '총콜레스테롤' : 'cholesterol',
                    '트리글리세라이드' : 'triglycerides',
                    'HDL콜레스테롤' : 'HDL',
                    'LDL콜레스테롤' : 'LDL',
                    '혈색소' : 'blood_pigment',
                    '요단백' : 'urine_protein',
                    '혈청크레아티닌' : 'serum_creatinine',
                    '(혈청지오티)AST' : 'AST',
                    '(혈청지오티)ALT' : 'ALT',
                    '감마지티피' : 'gamma_gtp',
                    '흡연상태' : 'smoking',
                    '음주여부' : 'alcohol',
                    '구강검진 수검여부' : 'oral_inspection'})

# 시각화에서 변수명 출력을 위해 영어로 변경

# %%
GJ_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
# sex                 1000000 non-null int64
# year                1000000 non-null int64
# sido                1000000 non-null int64
# height              1000000 non-null int64
# weight              1000000 non-null int64
# waist               1000000 non-null int64
# sight_left          1000000 non-null float64
# sight_right         1000000 non-null float64
# hearing_left        1000000 non-null float64
# hearing_right       1000000 non-null float64
# SBP                 1000000 non-null int64
# RPBP                1000000 non-null int64
# pred_blood_sugar    1000000 non-null int64
# cholesterol         1000000 non-null int64
# triglycerides       1000000 non-null int64
# HDL                 1000000 non-null int64
# LDL                 1000000 non-null float64
# blood_pigment       1000000 non-null float64
# urine_protein       1000000 non-null float64
# serum_creatinine    1000000 non-null float64
# AST                 1000000 non-null int64
# ALT                 1000000 non-null int64
# gamma_gtp           1000000 non-null int64
# smoking             1000000 non-null float64
# alcohol             1000000 non-null float64
# oral_inspection     1000000 non-null int64
# dtypes: float64(10), int64(16)
# memory usage: 198.4 MB

# %%
import matplotlib
import matplotlib.pyplot as plt

# 데이터 탐색을 위한 시각화 패키지 장착

# %%
plt.hist(GJ_2010['height'], histtype='bar', rwidth=0.9)
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
plt.boxplot(GJ_2010['height'])
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# %%
GJ_2010['pred_blood_sugar'] = np.where(GJ_2010['pred_blood_sugar'] >= 126, 1, 0)

# target 변수인 pred_blood_sugar가 126 이상일 때, 당뇨진단으로 판정
# 이분형 자료로 변환
# https://rfriend.tistory.com/tag/Python

# %%
GJ_2010['pred_blood_sugar'].value_counts()

# 당뇨진단자 비율 : 약 7%
# Out:
# 0    938468
# 1     61532
# Name: pred_blood_sugar, dtype: int64

# %% [markdown]
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
GJ_2010.hist(bins=50, figsize=(20,15))
plt.show()



# ALT / AST / HDL / LDL / RPBP / SBP / cholesterol / gamma_gtp / height / serum_creatinine / sight_left / sight_right -> skwed distribution
# triglycerides / urine_protein / waist / weight -> skwed distribution
# blood_pigment -> normal distribution
# alcohol / oral_inspection -> 이산형, 비교적 고른 분포
# hearing_left / hearing_right / smoking / pred_blood_sugar -> class unbalance
# sex / year / sido -> groupby 기준변수

# %%
GJ_2010.boxplot(figsize=(30,15))
plt.show()

# %% [markdown]
# # 이상치 처리
# 일반적으로 1) 표준점수로 변환 후 -3 이하 및 +3 제거 2) IQR 방식 3) 도메인 지식 이용하거나 Binning 처리하는 방식이 이용된다.
#
# 표준점수 이용할 경우 평균이 0, 표준편차가 1인 분포로 변환한후 +3 이상이거나 -3 이하인 경우 극단치로 처리한다.
#
# IQR 방식은 75% percentile * 1.5 이상이거나 25 percentile* 1.5 이하인 경우 극단치로 처리하는 방식이다.
# 이해하기 쉽고 적용하기 쉬운 편이지만, 경우에 따라 너무 많은 사례들이 극단치로 고려되는 경우가 있다.
#
# https://wikidocs.net/16582
#
# ![image.png](attachment:image.png)
#
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 3)
    upper_bound = quartile_3 + (iqr * 3)
    return np.where((ys > upper_bound) | (ys < lower_bound))

# %%
print(np.array(outliers_iqr(GJ_2010['height'])).shape[1],
      np.array(outliers_iqr(GJ_2010['weight'])).shape[1],
      np.array(outliers_iqr(GJ_2010['waist'])).shape[1],
      np.array(outliers_iqr(GJ_2010['sight_left'])).shape[1],
      np.array(outliers_iqr(GJ_2010['sight_right'])).shape[1],
      np.array(outliers_iqr(GJ_2010['SBP'])).shape[1],
      np.array(outliers_iqr(GJ_2010['RPBP'])).shape[1],
      np.array(outliers_iqr(GJ_2010['pred_blood_sugar'])).shape[1],
      np.array(outliers_iqr(GJ_2010['cholesterol'])).shape[1],
      np.array(outliers_iqr(GJ_2010['triglycerides'])).shape[1],
      np.array(outliers_iqr(GJ_2010['HDL'])).shape[1],
      np.array(outliers_iqr(GJ_2010['LDL'])).shape[1],
      np.array(outliers_iqr(GJ_2010['blood_pigment'])).shape[1],
      np.array(outliers_iqr(GJ_2010['serum_creatinine'])).shape[1],
      np.array(outliers_iqr(GJ_2010['AST'])).shape[1],
      np.array(outliers_iqr(GJ_2010['ALT'])).shape[1],
      np.array(outliers_iqr(GJ_2010['gamma_gtp'])).shape[1])

# Outer fence(바깥 울타리) 기준 심각한 이상치는 최소 24개를 가진 변수부터 최대 42361를 가진 변수까지 있음
# gamma_gtp 변수의 OF 기준 이상치 제거할 경우, 데이터 손실율 약 4.2%
# 특정 연령, 성별, 시/도에 해당하는 범주의 경우, 이상치 비율이 많을 경우 문제 발생
# 이상치 제거 방법으로 IQR 정보를 이용하는 것이 바람직하지 않을 수 있음
# Out:
# 0 33 24 3172 3093 596 2136 61532 594 16490 1713 1764 348 22021 22329 26289 42361

# %% [markdown]
# 데이터 단위 변환
# 데이터의 스케일(측정단위)이 다를 경우 특히 거리를 기반으로 분류하는 모델(KNN 등)에 부정적인 영향을 미치므로, 스케일링을 통해 단위를 일정하게 맞추는 작업을 진행해야 한다. 아래 방식이 주로 스케일링을 위해 쓰이는 방법이다. 대부분의 통계 분석 방법이 정규성 가정을 기반으로 하므로 완벽하지 않더라도 최대한 정규분포로 변환하는 노력이 필요하다.
#
# Scaling: 평균이 0, 분산이 1인 분포로 변환
# MinMax Scaling: 특정 범위 (예, 0~1)로 모든 데이터를 변환
# Box-Cox: 여러 k 값중 가장 작은 SSE 선택
# Robust_scale: median, interquartile range 사용(outlier 영향 최소화)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# http://ko.logpresso.com/documents/anomaly-detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clf = IsolationForest(max_samples=1000, random_state=1, contamination=0.01, max_features=2)
# Isolation Forest 방법을 사용하기 위해, 변수로 선언을 해 준다.
# n_estimators=100 : 학습모형 100개
# max_samples=100 : 모형 당 최대 아웃라이어 갯수 1000개
# contamination='legacy' : 아웃라이어 비율 : 0.01(10000개)
# max_features=2 : 각 학습모형이 2개의 변수로 학습됨
# bootstrap=False : 각 학습모형이 샘플을 비복원 추출함
clf.fit(GJ_2010)
# fit 함수를 이용하여, 데이터셋을 학습
y_pred_outliers = clf.predict(GJ_2010)
# predict 함수를 이용하여, outlier를 판별. 0과 1로 이루어진 Series형태의 데이터가 나옴

out = pd.DataFrame(y_pred_outliers)
out = out.rename(columns={0: "out"})
GJ_2010 = pd.concat([GJ_2010, out], 1)
# 원래의 dataframe에 붙이기. 데이터가 0인 것이 outlier이기 때문에, 0인 것을 제거하면 outlier가 제거된 dataframe을 얻을 수 있음

# https://mkjjo.github.io/python/2019/01/10/outlier.html
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html
# Out:
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
GJ_2010['out'].value_counts()

# 10000개의 이상치를 detecting(label : -1)
# Out:
#  1    990000
# -1     10000
# Name: out, dtype: int64

# %%
GJ_2010=GJ_2010[GJ_2010['out']==1]

# %%
GJ_2010.boxplot(figsize=(30,15))
plt.show()

# %%
GJ_2010=GJ_2010[GJ_2010['LDL']<4000]

# Box-plot에서 불연속이면서 많은 값의 차이를 보이는 이상치 제거

# %%
GJ_2010.boxplot(figsize=(30,15))
plt.show()

# 불연속으로 많이 떨어진 이상치 제거

# %%
del GJ_2010['out']

# %%
GJ_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 989980 entries, 0 to 999998
# Data columns (total 26 columns):
# sex                 989980 non-null int64
# year                989980 non-null int64
# sido                989980 non-null int64
# height              989980 non-null int64
# weight              989980 non-null int64
# waist               989980 non-null int64
# sight_left          989980 non-null float64
# sight_right         989980 non-null float64
# hearing_left        989980 non-null float64
# hearing_right       989980 non-null float64
# SBP                 989980 non-null int64
# RPBP                989980 non-null int64
# pred_blood_sugar    989980 non-null int32
# cholesterol         989980 non-null int64
# triglycerides       989980 non-null int64
# HDL                 989980 non-null int64
# LDL                 989980 non-null float64
# blood_pigment       989980 non-null float64
# urine_protein       989980 non-null float64
# serum_creatinine    989980 non-null float64
# AST                 989980 non-null int64
# ALT                 989980 non-null int64
# gamma_gtp           989980 non-null int64
# smoking             989980 non-null float64
# alcohol             989980 non-null float64
# oral_inspection     989980 non-null int64
# dtypes: float64(10), int32(1), int64(15)
# memory usage: 200.2 MB

# %%
GJ_2010 = GJ_2010.rename(columns = {'height' : 'height_2010',
                    'weight' : 'weight_2010',
                    'waist' : 'waist_2010',
                    'sight_left' : 'sight_left_2010',
                    'sight_right' : 'sight_right_2010',
                    'hearing_left' : 'hearing_left_2010',
                    'hearing_right' : 'hearing_right_2010',
                    'SBP' : 'SBP_2010',
                    'RPBP' : 'RPBP_2010',
                    'cholesterol' : 'cholesterol_2010',
                    'triglycerides' : 'triglycerides_2010',
                    'HDL' : 'HDL_2010',
                    'LDL' : 'LDL_2010',
                    'blood_pigment' : 'blood_pigment_2010',
                    'urine_protein' : 'urine_protein_2010',
                    'serum_creatinine' : 'serum_creatinine_2010',
                    'AST' : 'AST_2010',
                    'ALT' : 'ALT_2010',
                    'gamma_gtp' : 'gamma_gtp_2010',
                    'smoking' : 'smoking_2010',
                    'alcohol' : 'alcohol_2010',
                    'oral_inspection' : 'oral_inspection_2010'})

# 2017년도 건강검진정보 예측변수(22개) rename

# %%
GJ_2010['target'] = GJ_2010['pred_blood_sugar']

# %%
del GJ_2010['pred_blood_sugar']

# %%
plt.hist(GJ_2010['target'], histtype='bar', rwidth=0.9)
plt.xlabel('pre_blood_sugar')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
GJ_2010_group = GJ_2010.groupby(['sex','year','sido']).mean()

# 시/도 그룹별 평균치를 저장

# %%
GJ_2010_group.reset_index(inplace=True)

# %%
GJ_2010_group

# 448개 범주를 가지는 자료형태로 변환
# dimension : 448x26
# Out:
#      sex  year  sido  height_2010  weight_2010  waist_2010  sight_left_2010  \
# 0      1     1    11   172.173469    67.867347   78.109184         1.077245
# 1      1     1    26   171.097786    66.097786   77.298893         1.077491
# 2      1     1    27   171.430063    67.400835   78.768267         1.058246
# 3      1     1    28   171.723549    66.894198   77.800341         1.096758
# 4      1     1    29   171.442308    66.673077   77.980769         1.121923
# 5      1     1    30   171.965066    66.899563   77.659389         1.096507
# 6      1     1    31   171.307692    66.358974   77.728205         1.082564
# 7      1     1    41   171.438866    66.508601   77.575081         1.129149
# 8      1     1    42   172.239583    68.979167   78.479167         1.141875
# 9      1     1    43   171.687980    67.046036   77.869565         1.171867
# 10     1     1    44   171.091837    65.622449   76.971429         1.173878
# 11     1     1    45   171.193634    66.909814   78.068966         1.176393
# 12     1     1    46   171.754386    67.298246   78.189474         1.198246
# 13     1     1    47   171.415094    66.234277   77.426101         1.130346
# 14     1     1    48   170.986842    65.861244   77.331340         1.115072
# 15     1     1    49   172.260274    67.876712   78.643836         1.091781
# 16     1     2    11   172.865781    70.905648   81.290764         1.094498
# 17     1     2    26   172.102076    69.956747   80.685121         1.093668
# 18     1     2    27   172.143595    70.167872   81.110021         1.086002
# 19     1     2    28   172.000000    69.894052   80.909665         1.105390
# 20     1     2    29   171.539855    69.116848   80.673007         1.119112
# 21     1     2    30   172.701383    70.724166   80.707893         1.141334
# 22     1     2    31   172.125926    69.951852   80.843704         1.035407
# 23     1     2    41   171.939083    69.583836   80.445459         1.128718
# 24     1     2    42   172.449139    71.494523   81.349765         1.151565
# 25     1     2    43   171.856984    69.121397   80.258315         1.155987
# 26     1     2    44   171.968273    69.390913   80.502154         1.154994
# 27     1     2    45   172.016518    69.105299   79.843083         1.180248
# 28     1     2    46   171.824961    69.230769   80.485086         1.137363
# 29     1     2    47   171.430344    68.821340   80.112726         1.139383
# ..   ...   ...   ...          ...          ...         ...              ...
# 418    2    13    27   146.005587    49.357542   80.737430         0.597207
# 419    2    13    28   146.517241    50.689655   83.137931         0.702069
# 420    2    13    29   146.727941    48.713235   81.602941         0.678676
# 421    2    13    30   145.808824    48.750000   82.117647         0.666912
# 422    2    13    31   147.352941    49.352941   80.658824         0.678824
# 423    2    13    41   146.280048    49.771635   81.856971         0.563172
# 424    2    13    42   146.200000    49.275000   81.075000         0.463416
# 425    2    13    43   144.328859    47.214765   80.328859         0.573154
# 426    2    13    44   145.635593    47.457627   81.250000         0.619915
# 427    2    13    45   145.528455    48.211382   79.662602         0.680081
# 428    2    13    46   146.535714    49.053571   81.564286         0.554643
# 429    2    13    47   145.562701    48.102894   80.623794         0.489389
# 430    2    13    48   145.927673    48.144654   79.877358         0.529269
# 431    2    13    49   146.538462    48.615385   79.030769         0.437628
# 432    2    14    11   145.559701    46.156716   80.149254         0.511940
# 433    2    14    26   147.307692    47.019231   80.307692         0.444231
# 434    2    14    27   145.666667    44.166667   79.500000         0.450000
# 435    2    14    28   144.777778    45.777778   78.800000         0.604444
# 436    2    14    29   146.585366    46.219512   78.536585         0.356098
# 437    2    14    30   145.625000    45.375000   78.675000         0.407500
# 438    2    14    31   145.000000    45.769231   77.923077         0.400000
# 439    2    14    41   145.062893    45.911950   79.823899         0.406918
# 440    2    14    42   143.875000    47.875000   82.450000         0.360000
# 441    2    14    43   146.041667    48.750000   82.375000         0.379167
# 442    2    14    44   145.384615    44.423077   78.173077         0.363462
# 443    2    14    45   143.048780    43.292683   76.317073         0.426829
# 444    2    14    46   145.600000    44.900000   80.420000         0.726000
# 445    2    14    47   144.827586    44.137931   78.413793         0.379310
# 446    2    14    48   144.523810    44.285714   77.476190         0.495238
# 447    2    14    49   146.785714    51.071429   80.642857         0.414286
#
#      sight_right_2010  hearing_left_2010  hearing_right_2010  ...  \
# 0            1.077245           1.001020            1.003061  ...
# 1            1.086162           1.000000            1.003690  ...
# 2            1.049687           1.004175            1.002088  ...
# 3            1.068942           1.000000            1.006826  ...
# 4            1.113077           1.011538            1.007692  ...
# 5            1.100437           1.000000            1.000000  ...
# 6            1.059487           1.005128            1.000000  ...
# 7            1.125198           1.004184            1.006974  ...
# 8            1.151042           1.002083            1.000000  ...
# 9            1.159847           1.002558            1.000000  ...
# 10           1.146531           1.002041            1.002041  ...
# 11           1.153316           1.002653            1.002653  ...
# 12           1.155439           1.000000            1.000000  ...
# 13           1.140881           1.011006            1.012579  ...
# 14           1.109928           1.004785            1.005981  ...
# 15           1.123288           1.000000            1.000000  ...
# 16           1.084543           1.001728            1.000930  ...
# 17           1.092180           1.004498            1.005882  ...
# 18           1.101550           1.004135            1.004651  ...
# 19           1.107435           1.004461            1.004833  ...
# 20           1.106884           1.002717            1.003623  ...
# 21           1.126363           1.001627            1.001627  ...
# 22           1.023185           1.003704            1.002963  ...
# 23           1.119309           1.002585            1.003188  ...
# 24           1.150782           1.000782            1.000782  ...
# 25           1.153714           1.002217            1.002772  ...
# 26           1.139483           1.006267            1.004309  ...
# 27           1.160771           1.005506            1.004129  ...
# 28           1.127473           1.003925            1.004710  ...
# 29           1.131301           1.005672            1.005672  ...
# ..                ...                ...                 ...  ...
# 418          0.655307           1.055866            1.067039  ...
# 419          0.566897           1.089655            1.048276  ...
# 420          0.484559           1.102941            1.110294  ...
# 421          0.544853           1.088235            1.102941  ...
# 422          0.680000           1.082353            1.082353  ...
# 423          0.645211           1.113155            1.102324  ...
# 424          0.502877           1.080000            1.090000  ...
# 425          0.491058           1.080537            1.087248  ...
# 426          0.593220           1.046610            1.046610  ...
# 427          0.532927           1.089431            1.065041  ...
# 428          0.716786           1.071429            1.082143  ...
# 429          0.504823           1.112540            1.122186  ...
# 430          0.618908           1.107370            1.088468  ...
# 431          0.449615           1.153846            1.138462  ...
# 432          0.446269           1.104478            1.074627  ...
# 433          0.457692           1.057692            1.057692  ...
# 434          1.060000           1.100000            1.133333  ...
# 435          0.788889           1.155556            1.044444  ...
# 436          0.392683           1.146341            1.146341  ...
# 437          0.657500           1.050000            1.075000  ...
# 438          0.400000           1.000000            1.000000  ...
# 439          0.593711           1.100629            1.113208  ...
# 440          0.602500           1.025000            1.050000  ...
# 441          0.762500           1.083333            1.083333  ...
# 442          0.736538           1.057692            1.057692  ...
# 443          0.426829           1.048780            1.024390  ...
# 444          0.360000           1.080000            1.060000  ...
# 445          0.525862           1.086207            1.120690  ...
# 446          0.706349           1.015873            1.000000  ...
# 447          0.350000           1.142857            1.000000  ...
#
#      blood_pigment_2010  urine_protein_2010  serum_creatinine_2010   AST_2010  \
# 0             15.225102            1.041837               1.111633  23.614286
# 1             15.137638            1.036900               1.119742  23.983395
# 2             15.225470            1.033403               1.115658  22.726514
# 3             15.240273            1.034130               1.148294  23.104096
# 4             15.170769            1.015385               1.146923  23.534615
# 5             15.272926            1.048035               1.158515  23.262009
# 6             15.056410            1.041026               1.598462  24.517949
# 7             15.212692            1.049327               1.155370  23.446304
# 8             14.963750            1.035499               1.353958  23.708333
# 9             15.279284            1.015345               1.098465  25.373402
# 10            15.281224            1.044898               1.123878  22.948980
# 11            15.020159            1.047745               1.193369  23.700265
# 12            15.151228            1.017668               1.284561  24.354386
# 13            15.210535            1.025206               1.915881  23.305031
# 14            15.088756            1.059952               1.100239  23.686603
# 15            15.321918            1.095890               1.300000  22.945205
# 16            15.355708            1.048000               1.230140  24.355482
# 17            15.258962            1.036386               1.195363  24.659170
# 18            15.234866            1.052227               1.146436  23.811983
# 19            15.314721            1.042429               1.204907  24.797770
# 20            15.256975            1.021778               1.038949  25.454710
# 21            15.351098            1.049676               1.476810  24.650936
# 22            15.107630            1.025185               2.736963  24.588148
# 23            15.352137            1.041380               1.143753  25.194038
# 24            15.219249            1.032864               1.313459  25.629108
# 25            15.355931            1.034408               1.287694  24.809313
# 26            15.423972            1.027419               1.167019  23.916177
# 27            15.148451            1.029616               1.156160  24.883001
# 28            15.181868            1.032182               1.137755  25.683673
# 29            15.327650            1.029777               2.122049  24.798653
# ..                  ...                 ...                    ...        ...
# 418           12.353073            1.203737               0.930168  23.502793
# 419           12.668276            1.136006               0.937931  24.365517
# 420           12.288235            1.061528               0.888971  25.794118
# 421           12.525735            1.106389               0.833824  22.426471
# 422           11.963529            1.038235               0.924706  23.317647
# 423           12.419351            1.129118               0.903726  24.804087
# 424           12.491000            1.075587               0.999500  24.385000
# 425           12.299329            1.102795               0.874497  24.348993
# 426           12.466525            1.071442               0.842373  23.533898
# 427           12.016667            1.068596               0.914634  23.126016
# 428           12.126786            1.061156               0.898214  24.392857
# 429           12.274598            1.112873               0.875563  23.919614
# 430           12.003774            1.075472               0.844969  26.716981
# 431           12.404615            1.342959               0.961538  28.461538
# 432           12.061940            1.112386               1.046269  23.865672
# 433           11.400000            1.002137               1.017308  24.769231
# 434           11.790000            1.076923               0.890000  24.400000
# 435           12.206667            1.215556               0.942222  23.155556
# 436           11.726829            1.026303               0.880488  22.463415
# 437           11.932500            1.000000               0.837500  22.075000
# 438           11.938462            1.384615               0.753846  21.615385
# 439           12.131447            1.102404               0.907547  23.339623
# 440           12.457500            1.128500               0.857500  21.650000
# 441           12.191667            1.090278               0.904167  26.000000
# 442           12.192308            1.048408               0.855769  23.096154
# 443           11.282927            1.059233               1.097561  21.048780
# 444           11.738000            1.081967               0.878000  24.560000
# 445           12.062069            1.003364               0.815517  23.465517
# 446           11.890476            1.086224               0.798413  23.587302
# 447           12.578571            1.386364               0.921429  27.214286
#
#       ALT_2010  gamma_gtp_2010  smoking_2010  alcohol_2010  \
# 0    22.522449       24.128571      2.038776      0.720408
# 1    21.640221       21.738007      2.057196      0.699262
# 2    22.398747       22.356994      2.081420      0.691023
# 3    21.506826       24.324232      2.165529      0.692833
# 4    22.192308       22.084615      2.165385      0.688462
# 5    20.921397       23.668122      2.209607      0.681223
# 6    21.010256       23.128205      2.225641      0.738462
# 7    22.531846       25.716411      2.129242      0.705718
# 8    21.714583       24.462500      2.245833      0.716667
# 9    22.309463       25.675192      2.191816      0.721228
# 10   21.553061       23.293878      2.132653      0.675510
# 11   22.591512       23.132626      2.137931      0.657825
# 12   22.831579       24.221053      2.098246      0.750877
# 13   21.740566       23.507862      2.121069      0.704403
# 14   20.736842       23.116029      2.144737      0.677033
# 15   23.726027       28.260274      2.123288      0.835616
# 16   26.980731       33.669635      2.081254      0.786408
# 17   27.352941       32.897924      2.243945      0.774048
# 18   27.369835       32.758264      2.217975      0.752455
# 19   28.199628       36.534572      2.247305      0.759018
# 20   29.200181       32.818841      2.147645      0.721014
# 21   27.913751       33.993491      2.200976      0.783564
# 22   27.300000       31.301481      2.258519      0.789474
# 23   28.023092       34.471480      2.173348      0.746207
# 24   28.793427       36.360720      2.229264      0.768388
# 25   27.276053       34.278825      2.246120      0.755543
# 26   27.392871       33.367803      2.169213      0.743439
# 27   27.286992       33.384033      2.187887      0.757743
# 28   28.014129       34.383830      2.125789      0.749215
# 29   27.836583       33.339596      2.192554      0.768003
# ..         ...             ...           ...           ...
# 418  17.290503       21.463687      1.094972      0.016760
# 419  18.344828       22.572414      1.075862      0.013793
# 420  20.463235       21.551471      1.051471      0.029412
# 421  15.904412       22.161765      1.073529      0.022059
# 422  15.882353       20.223529      1.094118      0.035294
# 423  18.257212       21.995192      1.043269      0.025240
# 424  17.245000       21.455000      1.100000      0.035000
# 425  16.986577       19.879195      1.040268      0.040268
# 426  17.194915       19.258475      1.050847      0.042373
# 427  16.158537       18.373984      1.056911      0.028455
# 428  18.771429       21.889286      1.035714      0.028571
# 429  17.247588       19.479100      1.067524      0.028939
# 430  18.059748       21.896226      1.081761      0.037736
# 431  18.692308       19.123077      1.000000      0.030769
# 432  15.462687       17.380597      1.022388      0.007463
# 433  17.442308       19.288462      1.000000      0.019231
# 434  16.266667       17.700000      1.033333      0.000000
# 435  15.488889       20.311111      1.022222      0.000000
# 436  15.414634       16.512195      1.000000      0.000000
# 437  15.000000       21.225000      1.050000      0.000000
# 438  12.153846       20.153846      1.000000      0.000000
# 439  15.345912       17.301887      1.025157      0.000000
# 440  15.400000       17.625000      1.000000      0.000000
# 441  14.791667       16.416667      1.000000      0.041667
# 442  14.500000       20.461538      1.000000      0.000000
# 443  13.341463       19.585366      1.000000      0.000000
# 444  18.440000       23.520000      1.000000      0.000000
# 445  15.672414       19.982759      1.000000      0.000000
# 446  15.158730       20.142857      1.063492      0.031746
# 447  18.642857       20.642857      1.000000      0.000000
#
#      oral_inspection_2010    target
# 0                0.591837  0.007143
# 1                0.549815  0.001845
# 2                0.359081  0.000000
# 3                0.686007  0.006826
# 4                0.573077  0.003846
# 5                0.650655  0.004367
# 6                0.620513  0.010256
# 7                0.612738  0.006509
# 8                0.735417  0.008333
# 9                0.647059  0.005115
# 10               0.726531  0.008163
# 11               0.639257  0.005305
# 12               0.617544  0.021053
# 13               0.592767  0.001572
# 14               0.370813  0.009569
# 15               0.356164  0.013699
# 16               0.547641  0.006246
# 17               0.505190  0.013149
# 18               0.332128  0.012397
# 19               0.640149  0.010037
# 20               0.465580  0.016304
# 21               0.583401  0.011391
# 22               0.716296  0.005926
# 23               0.563071  0.007151
# 24               0.539906  0.013302
# 25               0.628603  0.009424
# 26               0.716804  0.012143
# 27               0.593255  0.016518
# 28               0.521978  0.017268
# 29               0.549805  0.009571
# ..                    ...       ...
# 418              0.089385  0.106145
# 419              0.165517  0.103448
# 420              0.095588  0.132353
# 421              0.102941  0.080882
# 422              0.094118  0.105882
# 423              0.158654  0.106971
# 424              0.105000  0.105000
# 425              0.120805  0.100671
# 426              0.097458  0.088983
# 427              0.142276  0.089431
# 428              0.017857  0.085714
# 429              0.041801  0.083601
# 430              0.069182  0.100629
# 431              0.107692  0.092308
# 432              0.134328  0.044776
# 433              0.038462  0.250000
# 434              0.033333  0.233333
# 435              0.155556  0.200000
# 436              0.073171  0.097561
# 437              0.050000  0.050000
# 438              0.076923  0.230769
# 439              0.088050  0.088050
# 440              0.050000  0.050000
# 441              0.083333  0.083333
# 442              0.038462  0.153846
# 443              0.073171  0.097561
# 444              0.040000  0.080000
# 445              0.017241  0.086207
# 446              0.000000  0.190476
# 447              0.000000  0.142857
#
# [448 rows x 26 columns]

# %%
GJ_2010_group.to_csv("GJ_2010_group.csv")

# 2010년 건강검진정보 데이터전처리 -> 448개 범주화된 자료를 csv로 저장
# https://tariat.tistory.com/583

# %%
# 척도화
# https://mkjjo.github.io/python/2019/01/10/scaler.html

# 데이터 분할
# https://pythonanalysis.tistory.com/7

# 데이터 분포 변환
# https://wikidocs.net/16582
