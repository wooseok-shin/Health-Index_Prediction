# %% [markdown]
# # 데이터 불러오기 및 전처리

# %%
import pandas as pd
import numpy as np

# 데이터 전처리에 필요한 패키지 장착

# %%
GJ_2016=pd.read_csv("./NHIS_OPEN_GJ_2016.csv",encoding='CP949') # 데이터 불러오기
GJ_2016.head() # 데이터 일부 확인
# Out:
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  \
# 0  2016        1     1           10    27      175.0       75.0  86.0    1.0
# 1  2016        2     2           11    41      160.0       65.0  85.0    1.5
# 2  2016        3     2           11    43      150.0       55.0  80.0    1.5
# 3  2016        4     1           12    48      175.0       70.0  85.0    1.2
# 4  2016        5     2            6    11      160.0       50.0  67.0    0.4
#
#    시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 0    1.2  ...   45.0   3.0   NaN          0      NaN    NaN      NaN
# 1    1.2  ...   19.0   1.0   NaN          0      NaN    NaN      NaN
# 2    1.5  ...   64.0   1.0   NaN          0      NaN    NaN      NaN
# 3    1.2  ...   69.0   2.0   NaN          1      NaN    NaN      NaN
# 4    0.5  ...   20.0   1.0   NaN          0      NaN    NaN      NaN
#
#    제3대구치(사랑니)이상   치석   데이터공개일자
# 0           NaN  NaN  20171219
# 1           NaN  NaN  20171219
# 2           NaN  NaN  20171219
# 3           NaN  1.0  20171219
# 4           NaN  NaN  20171219
#
# [5 rows x 34 columns]

# %%
GJ_2016.shape # 데이터 차원 : 1000000 x 34
# Out:
# (1000000, 34)

# %%
GJ_2016.info() # 34개 변수 타입 : 정수형 또는 실수형
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
# 기준년도            1000000 non-null int64
# 가입자일련번호         1000000 non-null int64
# 성별코드            1000000 non-null int64
# 연령대코드(5세단위)     1000000 non-null int64
# 시도코드            1000000 non-null int64
# 신장(5Cm단위)       999103 non-null float64
# 체중(5Kg단위)       999103 non-null float64
# 허리둘레            999807 non-null float64
# 시력(좌)           999700 non-null float64
# 시력(우)           999701 non-null float64
# 청력(좌)           999734 non-null float64
# 청력(우)           999734 non-null float64
# 수축기혈압           999912 non-null float64
# 이완기혈압           999911 non-null float64
# 식전혈당(공복혈당)      999952 non-null float64
# 총콜레스테롤          999957 non-null float64
# 트리글리세라이드        999956 non-null float64
# HDL콜레스테롤        999953 non-null float64
# LDL콜레스테롤        997369 non-null float64
# 혈색소             999947 non-null float64
# 요단백             995101 non-null float64
# 혈청크레아티닌         999955 non-null float64
# (혈청지오티)AST      999958 non-null float64
# (혈청지오티)ALT      999957 non-null float64
# 감마지티피           999957 non-null float64
# 흡연상태            999787 non-null float64
# 음주여부            0 non-null float64
# 구강검진 수검여부       1000000 non-null int64
# 치아우식증유무         0 non-null float64
# 결손치유무           0 non-null float64
# 치아마모증유무         0 non-null float64
# 제3대구치(사랑니)이상    0 non-null float64
# 치석              401763 non-null float64
# 데이터공개일자         1000000 non-null int64
# dtypes: float64(27), int64(7)
# memory usage: 259.4 MB

# %%
GJ_2016.isna().sum()

# 결측치가 있는 변수 : 신장/체중/허리둘레/시력좌/시력우/청력좌/청력우/수축기혈압/이완기혈압/식전혈당/총콜레스테롤
# 결측치가 있는 변수 : 트리글리세라이드/HDL/LDL/혈색소/요단백/혈청크레아티닌/AST/ALT/GTP/흡연상태/음주여부
# 결측치가 있는 변수 : 치아우식증유무/결손치유무/치아마모증유무/사랑니이상/치석
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)           897
# 체중(5Kg단위)           897
# 허리둘레                193
# 시력(좌)               300
# 시력(우)               299
# 청력(좌)               266
# 청력(우)               266
# 수축기혈압                88
# 이완기혈압                89
# 식전혈당(공복혈당)           48
# 총콜레스테롤               43
# 트리글리세라이드             44
# HDL콜레스테롤             47
# LDL콜레스테롤           2631
# 혈색소                  53
# 요단백                4899
# 혈청크레아티닌              45
# (혈청지오티)AST           42
# (혈청지오티)ALT           43
# 감마지티피                43
# 흡연상태                213
# 음주여부            1000000
# 구강검진 수검여부             0
# 치아우식증유무         1000000
# 결손치유무           1000000
# 치아마모증유무         1000000
# 제3대구치(사랑니)이상    1000000
# 치석               598237
# 데이터공개일자               0
# dtype: int64

# %%
GJ_2016=GJ_2016.drop(['치석','음주여부','치아우식증유무','결손치유무','치아마모증유무','제3대구치(사랑니)이상'],axis=1)

# 결측비율이 약 60%인 '치석' 변수와 100% 결측비율을 가지는 5개 변수 제거

# %%
GJ_2016.shape # 6개의 변수가 제거됨
# Out:
# (1000000, 28)

# %%
GJ_2016.describe()

# 영-분산에 해당하는 변수 : 기준년도/데이터공개일자
# Out:
#             기준년도         가입자일련번호            성별코드     연령대코드(5세단위)  \
# count  1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean      2016.0   500000.500000        1.466703       10.469293
# std          0.0   288675.278933        0.498890        2.843645
# min       2016.0        1.000000        1.000000        5.000000
# 25%       2016.0   250000.750000        1.000000        8.000000
# 50%       2016.0   500000.500000        1.000000       10.000000
# 75%       2016.0   750000.250000        2.000000       12.000000
# max       2016.0  1000000.000000        2.000000       18.000000
#
#                  시도코드      신장(5Cm단위)      체중(5Kg단위)           허리둘레  \
# count  1000000.000000  999103.000000  999103.000000  999807.000000
# mean        33.657342     162.386741      63.239341      81.252038
# std         12.692966       9.405526      12.709755      16.885343
# min         11.000000     100.000000      20.000000       2.000000
# 25%         27.000000     155.000000      55.000000      74.000000
# 50%         41.000000     160.000000      60.000000      81.000000
# 75%         44.000000     170.000000      70.000000      87.000000
# max         49.000000     205.000000     175.000000     999.000000
#
#                시력(좌)          시력(우)  ...       LDL콜레스테롤            혈색소  \
# count  999700.000000  999701.000000  ...  997369.000000  999947.000000
# mean        0.982544       0.979238  ...     114.417190      14.181924
# std         0.619421       0.611618  ...      38.261436       1.622612
# min         0.100000       0.100000  ...       1.000000       0.600000
# 25%         0.700000       0.700000  ...      90.000000      13.100000
# 50%         1.000000       1.000000  ...     112.000000      14.200000
# 75%         1.200000       1.200000  ...     136.000000      15.400000
# max         9.900000       9.900000  ...    9449.000000      25.000000
#
#                  요단백        혈청크레아티닌     (혈청지오티)AST     (혈청지오티)ALT  \
# count  995101.000000  999955.000000  999958.000000  999957.000000
# mean        1.092121       0.870973      25.695374      25.646171
# std         0.433205       0.526995      21.112738      25.289584
# min         1.000000       0.100000       1.000000       1.000000
# 25%         1.000000       0.700000      19.000000      15.000000
# 50%         1.000000       0.800000      22.000000      20.000000
# 75%         1.000000       1.000000      28.000000      29.000000
# max         6.000000      95.000000    7670.000000    7090.000000
#
#                감마지티피          흡연상태       구강검진 수검여부     데이터공개일자
# count  999957.000000  999787.00000  1000000.000000   1000000.0
# mean       36.984583       1.61585        0.401764  20171219.0
# std        50.178168       0.82446        0.490255         0.0
# min         1.000000       1.00000        0.000000  20171219.0
# 25%        15.000000       1.00000        0.000000  20171219.0
# 50%        23.000000       1.00000        0.000000  20171219.0
# 75%        39.000000       2.00000        1.000000  20171219.0
# max       999.000000       3.00000        1.000000  20171219.0
#
# [8 rows x 28 columns]

# %%
GJ_2016=GJ_2016.drop(['기준년도','데이터공개일자'],axis=1)

# 영-분산을 가지는 2개의 변수를 제거

# %%
GJ_2016.shape # 2개의 변수가 제거됨
# Out:
# (1000000, 26)

# %%
GJ_2016

# '가입자일련번호-1'와 index가 일치함
# Out:
#         가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  \
# 0             1     1           10    27      175.0       75.0  86.0    1.0
# 1             2     2           11    41      160.0       65.0  85.0    1.5
# 2             3     2           11    43      150.0       55.0  80.0    1.5
# 3             4     1           12    48      175.0       70.0  85.0    1.2
# 4             5     2            6    11      160.0       50.0  67.0    0.4
# 5             6     1            9    46      170.0       55.0  64.0    1.1
# 6             7     1           10    31      175.0       70.0  90.0    1.5
# 7             8     2           16    48      155.0       60.0  81.0    0.7
# 8             9     1           16    27      165.0       60.0  74.0    0.4
# 9            10     1           13    48      160.0       60.0  80.0    0.8
# 10           11     1            7    46      170.0       80.0  86.0    1.5
# 11           12     2            6    11      155.0       50.0  66.0    0.9
# 12           13     1            7    41      170.0       80.0  92.0    0.6
# 13           14     2           15    11      155.0       65.0  81.0    0.8
# 14           15     2           15    28      160.0       65.0  79.0    0.7
# 15           16     1           11    48      165.0       80.0  93.0    0.7
# 16           17     1            9    41      170.0       75.0  81.0    1.2
# 17           18     1            8    11      175.0       70.0  84.0    1.2
# 18           19     1            8    26      180.0       90.0  88.0    1.5
# 19           20     2            8    41      155.0       55.0  74.0    1.0
# 20           21     1           10    30      165.0       50.0  67.0    1.5
# 21           22     1            9    26      165.0       65.0  80.0    1.5
# 22           23     1           12    27      160.0       75.0  96.0    0.4
# 23           24     2            5    41      155.0       55.0  75.0    0.8
# 24           25     1           13    11      170.0       70.0  92.0    0.9
# 25           26     1           14    27      165.0       65.0  81.0    0.7
# 26           27     1           16    27      165.0       65.0  95.0    0.8
# 27           28     1           14    42      170.0       75.0  91.0    1.0
# 28           29     2            9    11      155.0       60.0  83.0    1.0
# 29           30     1            9    29      170.0       80.0  88.0    0.8
# ...         ...   ...          ...   ...        ...        ...   ...    ...
# 999970   999971     2            6    41      150.0       50.0  65.0    0.7
# 999971   999972     2            7    44      160.0       55.0  64.0    1.5
# 999972   999973     2           16    47      150.0       50.0  74.0    0.3
# 999973   999974     1            9    11      175.0       70.0  84.0    0.6
# 999974   999975     2           13    41      155.0       65.0  82.0    0.9
# 999975   999976     1           13    26      170.0       75.0  85.0    1.0
# 999976   999977     2           10    26      160.0       60.0  94.0    2.0
# 999977   999978     1           13    41      165.0       85.0  98.0    0.9
# 999978   999979     1            5    41      175.0       75.0  76.0    0.9
# 999979   999980     1           16    44      165.0       50.0  83.0    0.6
# 999980   999981     1           16    44      150.0       60.0  89.0    1.0
# 999981   999982     2            6    43      165.0       55.0  81.0    0.8
# 999982   999983     2           12    11      155.0       65.0  83.0    1.0
# 999983   999984     1           11    11      175.0       80.0  83.0    1.0
# 999984   999985     1            9    26      170.0       65.0  80.0    1.0
# 999985   999986     2            6    41      165.0       40.0  58.0    1.2
# 999986   999987     1           11    41      165.0       80.0  90.0    1.0
# 999987   999988     1           14    41      175.0       80.0  93.0    0.5
# 999988   999989     1            9    45      170.0       80.0  90.0    2.0
# 999989   999990     2           11    48      150.0       45.0  70.0    1.2
# 999990   999991     2           11    41      150.0       75.0  99.0    0.5
# 999991   999992     2            8    41      160.0       50.0  70.0    0.6
# 999992   999993     1            9    41      170.0       85.0  94.0    1.2
# 999993   999994     2            9    46      160.0       50.0  70.0    0.6
# 999994   999995     1           16    29      170.0       55.0  70.0    0.6
# 999995   999996     1           10    42      170.0       75.0  86.0    0.8
# 999996   999997     2           11    41      155.0       65.0  84.0    1.0
# 999997   999998     1           10    41      175.0       75.0  89.0    0.2
# 999998   999999     2           13    42      155.0       70.0  90.0    0.8
# 999999  1000000     2           10    41      150.0       45.0  66.0    1.2
#
#         시력(우)  청력(좌)  ...  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0         1.2    1.0  ...      46.0     177.0  16.0  1.0      0.9        27.0
# 1         1.2    1.0  ...      35.0     122.0  13.1  1.0      0.9        18.0
# 2         1.5    1.0  ...      59.0     150.0  13.6  1.0      0.7        23.0
# 3         1.2    1.0  ...      40.0     123.0  16.8  1.0      1.0        20.0
# 4         0.5    1.0  ...      72.0     130.0  12.8  1.0      0.7        13.0
# 5         1.2    1.0  ...      53.0     257.0  15.8  1.0      1.0        20.0
# 6         1.5    1.0  ...      50.0     138.0  13.9  1.0      0.8        25.0
# 7         0.5    1.0  ...      48.0     108.0  13.0  1.0      0.7        23.0
# 8         0.6    1.0  ...      59.0     129.0  13.5  1.0      1.0        21.0
# 9         0.2    1.0  ...      49.0      87.0  15.7  1.0      0.9        26.0
# 10        1.0    1.0  ...      53.0      95.0  16.7  1.0      1.0        27.0
# 11        0.6    1.0  ...      82.0      92.0  13.6  1.0      0.8        25.0
# 12        0.4    1.0  ...      42.0     145.0  15.3  1.0      1.0        22.0
# 13        0.5    1.0  ...      64.0      97.0  14.3  1.0      0.7        31.0
# 14        0.2    1.0  ...      45.0      84.0  13.9  1.0      0.9        19.0
# 15        0.8    1.0  ...      67.0      97.0  14.5  1.0      1.1        21.0
# 16        1.2    1.0  ...      45.0     103.0  14.0  1.0      0.9        34.0
# 17        1.2    1.0  ...      49.0     142.0  15.2  1.0      1.0        24.0
# 18        1.2    1.0  ...      47.0     130.0  13.7  1.0      0.8        16.0
# 19        1.0    1.0  ...      71.0     122.0  14.1  1.0      0.9        17.0
# 20        1.5    1.0  ...      91.0      88.0  15.9  1.0      0.8        19.0
# 21        2.0    1.0  ...      46.0     161.0  14.4  1.0      1.0        30.0
# 22        0.6    1.0  ...      36.0     147.0  14.7  1.0      1.2        43.0
# 23        0.5    1.0  ...      61.0      68.0  12.7  1.0      0.7        12.0
# 24        1.2    2.0  ...      42.0     136.0  15.4  1.0      1.2        57.0
# 25        0.9    1.0  ...      67.0      74.0  14.5  1.0      0.9        30.0
# 26        0.8    1.0  ...      33.0      72.0  11.4  1.0      2.3        19.0
# 27        0.9    1.0  ...      71.0     110.0  15.6  1.0      0.9        26.0
# 28        1.0    1.0  ...      72.0     116.0  12.7  1.0      0.8        21.0
# 29        0.8    1.0  ...      57.0     142.0  16.6  1.0      1.0       131.0
# ...       ...    ...  ...       ...       ...   ...  ...      ...         ...
# 999970    0.7    1.0  ...      66.0      85.0   9.7  1.0      0.5        19.0
# 999971    1.0    1.0  ...      55.0     101.0  12.7  1.0      0.6        18.0
# 999972    0.4    1.0  ...      56.0     137.0  13.9  1.0      1.0        19.0
# 999973    0.7    1.0  ...      48.0     110.0  15.6  1.0      1.0        15.0
# 999974    0.9    1.0  ...      56.0     118.0  13.4  1.0      0.7        17.0
# 999975    1.2    1.0  ...      33.0      84.0  13.6  1.0      1.0        18.0
# 999976    1.5    1.0  ...      67.0     133.0  15.3  1.0      0.7        48.0
# 999977    0.6    1.0  ...      41.0     196.0  15.3  1.0      1.1        23.0
# 999978    1.2    1.0  ...      49.0      82.0  16.3  1.0      1.1        11.0
# 999979    0.8    1.0  ...      39.0      48.0  16.6  1.0      1.2        33.0
# 999980    1.0    1.0  ...      56.0     106.0  12.8  1.0      0.8        43.0
# 999981    1.0    1.0  ...      67.0      55.0  12.9  1.0      0.6        11.0
# 999982    1.2    1.0  ...      64.0      63.0  12.4  1.0      0.9        18.0
# 999983    1.2    1.0  ...      38.0     113.0  14.7  1.0      1.0        23.0
# 999984    1.5    1.0  ...      59.0     175.0  15.3  1.0      0.9        15.0
# 999985    1.0    1.0  ...      73.0      96.0   8.1  1.0      0.7        35.0
# 999986    1.2    1.0  ...      55.0     110.0  15.5  1.0      1.0        19.0
# 999987    0.3    2.0  ...      65.0      74.0  15.1  3.0      0.9        24.0
# 999988    1.5    1.0  ...      25.0      55.0  18.4  1.0      0.9        18.0
# 999989    1.5    1.0  ...      63.0     114.0  12.1  1.0      0.6        24.0
# 999990    0.5    1.0  ...      54.0      97.0  13.0  1.0      0.8        24.0
# 999991    0.7    1.0  ...      71.0     116.0  13.9  1.0      0.8        21.0
# 999992    0.6    1.0  ...      42.0      81.0  15.3  1.0      0.9        49.0
# 999993    0.5    1.0  ...      78.0     139.0  12.9  1.0      0.6        30.0
# 999994    0.5    1.0  ...      49.0     116.0  15.0  1.0      0.9        29.0
# 999995    0.8    1.0  ...      30.0      82.0  15.0  1.0      0.8        24.0
# 999996    0.9    1.0  ...      58.0     172.0  13.2  1.0      0.9        29.0
# 999997    0.9    1.0  ...      44.0     109.0  15.6  1.0      0.8        20.0
# 999998    0.7    1.0  ...      71.0     128.0  13.3  1.0      0.8        17.0
# 999999    1.2    1.0  ...      59.0      94.0  13.2  1.0      0.8        19.0
#
#         (혈청지오티)ALT  감마지티피  흡연상태  구강검진 수검여부
# 0             30.0   45.0   3.0          0
# 1             17.0   19.0   1.0          0
# 2             19.0   64.0   1.0          0
# 3             39.0   69.0   2.0          1
# 4              7.0   20.0   1.0          0
# 5             14.0   12.0   1.0          1
# 6             30.0   24.0   3.0          1
# 7             14.0   14.0   1.0          0
# 8             16.0   20.0   1.0          0
# 9             32.0   24.0   1.0          0
# 10            39.0   81.0   3.0          1
# 11            39.0   19.0   1.0          0
# 12            22.0  101.0   1.0          1
# 13            26.0   26.0   1.0          0
# 14            14.0   11.0   1.0          0
# 15            20.0   32.0   2.0          0
# 16            39.0   19.0   2.0          0
# 17            21.0   18.0   2.0          0
# 18            22.0   20.0   1.0          0
# 19            13.0   22.0   1.0          0
# 20            11.0   37.0   3.0          0
# 21            40.0   62.0   1.0          1
# 22            62.0   37.0   2.0          0
# 23             8.0    6.0   1.0          0
# 24            40.0   61.0   2.0          0
# 25            14.0   15.0   2.0          0
# 26            17.0   14.0   1.0          0
# 27            23.0   12.0   2.0          0
# 28            20.0   55.0   1.0          0
# 29           285.0   74.0   1.0          1
# ...            ...    ...   ...        ...
# 999970         8.0   11.0   1.0          0
# 999971        18.0   18.0   3.0          1
# 999972        29.0   36.0   1.0          0
# 999973         9.0   25.0   3.0          1
# 999974        18.0   17.0   1.0          0
# 999975        23.0   21.0   1.0          0
# 999976        20.0   35.0   1.0          0
# 999977        26.0   38.0   1.0          0
# 999978        16.0   13.0   1.0          1
# 999979        14.0   14.0   1.0          0
# 999980        55.0   79.0   1.0          0
# 999981         9.0    8.0   2.0          1
# 999982        12.0   19.0   1.0          0
# 999983        37.0   25.0   1.0          1
# 999984        16.0   19.0   3.0          0
# 999985        39.0   19.0   1.0          0
# 999986        22.0   41.0   3.0          0
# 999987        25.0   37.0   2.0          0
# 999988        24.0   52.0   3.0          0
# 999989        19.0   28.0   1.0          0
# 999990        28.0   31.0   1.0          0
# 999991        13.0   27.0   1.0          1
# 999992        84.0   88.0   2.0          1
# 999993        27.0   14.0   1.0          0
# 999994        21.0   21.0   1.0          0
# 999995        39.0   44.0   3.0          1
# 999996        34.0  143.0   3.0          1
# 999997        24.0   23.0   3.0          0
# 999998        15.0   12.0   1.0          0
# 999999        20.0   12.0   1.0          1
#
# [1000000 rows x 26 columns]

# %%
GJ_2016.rename(index=GJ_2016['가입자일련번호'])
# index를 가입자 일련번호로 설정
# Out:
#          가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  \
# 1              1     1           10    27      175.0       75.0  86.0    1.0
# 2              2     2           11    41      160.0       65.0  85.0    1.5
# 3              3     2           11    43      150.0       55.0  80.0    1.5
# 4              4     1           12    48      175.0       70.0  85.0    1.2
# 5              5     2            6    11      160.0       50.0  67.0    0.4
# 6              6     1            9    46      170.0       55.0  64.0    1.1
# 7              7     1           10    31      175.0       70.0  90.0    1.5
# 8              8     2           16    48      155.0       60.0  81.0    0.7
# 9              9     1           16    27      165.0       60.0  74.0    0.4
# 10            10     1           13    48      160.0       60.0  80.0    0.8
# 11            11     1            7    46      170.0       80.0  86.0    1.5
# 12            12     2            6    11      155.0       50.0  66.0    0.9
# 13            13     1            7    41      170.0       80.0  92.0    0.6
# 14            14     2           15    11      155.0       65.0  81.0    0.8
# 15            15     2           15    28      160.0       65.0  79.0    0.7
# 16            16     1           11    48      165.0       80.0  93.0    0.7
# 17            17     1            9    41      170.0       75.0  81.0    1.2
# 18            18     1            8    11      175.0       70.0  84.0    1.2
# 19            19     1            8    26      180.0       90.0  88.0    1.5
# 20            20     2            8    41      155.0       55.0  74.0    1.0
# 21            21     1           10    30      165.0       50.0  67.0    1.5
# 22            22     1            9    26      165.0       65.0  80.0    1.5
# 23            23     1           12    27      160.0       75.0  96.0    0.4
# 24            24     2            5    41      155.0       55.0  75.0    0.8
# 25            25     1           13    11      170.0       70.0  92.0    0.9
# 26            26     1           14    27      165.0       65.0  81.0    0.7
# 27            27     1           16    27      165.0       65.0  95.0    0.8
# 28            28     1           14    42      170.0       75.0  91.0    1.0
# 29            29     2            9    11      155.0       60.0  83.0    1.0
# 30            30     1            9    29      170.0       80.0  88.0    0.8
# ...          ...   ...          ...   ...        ...        ...   ...    ...
# 999971    999971     2            6    41      150.0       50.0  65.0    0.7
# 999972    999972     2            7    44      160.0       55.0  64.0    1.5
# 999973    999973     2           16    47      150.0       50.0  74.0    0.3
# 999974    999974     1            9    11      175.0       70.0  84.0    0.6
# 999975    999975     2           13    41      155.0       65.0  82.0    0.9
# 999976    999976     1           13    26      170.0       75.0  85.0    1.0
# 999977    999977     2           10    26      160.0       60.0  94.0    2.0
# 999978    999978     1           13    41      165.0       85.0  98.0    0.9
# 999979    999979     1            5    41      175.0       75.0  76.0    0.9
# 999980    999980     1           16    44      165.0       50.0  83.0    0.6
# 999981    999981     1           16    44      150.0       60.0  89.0    1.0
# 999982    999982     2            6    43      165.0       55.0  81.0    0.8
# 999983    999983     2           12    11      155.0       65.0  83.0    1.0
# 999984    999984     1           11    11      175.0       80.0  83.0    1.0
# 999985    999985     1            9    26      170.0       65.0  80.0    1.0
# 999986    999986     2            6    41      165.0       40.0  58.0    1.2
# 999987    999987     1           11    41      165.0       80.0  90.0    1.0
# 999988    999988     1           14    41      175.0       80.0  93.0    0.5
# 999989    999989     1            9    45      170.0       80.0  90.0    2.0
# 999990    999990     2           11    48      150.0       45.0  70.0    1.2
# 999991    999991     2           11    41      150.0       75.0  99.0    0.5
# 999992    999992     2            8    41      160.0       50.0  70.0    0.6
# 999993    999993     1            9    41      170.0       85.0  94.0    1.2
# 999994    999994     2            9    46      160.0       50.0  70.0    0.6
# 999995    999995     1           16    29      170.0       55.0  70.0    0.6
# 999996    999996     1           10    42      170.0       75.0  86.0    0.8
# 999997    999997     2           11    41      155.0       65.0  84.0    1.0
# 999998    999998     1           10    41      175.0       75.0  89.0    0.2
# 999999    999999     2           13    42      155.0       70.0  90.0    0.8
# 1000000  1000000     2           10    41      150.0       45.0  66.0    1.2
#
#          시력(우)  청력(좌)  ...  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  \
# 1          1.2    1.0  ...      46.0     177.0  16.0  1.0      0.9
# 2          1.2    1.0  ...      35.0     122.0  13.1  1.0      0.9
# 3          1.5    1.0  ...      59.0     150.0  13.6  1.0      0.7
# 4          1.2    1.0  ...      40.0     123.0  16.8  1.0      1.0
# 5          0.5    1.0  ...      72.0     130.0  12.8  1.0      0.7
# 6          1.2    1.0  ...      53.0     257.0  15.8  1.0      1.0
# 7          1.5    1.0  ...      50.0     138.0  13.9  1.0      0.8
# 8          0.5    1.0  ...      48.0     108.0  13.0  1.0      0.7
# 9          0.6    1.0  ...      59.0     129.0  13.5  1.0      1.0
# 10         0.2    1.0  ...      49.0      87.0  15.7  1.0      0.9
# 11         1.0    1.0  ...      53.0      95.0  16.7  1.0      1.0
# 12         0.6    1.0  ...      82.0      92.0  13.6  1.0      0.8
# 13         0.4    1.0  ...      42.0     145.0  15.3  1.0      1.0
# 14         0.5    1.0  ...      64.0      97.0  14.3  1.0      0.7
# 15         0.2    1.0  ...      45.0      84.0  13.9  1.0      0.9
# 16         0.8    1.0  ...      67.0      97.0  14.5  1.0      1.1
# 17         1.2    1.0  ...      45.0     103.0  14.0  1.0      0.9
# 18         1.2    1.0  ...      49.0     142.0  15.2  1.0      1.0
# 19         1.2    1.0  ...      47.0     130.0  13.7  1.0      0.8
# 20         1.0    1.0  ...      71.0     122.0  14.1  1.0      0.9
# 21         1.5    1.0  ...      91.0      88.0  15.9  1.0      0.8
# 22         2.0    1.0  ...      46.0     161.0  14.4  1.0      1.0
# 23         0.6    1.0  ...      36.0     147.0  14.7  1.0      1.2
# 24         0.5    1.0  ...      61.0      68.0  12.7  1.0      0.7
# 25         1.2    2.0  ...      42.0     136.0  15.4  1.0      1.2
# 26         0.9    1.0  ...      67.0      74.0  14.5  1.0      0.9
# 27         0.8    1.0  ...      33.0      72.0  11.4  1.0      2.3
# 28         0.9    1.0  ...      71.0     110.0  15.6  1.0      0.9
# 29         1.0    1.0  ...      72.0     116.0  12.7  1.0      0.8
# 30         0.8    1.0  ...      57.0     142.0  16.6  1.0      1.0
# ...        ...    ...  ...       ...       ...   ...  ...      ...
# 999971     0.7    1.0  ...      66.0      85.0   9.7  1.0      0.5
# 999972     1.0    1.0  ...      55.0     101.0  12.7  1.0      0.6
# 999973     0.4    1.0  ...      56.0     137.0  13.9  1.0      1.0
# 999974     0.7    1.0  ...      48.0     110.0  15.6  1.0      1.0
# 999975     0.9    1.0  ...      56.0     118.0  13.4  1.0      0.7
# 999976     1.2    1.0  ...      33.0      84.0  13.6  1.0      1.0
# 999977     1.5    1.0  ...      67.0     133.0  15.3  1.0      0.7
# 999978     0.6    1.0  ...      41.0     196.0  15.3  1.0      1.1
# 999979     1.2    1.0  ...      49.0      82.0  16.3  1.0      1.1
# 999980     0.8    1.0  ...      39.0      48.0  16.6  1.0      1.2
# 999981     1.0    1.0  ...      56.0     106.0  12.8  1.0      0.8
# 999982     1.0    1.0  ...      67.0      55.0  12.9  1.0      0.6
# 999983     1.2    1.0  ...      64.0      63.0  12.4  1.0      0.9
# 999984     1.2    1.0  ...      38.0     113.0  14.7  1.0      1.0
# 999985     1.5    1.0  ...      59.0     175.0  15.3  1.0      0.9
# 999986     1.0    1.0  ...      73.0      96.0   8.1  1.0      0.7
# 999987     1.2    1.0  ...      55.0     110.0  15.5  1.0      1.0
# 999988     0.3    2.0  ...      65.0      74.0  15.1  3.0      0.9
# 999989     1.5    1.0  ...      25.0      55.0  18.4  1.0      0.9
# 999990     1.5    1.0  ...      63.0     114.0  12.1  1.0      0.6
# 999991     0.5    1.0  ...      54.0      97.0  13.0  1.0      0.8
# 999992     0.7    1.0  ...      71.0     116.0  13.9  1.0      0.8
# 999993     0.6    1.0  ...      42.0      81.0  15.3  1.0      0.9
# 999994     0.5    1.0  ...      78.0     139.0  12.9  1.0      0.6
# 999995     0.5    1.0  ...      49.0     116.0  15.0  1.0      0.9
# 999996     0.8    1.0  ...      30.0      82.0  15.0  1.0      0.8
# 999997     0.9    1.0  ...      58.0     172.0  13.2  1.0      0.9
# 999998     0.9    1.0  ...      44.0     109.0  15.6  1.0      0.8
# 999999     0.7    1.0  ...      71.0     128.0  13.3  1.0      0.8
# 1000000    1.2    1.0  ...      59.0      94.0  13.2  1.0      0.8
#
#          (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태  구강검진 수검여부
# 1              27.0        30.0   45.0   3.0          0
# 2              18.0        17.0   19.0   1.0          0
# 3              23.0        19.0   64.0   1.0          0
# 4              20.0        39.0   69.0   2.0          1
# 5              13.0         7.0   20.0   1.0          0
# 6              20.0        14.0   12.0   1.0          1
# 7              25.0        30.0   24.0   3.0          1
# 8              23.0        14.0   14.0   1.0          0
# 9              21.0        16.0   20.0   1.0          0
# 10             26.0        32.0   24.0   1.0          0
# 11             27.0        39.0   81.0   3.0          1
# 12             25.0        39.0   19.0   1.0          0
# 13             22.0        22.0  101.0   1.0          1
# 14             31.0        26.0   26.0   1.0          0
# 15             19.0        14.0   11.0   1.0          0
# 16             21.0        20.0   32.0   2.0          0
# 17             34.0        39.0   19.0   2.0          0
# 18             24.0        21.0   18.0   2.0          0
# 19             16.0        22.0   20.0   1.0          0
# 20             17.0        13.0   22.0   1.0          0
# 21             19.0        11.0   37.0   3.0          0
# 22             30.0        40.0   62.0   1.0          1
# 23             43.0        62.0   37.0   2.0          0
# 24             12.0         8.0    6.0   1.0          0
# 25             57.0        40.0   61.0   2.0          0
# 26             30.0        14.0   15.0   2.0          0
# 27             19.0        17.0   14.0   1.0          0
# 28             26.0        23.0   12.0   2.0          0
# 29             21.0        20.0   55.0   1.0          0
# 30            131.0       285.0   74.0   1.0          1
# ...             ...         ...    ...   ...        ...
# 999971         19.0         8.0   11.0   1.0          0
# 999972         18.0        18.0   18.0   3.0          1
# 999973         19.0        29.0   36.0   1.0          0
# 999974         15.0         9.0   25.0   3.0          1
# 999975         17.0        18.0   17.0   1.0          0
# 999976         18.0        23.0   21.0   1.0          0
# 999977         48.0        20.0   35.0   1.0          0
# 999978         23.0        26.0   38.0   1.0          0
# 999979         11.0        16.0   13.0   1.0          1
# 999980         33.0        14.0   14.0   1.0          0
# 999981         43.0        55.0   79.0   1.0          0
# 999982         11.0         9.0    8.0   2.0          1
# 999983         18.0        12.0   19.0   1.0          0
# 999984         23.0        37.0   25.0   1.0          1
# 999985         15.0        16.0   19.0   3.0          0
# 999986         35.0        39.0   19.0   1.0          0
# 999987         19.0        22.0   41.0   3.0          0
# 999988         24.0        25.0   37.0   2.0          0
# 999989         18.0        24.0   52.0   3.0          0
# 999990         24.0        19.0   28.0   1.0          0
# 999991         24.0        28.0   31.0   1.0          0
# 999992         21.0        13.0   27.0   1.0          1
# 999993         49.0        84.0   88.0   2.0          1
# 999994         30.0        27.0   14.0   1.0          0
# 999995         29.0        21.0   21.0   1.0          0
# 999996         24.0        39.0   44.0   3.0          1
# 999997         29.0        34.0  143.0   3.0          1
# 999998         20.0        24.0   23.0   3.0          0
# 999999         17.0        15.0   12.0   1.0          0
# 1000000        19.0        20.0   12.0   1.0          1
#
# [1000000 rows x 26 columns]

# %%
GJ_2016=GJ_2016.drop(['가입자일련번호'],axis=1)
# 가입자일련번호 변수 제거

# %%
GJ_2016.shape # 1개의 변수가 제거됨
# Out:
# (1000000, 25)

# %%
GJ_2016.isna().sum()

# 결측치가 있는 변수 : 신장/체중/허리둘레/시력좌/시력우/청력좌/청력우/수축기혈압/이완기혈압/식전혈당
# 결측치가 있는 변수 : 총콜레스테롤/트리글리세라이드/HDL/LDL/혈색소/요단백/혈청크레아티닌/AST/ALT/GTP/흡연상태/음주여부
# Out:
# 성별코드              0
# 연령대코드(5세단위)       0
# 시도코드              0
# 신장(5Cm단위)       897
# 체중(5Kg단위)       897
# 허리둘레            193
# 시력(좌)           300
# 시력(우)           299
# 청력(좌)           266
# 청력(우)           266
# 수축기혈압            88
# 이완기혈압            89
# 식전혈당(공복혈당)       48
# 총콜레스테롤           43
# 트리글리세라이드         44
# HDL콜레스테롤         47
# LDL콜레스테롤       2631
# 혈색소              53
# 요단백            4899
# 혈청크레아티닌          45
# (혈청지오티)AST       42
# (혈청지오티)ALT       43
# 감마지티피            43
# 흡연상태            213
# 구강검진 수검여부         0
# dtype: int64

# %%
fill_mean_func = lambda g: g.fillna(g.mean())
GJ_2016=GJ_2016.groupby(['성별코드','연령대코드(5세단위)','시도코드']).apply(fill_mean_func)

# sex, age, sido 그룹별로 결측값 평균치 대체
# mean, median, mode 중 UE(비편향) 성질을 만족하는 평균값으로 대체
# 각 변수별로 이상치가 많으나, 데이터의 갯수가 충분히 확보(100만개)된 상태이므로, mean 사용
# 전반적으로 히스토그램이 우측 긴 꼬리의 형태를 나타내고 있으므로, 평균 > 중앙값 > 최빈값 순서를 따름
# https://rfriend.tistory.com/402 : 결측값을 그룹 평균값으로 채우기 (Fill missing values by Group means)
# 출처: https://rfriend.tistory.com/402 [R, Python 분석과 프로그래밍 (by R Friend)]

# %%
GJ_2016=GJ_2016.drop(['성별코드','연령대코드(5세단위)','시도코드'], axis=1)

# %%
GJ_2016.reset_index(inplace=True)

# 인덱스 초기화
# inplace=True : 객체 반환 x(결과물 안보이게 하기)
# https://nittaku.tistory.com/122

# %%
del GJ_2016['level_3']

# del health['변수명'] : 특정 변수 제거

# %%
GJ_2016.head()
# Out:
#    성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0     1            5    11      180.0       90.0  88.0    0.9    0.9    1.0
# 1     1            5    11      170.0       65.0  70.0    1.2    1.0    1.0
# 2     1            5    11      170.0       80.0  89.0    1.0    1.5    1.0
# 3     1            5    11      165.0       55.0  68.0    1.0    1.0    1.0
# 4     1            5    11      180.0       75.0  88.0    1.0    1.2    1.0
#
#    청력(우)  ...  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  \
# 0    1.0  ...      43.0     110.0  16.2  1.0      0.9        16.0        20.0
# 1    1.0  ...      64.0      72.0  14.9  1.0      0.8        23.0        17.0
# 2    1.0  ...      45.0     116.0  17.8  1.0      0.9        15.0        20.0
# 3    1.0  ...      55.0      80.0  16.1  2.0      1.0        19.0        11.0
# 4    1.0  ...      52.0      99.0  16.0  1.0      0.8        16.0        11.0
#
#    감마지티피  흡연상태  구강검진 수검여부
# 0   24.0   3.0          0
# 1   18.0   1.0          0
# 2   27.0   3.0          0
# 3   15.0   1.0          1
# 4   12.0   3.0          0
#
# [5 rows x 25 columns]

# %%
GJ_2016.shape
# Out:
# (1000000, 25)

# %%
GJ_2016.describe()
# Out:
#                  성별코드     연령대코드(5세단위)            시도코드       신장(5Cm단위)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         1.466703       10.469293       33.657342      162.387401
# std          0.498890        2.843645       12.692966        9.405256
# min          1.000000        5.000000       11.000000      100.000000
# 25%          1.000000        8.000000       27.000000      155.000000
# 50%          1.000000       10.000000       41.000000      160.000000
# 75%          2.000000       12.000000       44.000000      170.000000
# max          2.000000       18.000000       49.000000      205.000000
#
#             체중(5Kg단위)            허리둘레           시력(좌)           시력(우)  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        63.239868       81.251708        0.982525        0.979220
# std         12.707181       16.883842        0.619338        0.611535
# min         20.000000        2.000000        0.100000        0.100000
# 25%         55.000000       74.000000        0.700000        0.700000
# 50%         60.000000       81.000000        1.000000        1.000000
# 75%         70.000000       87.000000        1.200000        1.200000
# max        175.000000      999.000000        9.900000        9.900000
#
#                 청력(좌)           청력(우)  ...        HDL콜레스테롤        LDL콜레스테롤  \
# count  1000000.000000  1000000.000000  ...  1000000.000000  1000000.000000
# mean         1.031025        1.029923  ...       56.396531      114.421661
# std          0.173337        0.170326  ...       19.979935       38.212291
# min          1.000000        1.000000  ...        1.000000        1.000000
# 25%          1.000000        1.000000  ...       46.000000       90.000000
# 50%          1.000000        1.000000  ...       54.000000      112.000000
# 75%          1.000000        1.000000  ...       65.000000      136.000000
# max          2.000000        2.000000  ...     6409.000000     9449.000000
#
#                   혈색소             요단백         혈청크레아티닌      (혈청지오티)AST  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        14.181914        1.092195        0.870972       25.695348
# std          1.622593        0.432153        0.526984       21.112306
# min          0.600000        1.000000        0.100000        1.000000
# 25%         13.100000        1.000000        0.700000       19.000000
# 50%         14.200000        1.000000        0.800000       22.000000
# 75%         15.400000        1.000000        1.000000       28.000000
# max         25.000000        6.000000       95.000000     7670.000000
#
#            (혈청지오티)ALT           감마지티피            흡연상태       구강검진 수검여부
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        25.646107       36.984430        1.615795        0.401764
# std         25.289074       50.177178        0.824403        0.490255
# min          1.000000        1.000000        1.000000        0.000000
# 25%         15.000000       15.000000        1.000000        0.000000
# 50%         20.000000       23.000000        1.000000        0.000000
# 75%         29.000000       39.000000        2.000000        1.000000
# max       7090.000000      999.000000        3.000000        1.000000
#
# [8 rows x 25 columns]

# %%
GJ_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 25 columns):
# 성별코드           1000000 non-null int64
# 연령대코드(5세단위)    1000000 non-null int64
# 시도코드           1000000 non-null int64
# 신장(5Cm단위)      1000000 non-null float64
# 체중(5Kg단위)      1000000 non-null float64
# 허리둘레           1000000 non-null float64
# 시력(좌)          1000000 non-null float64
# 시력(우)          1000000 non-null float64
# 청력(좌)          1000000 non-null float64
# 청력(우)          1000000 non-null float64
# 수축기혈압          1000000 non-null float64
# 이완기혈압          1000000 non-null float64
# 식전혈당(공복혈당)     1000000 non-null float64
# 총콜레스테롤         1000000 non-null float64
# 트리글리세라이드       1000000 non-null float64
# HDL콜레스테롤       1000000 non-null float64
# LDL콜레스테롤       1000000 non-null float64
# 혈색소            1000000 non-null float64
# 요단백            1000000 non-null float64
# 혈청크레아티닌        1000000 non-null float64
# (혈청지오티)AST     1000000 non-null float64
# (혈청지오티)ALT     1000000 non-null float64
# 감마지티피          1000000 non-null float64
# 흡연상태           1000000 non-null float64
# 구강검진 수검여부      1000000 non-null int64
# dtypes: float64(21), int64(4)
# memory usage: 190.7 MB

# %%
GJ_2016 = GJ_2016.rename(columns = {'성별코드' : 'sex',
                    '연령대코드(5세단위)' : 'year',
                    '시도코드' : 'sido',
                    '신장(5Cm단위)' : 'height',
                    '체중(5Kg단위)' : 'weight',
                    '허리둘레' : 'waist',
                    '시력(좌)' : 'sight_left',
                    '시력(우)' : 'sight_right',
                    '청력(좌)' : 'hearing_left',
                    '청력(우)' : 'hearing_right',
                    '수축기혈압' : 'SBP',
                    '이완기혈압' : 'RPBP',
                    '식전혈당(공복혈당)' : 'pred_blood_sugar',
                    '총콜레스테롤' : 'cholesterol',
                    '트리글리세라이드' : 'triglycerides',
                    'HDL콜레스테롤' : 'HDL',
                    'LDL콜레스테롤' : 'LDL',
                    '혈색소' : 'blood_pigment',
                    '요단백' : 'urine_protein',
                    '혈청크레아티닌' : 'serum_creatinine',
                    '(혈청지오티)AST' : 'AST',
                    '(혈청지오티)ALT' : 'ALT',
                    '감마지티피' : 'gamma_gtp',
                    '흡연상태' : 'smoking',
                    '구강검진 수검여부' : 'oral_inspection'})

# 시각화에서 변수명 출력을 위해 영어로 변경

# %%
GJ_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 25 columns):
# sex                 1000000 non-null int64
# year                1000000 non-null int64
# sido                1000000 non-null int64
# height              1000000 non-null float64
# weight              1000000 non-null float64
# waist               1000000 non-null float64
# sight_left          1000000 non-null float64
# sight_right         1000000 non-null float64
# hearing_left        1000000 non-null float64
# hearing_right       1000000 non-null float64
# SBP                 1000000 non-null float64
# RPBP                1000000 non-null float64
# pred_blood_sugar    1000000 non-null float64
# cholesterol         1000000 non-null float64
# triglycerides       1000000 non-null float64
# HDL                 1000000 non-null float64
# LDL                 1000000 non-null float64
# blood_pigment       1000000 non-null float64
# urine_protein       1000000 non-null float64
# serum_creatinine    1000000 non-null float64
# AST                 1000000 non-null float64
# ALT                 1000000 non-null float64
# gamma_gtp           1000000 non-null float64
# smoking             1000000 non-null float64
# oral_inspection     1000000 non-null int64
# dtypes: float64(21), int64(4)
# memory usage: 190.7 MB

# %%
import matplotlib
import matplotlib.pyplot as plt

# 데이터 탐색을 위한 시각화 패키지 장착

# %%
plt.hist(GJ_2016['height'], histtype='bar', rwidth=0.9)
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
plt.boxplot(GJ_2016['height'])
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# %%
GJ_2016['pred_blood_sugar'] = np.where(GJ_2016['pred_blood_sugar'] >= 126, 1, 0)

# target 변수인 pred_blood_sugar가 126 이상일 때, 당뇨진단으로 판정
# 이분형 자료로 변환
# https://rfriend.tistory.com/tag/Python

# %%
GJ_2016['pred_blood_sugar'].value_counts()

# 당뇨진단자 비율 : 7 ~ 8 % 사이
# Out:
# 0    924381
# 1     75619
# Name: pred_blood_sugar, dtype: int64

# %% [markdown]
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
GJ_2016.hist(bins=50, figsize=(20,15))
plt.show()



# ALT / AST / HDL / LDL / RPBP / SBP / cholesterol / gamma_gtp / height / serum_creatinine / sight_left / sight_right -> skwed distribution
# triglycerides / urine_protein / waist / weight -> skwed distribution
# blood_pigment -> normal distribution
# oral_inspection -> 이산형, 비교적 고른 분포
# hearing_left / hearing_right / smoking / pred_blood_sugar -> class unbalance
# sex / year / sido -> groupby 기준변수

# %%
GJ_2016.boxplot(figsize=(30,15))
plt.show()

# %% [markdown]
# # 이상치 처리
# 일반적으로 1) 표준점수로 변환 후 -3 이하 및 +3 제거 2) IQR 방식 3) 도메인 지식 이용하거나 Binning 처리하는 방식이 이용된다.
#
# 표준점수 이용할 경우 평균이 0, 표준편차가 1인 분포로 변환한후 +3 이상이거나 -3 이하인 경우 극단치로 처리한다.
#
# IQR 방식은 75% percentile * 1.5 이상이거나 25 percentile* 1.5 이하인 경우 극단치로 처리하는 방식이다.
# 이해하기 쉽고 적용하기 쉬운 편이지만, 경우에 따라 너무 많은 사례들이 극단치로 고려되는 경우가 있다.
#
# https://wikidocs.net/16582
#
# ![image.png](attachment:image.png)
#
# 연속형 변수 목록
#
# -> 신장(5Cm단위) / 체중(5Kg단위) / 허리둘레 / 시력좌 / 시력우 / 수축기혈압 / 이완기혈압 / 식전혈당.공복혈당 / 총콜레스테롤 / 트리글리세라이드 / HDL콜레스테롤 / LDL콜레스테롤 / 혈색소 / 혈청크레아티닌 / X.혈청지오티.AST / X.혈청지오티.ALT / 감마지티피 : 연속형 변수
#
# 이산형 변수 목록
#
# -> 성별코드 / 연령대코드 / 시도코드 / 청력좌 / 청력우 / 요단백 / 흡연상태 / 구강검진.수검여부 / 음주여부 : 이산형 변수(성별코드,연령대코드,시도코드,요단백,흡연상태 : 다범주, 나머지 변수 : 이분형)

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 3)
    upper_bound = quartile_3 + (iqr * 3)
    return np.where((ys > upper_bound) | (ys < lower_bound))

# %%
print(np.array(outliers_iqr(GJ_2016['height'])).shape[1],
      np.array(outliers_iqr(GJ_2016['weight'])).shape[1],
      np.array(outliers_iqr(GJ_2016['waist'])).shape[1],
      np.array(outliers_iqr(GJ_2016['sight_left'])).shape[1],
      np.array(outliers_iqr(GJ_2016['sight_right'])).shape[1],
      np.array(outliers_iqr(GJ_2016['SBP'])).shape[1],
      np.array(outliers_iqr(GJ_2016['RPBP'])).shape[1],
      np.array(outliers_iqr(GJ_2016['pred_blood_sugar'])).shape[1],
      np.array(outliers_iqr(GJ_2016['cholesterol'])).shape[1],
      np.array(outliers_iqr(GJ_2016['triglycerides'])).shape[1],
      np.array(outliers_iqr(GJ_2016['HDL'])).shape[1],
      np.array(outliers_iqr(GJ_2016['LDL'])).shape[1],
      np.array(outliers_iqr(GJ_2016['blood_pigment'])).shape[1],
      np.array(outliers_iqr(GJ_2016['serum_creatinine'])).shape[1],
      np.array(outliers_iqr(GJ_2016['AST'])).shape[1],
      np.array(outliers_iqr(GJ_2016['ALT'])).shape[1],
      np.array(outliers_iqr(GJ_2016['gamma_gtp'])).shape[1])

# Outer fence(바깥 울타리) 기준 심각한 이상치는 최소 9개를 가진 변수(height)부터 최대 44312개를 가진 변수(gamma_gtp)까지 있음
# gamma_gtp 변수의 OF 기준 이상치 제거할 경우, 데이터 손실율 약 4.4%
# 특정 연령, 성별, 시/도에 해당하는 범주의 경우, 이상치 비율이 많을 경우 문제 발생
# 이상치 제거 방법으로 IQR 정보를 이용하는 것이 바람직하지 않을 수 있음
# Out:
# 9 977 426 3313 3210 770 1471 75619 563 17871 1012 472 223 2449 27326 30342 44514

# %% [markdown]
# 데이터 단위 변환
# 데이터의 스케일(측정단위)이 다를 경우 특히 거리를 기반으로 분류하는 모델(KNN 등)에 부정적인 영향을 미치므로, 스케일링을 통해 단위를 일정하게 맞추는 작업을 진행해야 한다. 아래 방식이 주로 스케일링을 위해 쓰이는 방법이다. 대부분의 통계 분석 방법이 정규성 가정을 기반으로 하므로 완벽하지 않더라도 최대한 정규분포로 변환하는 노력이 필요하다.
#
# Scaling: 평균이 0, 분산이 1인 분포로 변환
# MinMax Scaling: 특정 범위 (예, 0~1)로 모든 데이터를 변환
# Box-Cox: 여러 k 값중 가장 작은 SSE 선택
# Robust_scale: median, interquartile range 사용(outlier 영향 최소화)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# http://ko.logpresso.com/documents/anomaly-detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clf = IsolationForest(max_samples=1000, random_state=1, contamination=0.01, max_features=2)
# Isolation Forest 방법을 사용하기 위해, 변수로 선언을 해 준다.
# n_estimators=100 : 학습모형 100개
# max_samples=100 : 모형 당 최대 아웃라이어 갯수 1000개
# contamination='legacy' : 아웃라이어 비율 : 0.01(10000개)
# max_features=2 : 각 학습모형이 2개의 변수로 학습됨
# bootstrap=False : 각 학습모형이 샘플을 비복원 추출함
clf.fit(GJ_2016)
# fit 함수를 이용하여, 데이터셋을 학습
y_pred_outliers = clf.predict(GJ_2016)
# predict 함수를 이용하여, outlier를 판별. 0과 1로 이루어진 Series형태의 데이터가 나옴

out = pd.DataFrame(y_pred_outliers)
out = out.rename(columns={0: "out"})
GJ_2016 = pd.concat([GJ_2016, out], 1)
# 원래의 dataframe에 붙이기. 데이터가 0인 것이 outlier이기 때문에, 0인 것을 제거하면 outlier가 제거된 dataframe을 얻을 수 있음

# https://mkjjo.github.io/python/2019/01/10/outlier.html
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html
# Out:
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\HanJeongWook\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
GJ_2016['out'].value_counts()

# 10000개의 이상치를 detecting(label : -1)
# Out:
#  1    990000
# -1     10000
# Name: out, dtype: int64

# %%
GJ_2016=GJ_2016[GJ_2016['out']==1]

# %%
GJ_2016.boxplot(figsize=(30,15))
plt.show()

# %%
GJ_2016=GJ_2016[(GJ_2016['waist']<500) & (GJ_2016['cholesterol']<6000) & (GJ_2016['LDL']<4000) & (GJ_2016['ALT']<2000)]

# Box-plot에서 불연속이면서 많은 값의 차이를 보이는 이상치 제거

# %%
GJ_2016.boxplot(figsize=(30,15))
plt.show()

# 불연속으로 많이 떨어진 이상치 제거

# %%
del GJ_2016['out']

# %%
GJ_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 989802 entries, 0 to 999999
# Data columns (total 25 columns):
# sex                 989802 non-null int64
# year                989802 non-null int64
# sido                989802 non-null int64
# height              989802 non-null float64
# weight              989802 non-null float64
# waist               989802 non-null float64
# sight_left          989802 non-null float64
# sight_right         989802 non-null float64
# hearing_left        989802 non-null float64
# hearing_right       989802 non-null float64
# SBP                 989802 non-null float64
# RPBP                989802 non-null float64
# pred_blood_sugar    989802 non-null int32
# cholesterol         989802 non-null float64
# triglycerides       989802 non-null float64
# HDL                 989802 non-null float64
# LDL                 989802 non-null float64
# blood_pigment       989802 non-null float64
# urine_protein       989802 non-null float64
# serum_creatinine    989802 non-null float64
# AST                 989802 non-null float64
# ALT                 989802 non-null float64
# gamma_gtp           989802 non-null float64
# smoking             989802 non-null float64
# oral_inspection     989802 non-null int64
# dtypes: float64(20), int32(1), int64(4)
# memory usage: 192.6 MB

# %%
GJ_2016 = GJ_2016.rename(columns = {'height' : 'height_2016',
                    'weight' : 'weight_2016',
                    'waist' : 'waist_2016',
                    'sight_left' : 'sight_left_2016',
                    'sight_right' : 'sight_right_2016',
                    'hearing_left' : 'hearing_left_2016',
                    'hearing_right' : 'hearing_right_2016',
                    'SBP' : 'SBP_2016',
                    'RPBP' : 'RPBP_2016',
                    'cholesterol' : 'cholesterol_2016',
                    'triglycerides' : 'triglycerides_2016',
                    'HDL' : 'HDL_2016',
                    'LDL' : 'LDL_2016',
                    'blood_pigment' : 'blood_pigment_2016',
                    'urine_protein' : 'urine_protein_2016',
                    'serum_creatinine' : 'serum_creatinine_2016',
                    'AST' : 'AST_2016',
                    'ALT' : 'ALT_2016',
                    'gamma_gtp' : 'gamma_gtp_2016',
                    'smoking' : 'smoking_2016',
                    'oral_inspection' : 'oral_inspection_2016'})

# 2017년도 건강검진정보 예측변수(22개) rename

# %%
GJ_2016['target'] = GJ_2016['pred_blood_sugar']

# %%
del GJ_2016['pred_blood_sugar']

# %%
plt.hist(GJ_2016['target'], histtype='bar', rwidth=0.9)
plt.xlabel('pre_blood_sugar')
plt.ylabel('frequency')
plt.show()

# https://ordo.tistory.com/69

# %%
GJ_2016.head()
# Out:
#    sex  year  sido  height_2016  weight_2016  waist_2016  sight_left_2016  \
# 0    1     5    11        180.0         90.0        88.0              0.9
# 1    1     5    11        170.0         65.0        70.0              1.2
# 2    1     5    11        170.0         80.0        89.0              1.0
# 3    1     5    11        165.0         55.0        68.0              1.0
# 4    1     5    11        180.0         75.0        88.0              1.0
#
#    sight_right_2016  hearing_left_2016  hearing_right_2016  ...  LDL_2016  \
# 0               0.9                1.0                 1.0  ...     110.0
# 1               1.0                1.0                 1.0  ...      72.0
# 2               1.5                1.0                 1.0  ...     116.0
# 3               1.0                1.0                 1.0  ...      80.0
# 4               1.2                1.0                 1.0  ...      99.0
#
#    blood_pigment_2016  urine_protein_2016  serum_creatinine_2016  AST_2016  \
# 0                16.2                 1.0                    0.9      16.0
# 1                14.9                 1.0                    0.8      23.0
# 2                17.8                 1.0                    0.9      15.0
# 3                16.1                 2.0                    1.0      19.0
# 4                16.0                 1.0                    0.8      16.0
#
#    ALT_2016  gamma_gtp_2016  smoking_2016  oral_inspection_2016  target
# 0      20.0            24.0           3.0                     0       0
# 1      17.0            18.0           1.0                     0       0
# 2      20.0            27.0           3.0                     0       0
# 3      11.0            15.0           1.0                     1       0
# 4      11.0            12.0           3.0                     0       0
#
# [5 rows x 25 columns]

# %%
GJ_2016_group = GJ_2016.groupby(['sex','year','sido']).mean()

# 시/도 그룹별 평균치를 저장

# %%
GJ_2016_group.reset_index(inplace=True)

# %%
GJ_2016_group

# 476개 범주를 가지는 자료형태로 변환
# dimension : 476x25
# Out:
#      sex  year  sido  height_2016  weight_2016  waist_2016  sight_left_2016  \
# 0      1     5    11   172.365385    70.269231   80.158654         1.077404
# 1      1     5    26   171.344605    68.913043   79.413849         1.070048
# 2      1     5    27   171.709234    70.530452   80.683694         1.099411
# 3      1     5    28   172.134146    70.144817   80.038110         1.112500
# 4      1     5    29   171.996047    69.664032   79.608696         1.118182
# 5      1     5    30   172.083333    70.235507   80.489130         1.089130
# 6      1     5    31   171.870968    69.838710   80.109677         1.105806
# 7      1     5    36   171.891892    70.135135   79.756757         1.064865
# 8      1     5    41   171.018000    68.438000   79.438800         1.121600
# 9      1     5    42   172.743682    71.416968   79.422383         1.142855
# 10     1     5    43   171.302521    68.224790   78.909866         1.145890
# 11     1     5    44   171.028571    67.952381   79.017143         1.121455
# 12     1     5    45   171.439206    68.784119   79.047146         1.110918
# 13     1     5    46   171.709402    69.358974   79.168091         1.106553
# 14     1     5    47   171.204268    69.131098   80.314024         1.128506
# 15     1     5    48   170.824742    68.592784   79.200000         1.105979
# 16     1     5    49   170.714286    69.642857   79.595238         0.967857
# 17     1     6    11   173.060509    72.996246   82.919760         1.094378
# 18     1     6    26   172.356708    72.548227   82.565494         1.103617
# 19     1     6    27   172.112276    72.840880   82.953401         1.133060
# 20     1     6    28   172.121423    72.835808   82.918853         1.129349
# 21     1     6    29   172.059165    72.006961   82.287703         1.144084
# 22     1     6    30   172.608489    72.952773   83.154334         1.146300
# 23     1     6    31   172.303965    72.748899   82.732159         1.090573
# 24     1     6    36   172.148438    72.773438   82.765625         1.097656
# 25     1     6    41   171.860456    71.689839   82.339172         1.122657
# 26     1     6    42   172.534121    74.293313   82.713191         1.167489
# 27     1     6    43   171.983624    71.372277   81.868107         1.153577
# 28     1     6    44   171.678710    71.392440   82.424680         1.147497
# 29     1     6    45   172.097672    71.972461   81.982932         1.128213
# ..   ...   ...   ...          ...          ...         ...              ...
# 446    2    17    29   146.971154    51.802885   83.605769         0.591346
# 447    2    17    30   146.237113    51.546392   83.989691         0.642784
# 448    2    17    31   146.915888    51.448598   83.588785         0.553271
# 449    2    17    36   144.515993    50.765993   83.305556         0.555724
# 450    2    17    41   146.722502    51.760834   83.650415         0.670950
# 451    2    17    42   145.338542    50.442708   81.927083         0.667448
# 452    2    17    43   145.149858    49.151585   81.783278         0.562827
# 453    2    17    44   145.433195    49.178296   82.014733         0.643462
# 454    2    17    45   145.416798    48.808511   80.923894         0.606018
# 455    2    17    46   146.849418    49.874543   81.406486         0.561584
# 456    2    17    47   145.843281    48.931759   80.580606         0.554303
# 457    2    17    48   146.780070    49.913371   80.647073         0.540738
# 458    2    17    49   147.238095    52.666667   82.752381         0.579048
# 459    2    18    11   146.128670    49.726408   82.909073         0.514284
# 460    2    18    26   147.038835    49.611650   81.864078         0.485693
# 461    2    18    27   144.616725    46.177700   79.756799         0.464007
# 462    2    18    28   147.291183    49.664388   82.623100         0.587683
# 463    2    18    29   143.815789    47.500000   80.394737         0.768421
# 464    2    18    30   146.758242    50.406593   82.888571         0.555286
# 465    2    18    31   143.809524    43.809524   77.761905         0.514286
# 466    2    18    36   144.209184    47.627551   78.806122         0.363776
# 467    2    18    41   145.260444    48.021250   81.372263         0.546743
# 468    2    18    42   144.199226    47.283366   80.690909         0.462721
# 469    2    18    43   144.285229    45.984720   80.688000         0.583267
# 470    2    18    44   144.623222    46.648120   81.112450         0.672333
# 471    2    18    45   144.977584    45.621027   79.042553         0.515603
# 472    2    18    46   145.656168    46.150610   78.794118         0.623529
# 473    2    18    47   143.650794    45.608466   78.201058         0.417989
# 474    2    18    48   145.346115    46.362261   77.715487         0.482126
# 475    2    18    49   146.764706    50.882353   79.529412         0.518736
#
#      sight_right_2016  hearing_left_2016  hearing_right_2016  ...    LDL_2016  \
# 0            1.073750           1.001925            1.000000  ...   96.511613
# 1            1.055395           1.009662            1.008052  ...   96.909823
# 2            1.068173           1.009823            1.009823  ...   94.980354
# 3            1.101829           1.003049            1.004573  ...   95.614329
# 4            1.113043           1.007905            1.003953  ...  100.233202
# 5            1.072826           1.003623            1.003623  ...   96.108696
# 6            1.086129           1.000000            1.003226  ...   97.260895
# 7            1.110811           1.000000            1.000000  ...   96.054054
# 8            1.101480           1.002800            1.004000  ...   97.359839
# 9            1.166183           1.003623            1.000000  ...   96.745311
# 10           1.131577           1.004210            1.006316  ...   94.487395
# 11           1.118584           1.003831            1.000000  ...   94.799667
# 12           1.130273           1.000000            1.000000  ...   96.547515
# 13           1.112821           1.000000            1.000000  ...   94.678063
# 14           1.139024           1.006098            1.003049  ...   96.624138
# 15           1.108454           1.003093            1.006186  ...   94.474914
# 16           0.976190           1.011905            1.000000  ...  101.738095
# 17           1.073838           1.003059            1.002103  ...  107.082134
# 18           1.116667           1.001955            1.001955  ...  105.919543
# 19           1.095025           1.003149            1.002519  ...  106.547593
# 20           1.114723           1.001458            1.003887  ...  107.675311
# 21           1.126334           1.004640            1.004640  ...  107.745752
# 22           1.143658           1.003171            1.002114  ...  105.240411
# 23           1.087048           1.003524            1.003524  ...  108.080283
# 24           1.128906           1.007812            1.000000  ...  102.742188
# 25           1.119143           1.003312            1.003202  ...  106.810003
# 26           1.160000           1.004255            1.004255  ...  107.385053
# 27           1.167213           1.002981            1.002235  ...  103.862080
# 28           1.155117           1.004447            1.002779  ...  105.597325
# 29           1.137651           1.002008            1.002008  ...  106.170066
# ..                ...                ...                 ...  ...         ...
# 446          0.766827           1.216346            1.197115  ...  111.629808
# 447          0.651546           1.180412            1.201031  ...  106.051546
# 448          0.649533           1.327103            1.289720  ...  114.467290
# 449          0.518266           1.158249            1.158249  ...  112.818182
# 450          0.681014           1.155484            1.147086  ...  109.489098
# 451          0.594271           1.153646            1.166667  ...  107.363161
# 452          0.629490           1.161343            1.172267  ...  113.861413
# 453          0.625783           1.147330            1.147330  ...  112.167967
# 454          0.587965           1.161062            1.145133  ...  113.256637
# 455          0.579857           1.120969            1.110122  ...  114.380805
# 456          0.638182           1.151515            1.156364  ...  108.839435
# 457          0.624758           1.133644            1.138796  ...  117.601377
# 458          0.498095           1.133333            1.114286  ...  111.828571
# 459          0.491790           1.210187            1.206037  ...  101.036885
# 460          0.493421           1.245437            1.235728  ...  115.155340
# 461          0.574251           1.186063            1.216725  ...  109.400000
# 462          0.490406           1.227411            1.214148  ...  104.519481
# 463          0.523684           1.078947            1.078947  ...  104.789474
# 464          0.541571           1.257895            1.227068  ...  109.914286
# 465          0.547619           1.142857            1.238095  ...  113.724868
# 466          0.394388           1.153061            1.229592  ...  106.357143
# 467          0.541390           1.170045            1.181673  ...  106.859446
# 468          0.554901           1.183916            1.201335  ...  106.818182
# 469          0.483326           1.114021            1.190400  ...  106.610526
# 470          0.405866           1.140940            1.174497  ...  117.912752
# 471          0.509220           1.184397            1.163121  ...  106.617021
# 472          0.500980           1.142157            1.117647  ...  112.436275
# 473          0.538624           1.116402            1.153439  ...  111.798942
# 474          0.425167           1.122911            1.158232  ...  112.419580
# 475          0.549673           1.117647            1.000000  ...  117.117647
#
#      blood_pigment_2016  urine_protein_2016  serum_creatinine_2016   AST_2016  \
# 0             15.584615            1.055831               0.960000  24.348077
# 1             15.474396            1.048309               0.940097  23.745572
# 2             15.540668            1.037328               0.966601  24.467583
# 3             15.618750            1.061068               0.972713  23.935976
# 4             15.439921            1.075099               0.986166  23.407115
# 5             15.552536            1.050725               0.947464  22.757246
# 6             15.400645            1.051779               0.916129  22.548387
# 7             15.340541            1.027027               0.970270  24.702703
# 8             15.556160            1.055224               0.964800  23.702000
# 9             15.604152            1.019856               0.982491  24.963899
# 10            15.505672            1.035789               0.982353  24.548319
# 11            15.502118            1.043810               0.952100  24.687345
# 12            15.532010            1.014888               0.953350  23.429280
# 13            15.472080            1.048571               0.965812  22.962963
# 14            15.479878            1.033648               0.953049  23.332317
# 15            15.358351            1.038144               0.943814  24.729897
# 16            15.600000            1.011905               0.939286  22.095238
# 17            15.601321            1.059347               0.968356  24.661516
# 18            15.535288            1.052840               0.952835  25.082111
# 19            15.561693            1.030880               0.969270  25.482368
# 20            15.619145            1.055421               0.980612  25.177843
# 21            15.557309            1.085015               0.984339  25.269142
# 22            15.445666            1.077167               0.964693  24.923890
# 23            15.412599            1.048458               0.921057  25.452863
# 24            15.579688            1.031250               0.971094  25.468750
# 25            15.583784            1.056785               0.966862  25.157633
# 26            15.741106            1.029818               0.996426  25.582979
# 27            15.602161            1.040238               0.984054  25.184054
# 28            15.604058            1.033465               0.962868  24.608116
# 29            15.550301            1.046185               0.957028  25.780120
# ..                  ...                 ...                    ...        ...
# 446           12.475962            1.069464               0.845192  24.524038
# 447           12.677320            1.089039               0.803093  24.685567
# 448           12.711215            1.121495               0.819626  25.542056
# 449           12.669697            1.151515               0.824242  26.030303
# 450           12.714615            1.146822               0.838042  24.682517
# 451           12.769271            1.098017               0.855469  24.294271
# 452           12.604891            1.137259               0.838043  24.127717
# 453           12.587109            1.101966               0.830018  24.545120
# 454           12.183540            1.091514               0.841593  24.099115
# 455           12.206656            1.080523               0.850774  25.605263
# 456           12.415394            1.134290               0.807758  23.505455
# 457           12.213311            1.107857               0.827986  24.747440
# 458           12.578095            1.059030               0.863810  24.752381
# 459           12.447131            1.165041               0.877459  24.290984
# 460           12.269903            1.167180               0.922330  25.135922
# 461           12.291429            1.127106               0.832857  23.842857
# 462           12.309091            1.202346               0.851948  24.194805
# 463           12.300000            1.105263               0.871053  25.131579
# 464           12.414286            1.242857               0.862857  23.657143
# 465           11.852381            1.000000               0.866667  24.000000
# 466           12.050000            1.000000               0.885714  24.714286
# 467           12.355233            1.196639               0.872093  23.369186
# 468           12.665455            1.113116               0.820000  22.490909
# 469           11.973684            1.060942               0.878947  23.336842
# 470           12.042028            1.085116               0.890604  24.496644
# 471           12.175887            1.093528               0.887943  23.574468
# 472           11.771569            1.133213               0.907843  24.235294
# 473           12.077778            1.153686               0.849735  23.238095
# 474           11.772727            1.111802               0.849650  25.748252
# 475           12.217647            1.000000               0.858824  23.235294
#
#       ALT_2016  gamma_gtp_2016  smoking_2016  oral_inspection_2016    target
# 0    25.225962       26.961538      1.971154              0.562500  0.009615
# 1    24.396135       26.446055      1.953301              0.557166  0.006441
# 2    23.899804       25.622790      1.964637              0.410609  0.007859
# 3    24.865854       28.794207      2.097561              0.661585  0.010671
# 4    25.509881       28.233202      2.000000              0.529644  0.007905
# 5    24.355072       27.597826      2.000000              0.615942  0.000000
# 6    22.551613       24.645161      2.154839              0.516129  0.012903
# 7    20.864865       22.405405      1.918919              0.675676  0.000000
# 8    24.651600       27.879600      1.961200              0.516400  0.006000
# 9    23.395307       25.467509      2.092058              0.711191  0.007220
# 10   23.815126       27.674370      2.004202              0.647059  0.006303
# 11   24.071555       26.262251      1.979048              0.651429  0.005714
# 12   24.133995       26.168734      2.047146              0.625310  0.000000
# 13   22.752137       27.270655      1.928775              0.498575  0.005698
# 14   24.195122       26.102134      2.044207              0.507622  0.009146
# 15   24.089691       25.707216      1.971134              0.400000  0.005155
# 16   23.869048       27.678571      2.071429              0.547619  0.000000
# 17   27.841235       33.517688      1.920268              0.572166  0.007073
# 18   28.791789       33.727273      2.046432              0.538612  0.008309
# 19   29.558564       32.707809      2.001261              0.396725  0.010705
# 20   29.018950       36.961613      2.039845              0.637998  0.012148
# 21   30.453596       37.892111      1.961717              0.524362  0.013921
# 22   28.287526       33.614165      1.989429              0.652220  0.005285
# 23   27.801762       32.317181      2.021145              0.659912  0.011454
# 24   30.304688       37.921875      1.968750              0.726562  0.015625
# 25   29.034220       35.406226      1.980566              0.593995  0.008169
# 26   29.320000       34.830638      2.135319              0.620426  0.008511
# 27   27.657228       34.694486      2.061848              0.653502  0.010432
# 28   28.221234       34.027237      2.015564              0.634241  0.012785
# 29   30.317269       33.585341      2.016064              0.626506  0.005020
# ..         ...             ...           ...                   ...       ...
# 446  18.951923       23.947115      1.033654              0.264423  0.182692
# 447  17.675258       25.221649      1.020619              0.231959  0.164948
# 448  17.990654       22.000000      1.056075              0.308411  0.149533
# 449  17.272727       25.969697      1.060606              0.121212  0.090909
# 450  18.246154       22.696503      1.030791              0.163636  0.136364
# 451  17.026042       22.270833      1.026042              0.171875  0.130208
# 452  17.119565       20.616848      1.032609              0.184783  0.133152
# 453  16.920810       22.130755      1.005525              0.106814  0.134438
# 454  17.139823       20.623009      1.019469              0.219469  0.122124
# 455  19.270898       22.818885      1.020124              0.074303  0.136223
# 456  17.195152       20.665455      1.037576              0.044848  0.115152
# 457  17.341297       21.665529      1.054608              0.081911  0.124573
# 458  19.723810       23.819048      1.019048              0.161905  0.180952
# 459  15.471311       20.221311      1.036885              0.159836  0.143443
# 460  16.815534       27.291262      1.029126              0.126214  0.145631
# 461  16.085714       27.742857      1.057143              0.042857  0.085714
# 462  16.090909       21.805195      1.025974              0.090909  0.090909
# 463  16.157895       21.763158      1.000000              0.026316  0.131579
# 464  15.885714       21.914286      1.057143              0.085714  0.114286
# 465  16.190476       30.428571      1.000000              0.285714  0.190476
# 466  14.714286       21.142857      1.071429              0.071429  0.357143
# 467  15.049419       20.287791      1.023256              0.098837  0.107558
# 468  14.545455       20.445455      1.018182              0.072727  0.090909
# 469  15.021053       20.810526      1.073684              0.073684  0.105263
# 470  15.020134       19.046980      1.006711              0.060403  0.120805
# 471  15.475177       20.794326      1.028369              0.113475  0.127660
# 472  16.166667       18.656863      1.019608              0.014706  0.098039
# 473  15.814815       18.269841      1.031746              0.021164  0.126984
# 474  15.944056       23.132867      1.062937              0.034965  0.048951
# 475  16.294118       17.235294      1.000000              0.117647  0.235294
#
# [476 rows x 25 columns]

# %%
GJ_2016_group.to_csv("GJ_2016_group.csv")

# 2016년 건강검진정보 데이터전처리 -> 476개 범주화된 자료를 csv로 저장
# https://tariat.tistory.com/583

# %%
# 척도화
# https://mkjjo.github.io/python/2019/01/10/scaler.html

# 데이터 분할
# https://pythonanalysis.tistory.com/7

# 데이터 분포 변환
# https://wikidocs.net/16582
